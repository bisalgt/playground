# %% [markdown]
# ##### In this document, I will be going through how to run shell scripts through python

# %%
import subprocess

# %%
subprocess.call("ls")
# Out:
# async learn py.ipynb
# htmcore.ipynb
# learn async js.ipynb
# learn js 2.ipynb
# learn js.ipynb
# learn shell scripting.ipynb
# learn-opencv.ipynb
# think py 2.ipynb
# think py.ipynb
# 0

# %%
tr
