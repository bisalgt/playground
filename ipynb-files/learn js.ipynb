// %%
console.log("Its working");
// Out:
// Its working

// %%
function name(){
    console.log("Name");
}

name()
// Out:
// Name

// %%
function letTest() {
  let x = 1;
  {
    let x = 2; // different variable
    x = 4;
      console.log(x);  // 2
  }
  console.log(x);  // 1
}

letTest()
// Out:
// 4
// 1

// %%
function varTest() {
  var x = 1;
  {
    var x = 2;  // same variable!
    console.log(x);  // 2
  }
  console.log(x);  // 2
}
varTest()
// Out:
// 2
// 2

// %%
var x = 'global';
let y = 'global';
console.log(this.x); // "global"
console.log(this.y); // undefined
// Out:
// global
// undefined

// %%
console.log(this.c)
// Out:
// undefined

// %%
{ // TDZ starts at beginning of scope
  console.log(bar); // undefined
  console.log(foo); // ReferenceError
  var bar = 1;
  let foo = 2; // End of TDZ (for foo)
}
// Out:
// undefined
// evalmachine.<anonymous>:3
//   console.log(foo); // ReferenceError
//               ^
//
// ReferenceError: Cannot access 'foo' before initialization
//     at evalmachine.<anonymous>:3:15
//     at Script.runInThisContext (node:vm:129:12)
//     at Object.runInThisContext (node:vm:305:38)
//     at run ([eval]:1054:15)
//     at onRunRequest ([eval]:888:18)
//     at onMessage ([eval]:848:13)
//     at process.emit (node:events:520:28)
//     at emit (node:internal/child_process:936:14)
//     at processTicksAndRejections (node:internal/process/task_queues:84:21)

// %%
typeof i
var i;
// Out:
// 'undefined'

// %%
typeof j;
let j;
// Out:
// evalmachine.<anonymous>:1
// typeof j;
// ^
//
// ReferenceError: Cannot access 'j' before initialization
//     at evalmachine.<anonymous>:1:1
//     at Script.runInThisContext (node:vm:129:12)
//     at Object.runInThisContext (node:vm:305:38)
//     at run ([eval]:1054:15)
//     at onRunRequest ([eval]:888:18)
//     at onMessage ([eval]:848:13)
//     at process.emit (node:events:520:28)
//     at emit (node:internal/child_process:936:14)
//     at processTicksAndRejections (node:internal/process/task_queues:84:21)

// %%
var a = 1;
{
    console.log(a); // this line produces reference error as a is redeclared using let, this makes a not exist in the block before the let statment
    let a = 3;
    console.log(a);
}
//let a = 2;
// Out:
// evalmachine.<anonymous>:3
//     console.log(a); // this line produces reference error as a is redeclared using let, this makes a not exist in the block before the let statment
//                 ^
//
// ReferenceError: Cannot access 'a' before initialization
//     at evalmachine.<anonymous>:3:17
//     at Script.runInThisContext (node:vm:129:12)
//     at Object.runInThisContext (node:vm:305:38)
//     at run ([eval]:1054:15)
//     at onRunRequest ([eval]:888:18)
//     at onMessage ([eval]:848:13)
//     at process.emit (node:events:520:28)
//     at emit (node:internal/child_process:936:14)
//     at processTicksAndRejections (node:internal/process/task_queues:84:21)

// %%
let age = 14;
typeof age;
// Out:
// 'number'

// %%
let name = "Bishal";
typeof name;
// Out:
// 'string'

// %%
name.__proto__
// Out:
// {}

// %%
name.isPrototypeOf(String)
// Out:
// false

// %%
String.isPrototypeOf(name)
// Out:
// false

// %%
let dog = { name : 'Spot', breed : 'Dalmatian' };

// %%
dog.__proto__
// Out:
// [Object: null prototype] {}

// %% [markdown]
// ##### In js, you don't need to specify what data type a variable will contain (numbers, strings, arrays, etc).

// %% [markdown]
// #### Constants in JavaScript
//
// you must initialize them when you declare them
//  and you can't assign them a new value after you've initialized them.

// %%
const con = 4;

// %%
const conn;
// Out:
// evalmachine.<anonymous>:1
// const conn;
//       ^^^^
//
// SyntaxError: Missing initializer in const declaration
//     at new Script (node:vm:100:7)
//     at createScript (node:vm:257:10)
//     at Object.runInThisContext (node:vm:305:10)
//     at run ([eval]:1054:15)
//     at onRunRequest ([eval]:888:18)
//     at onMessage ([eval]:848:13)
//     at process.emit (node:events:520:28)
//     at emit (node:internal/child_process:936:14)
//     at processTicksAndRejections (node:internal/process/task_queues:84:21)

// %%
let b = 4;
typeof b
// Out:
// 'number'

// %%
typeof 4.5
// Out:
// 'number'

// %%
Number.MIN_VALUE
// Out:
// 5e-324

// %%
Number.MAX_VALUE
// Out:
// 1.7976931348623157e+308

// %%
b = 4.5533333333;
b.valueOf()
// Out:
// 4.5533333333

// %%
let myNumber = '74';
myNumber += 3;
// Out:
// '743'

// %%
typeof Number(myNumber)
// Out:
// 'number'

// %%
"aaa" * 4
// Out:
// NaN

// %%
"aaa" + 4
// Out:
// 'aaa4'
