// %%
console.log("Its working");
// Out:
// Its working

// %%
function name(){
    console.log("Name");
}

name()
// Out:
// Name

// %%
function letTest() {
  let x = 1;
  {
    let x = 2; // different variable
    x = 4;
      console.log(x);  // 2
  }
  console.log(x);  // 1
}

letTest()
// Out:
// 4
// 1

// %%
function varTest() {
  var x = 1;
  {
    var x = 2;  // same variable!
    console.log(x);  // 2
  }
  console.log(x);  // 2
}
varTest()
// Out:
// 2
// 2

// %%
var x = 'global';
let y = 'global';
console.log(this.x); // "global"
console.log(this.y); // undefined
// Out:
// global
// undefined

// %%
console.log(this.c)
// Out:
// undefined

// %%
{ // TDZ starts at beginning of scope
  console.log(bar); // undefined
  console.log(foo); // ReferenceError
  var bar = 1;
  let foo = 2; // End of TDZ (for foo)
}
// Out:
// undefined
// evalmachine.<anonymous>:3
//   console.log(foo); // ReferenceError
//               ^
//
// ReferenceError: Cannot access 'foo' before initialization
//     at evalmachine.<anonymous>:3:15
//     at Script.runInThisContext (node:vm:129:12)
//     at Object.runInThisContext (node:vm:305:38)
//     at run ([eval]:1054:15)
//     at onRunRequest ([eval]:888:18)
//     at onMessage ([eval]:848:13)
//     at process.emit (node:events:520:28)
//     at emit (node:internal/child_process:936:14)
//     at processTicksAndRejections (node:internal/process/task_queues:84:21)

// %%
typeof i
var i;
// Out:
// 'undefined'

// %%
typeof j;
let j;
// Out:
// evalmachine.<anonymous>:1
// typeof j;
// ^
//
// ReferenceError: Cannot access 'j' before initialization
//     at evalmachine.<anonymous>:1:1
//     at Script.runInThisContext (node:vm:129:12)
//     at Object.runInThisContext (node:vm:305:38)
//     at run ([eval]:1054:15)
//     at onRunRequest ([eval]:888:18)
//     at onMessage ([eval]:848:13)
//     at process.emit (node:events:520:28)
//     at emit (node:internal/child_process:936:14)
//     at processTicksAndRejections (node:internal/process/task_queues:84:21)

// %%
var a = 1;
{
    console.log(a); // this line produces reference error as a is redeclared using let, this makes a not exist in the block before the let statment
    let a = 3;
    console.log(a);
}
//let a = 2;
// Out:
// evalmachine.<anonymous>:3
//     console.log(a); // this line produces reference error as a is redeclared using let, this makes a not exist in the block before the let statment
//                 ^
//
// ReferenceError: Cannot access 'a' before initialization
//     at evalmachine.<anonymous>:3:17
//     at Script.runInThisContext (node:vm:129:12)
//     at Object.runInThisContext (node:vm:305:38)
//     at run ([eval]:1054:15)
//     at onRunRequest ([eval]:888:18)
//     at onMessage ([eval]:848:13)
//     at process.emit (node:events:520:28)
//     at emit (node:internal/child_process:936:14)
//     at processTicksAndRejections (node:internal/process/task_queues:84:21)

// %%
let age = 14;
typeof age;
// Out:
// 'number'

// %%
let name = "Bishal";
typeof name;
// Out:
// 'string'

// %%
name.__proto__
// Out:
// {}

// %%
name.isPrototypeOf(String)
// Out:
// false

// %%
String.isPrototypeOf(name)
// Out:
// false

// %%
let dog = { name : 'Spot', breed : 'Dalmatian' };

// %%
dog.__proto__
// Out:
// [Object: null prototype] {}

// %% [markdown]
// ##### In js, you don't need to specify what data type a variable will contain (numbers, strings, arrays, etc).

// %% [markdown]
// #### Constants in JavaScript
//
// you must initialize them when you declare them
//  and you can't assign them a new value after you've initialized them.

// %%
const con = 4;

// %%
const conn;
// Out:
// evalmachine.<anonymous>:1
// const conn;
//       ^^^^
//
// SyntaxError: Missing initializer in const declaration
//     at new Script (node:vm:100:7)
//     at createScript (node:vm:257:10)
//     at Object.runInThisContext (node:vm:305:10)
//     at run ([eval]:1054:15)
//     at onRunRequest ([eval]:888:18)
//     at onMessage ([eval]:848:13)
//     at process.emit (node:events:520:28)
//     at emit (node:internal/child_process:936:14)
//     at processTicksAndRejections (node:internal/process/task_queues:84:21)

// %%
let b = 4;
typeof b
// Out:
// 'number'

// %%
typeof 4.5
// Out:
// 'number'

// %%
Number.MIN_VALUE
// Out:
// 5e-324

// %%
Number.MAX_VALUE
// Out:
// 1.7976931348623157e+308

// %%
b = 4.5533333333;
b.valueOf()
// Out:
// 4.5533333333

// %%
let myNumber = '74';
myNumber += 3;
// Out:
// '743'

// %%
typeof Number(myNumber)
// Out:
// 'number'

// %%
"aaa" * 4
// Out:
// NaN

// %%
"aaa" + 4
// Out:
// 'aaa4'

// %%
function Employee(){
    this.name = ""
    this.dept = "general"
    // console.log(this)
}

e1 = new Employee()
// Out:
// Employee { name: '', dept: 'general' }

// %%
e1.name
// Out:
// ''

// %%
e1.dept
// Out:
// 'general'

// %%
e1.constructor
// Out:
// [Function: Employee]

// %%
function Manager(){
    Employee.call(this);
    this.reports = [];
}

m1 = new Manager()
// Out:
// Manager { name: '', dept: 'general', reports: [] }

// %%
m1.constructor
// Out:
// [Function: Manager]

// %%
Manager.prototype
// Out:
// {}

// %%
Employee.prototype
// Out:
// {}

// %%
e1.age = 13;
// Out:
// 13

// %%
m1
// Out:
// Manager { name: '', dept: 'general', reports: [] }

// %%
Employee.height = 34;
// Out:
// 34

// %%
e1 = new Employee()
// Out:
// Employee { name: '', dept: 'general' }

// %%
e1
// Out:
// Employee { name: '', dept: 'general' }

// %%
Manager.prototype = Object.create(Employee.prototype);
// Out:
// Employee {}

// %%
Manager.prototype
// Out:
// Employee {}

// %%
Manager.prototype.constructor
// Out:
// [Function: Employee] { height: 34 }

// %%
Manager.prototype.constructor = Manager;
// Out:
// [Function: Manager]

// %%
m1 = new Manager()
// Out:
// Manager { name: '', dept: 'general', reports: [] }

// %%
e1
// Out:
// Employee { name: '', dept: 'general' }

// %%
e1.constructor
// Out:
// [Function: Employee] { height: 34 }

// %%
m1.constructor
// Out:
// [Function: Manager]

// %%
function WorkerBee()
{
    Employee.call(this);
    this.projects = [];
}

// %%
e1 = new Employee();
m1 = new Manager();
w1 = new WorkerBee();
// Out:
// WorkerBee { name: '', dept: 'general', projects: [] }

// %%
console.log(e1);console.log(m1);console.log(w1);
// Out:
// Employee { name: '', dept: 'general' }
// Manager { name: '', dept: 'general', reports: [] }
// WorkerBee { name: '', dept: 'general', projects: [] }

// %%
Employee.prototype
// Out:
// {}

// %%
Manager.prototype
// Out:
// Employee { constructor: [Function: Manager] }

// %%
WorkerBee.prototype
// Out:
// {}

// %%
Employee.age = 34;
// Out:
// 34

// %%
e2 = new Employee();
// Out:
// Employee { name: '', dept: 'general' }

// %%
e2.constructor
// Out:
// [Function: Employee] { age: 34 }

// %%
m2 = new Manager();
// Out:
// Manager { name: '', dept: 'general', reports: [] }

// %%
Manager.prototype
// Out:
// Employee { constructor: [Function: Manager] }

// %%
Manager.prototype.constructor
// Out:
// [Function: Manager]

// %%
Manager.prototype
// Out:
// Employee { constructor: [Function: Manager] }

// %%
WorkerBee.prototype
// Out:
// {}

// %%
WorkerBee.prototype = Object.create(Employee.prototype)
// Out:
// Employee {}

// %%
WorkerBee.prototype
// Out:
// Employee {}

// %%
WorkerBee.prototype.constructor = WorkerBee;
// Out:
// [Function: WorkerBee]

// %%
function Engineer()
{
    WorkerBee.call(this)
    this.dept = "engineering";
    this.machine = "";
    //console.log(this)
}
eg1 = new Engineer()
// Out:
// Engineer { name: '', dept: 'engineering', projects: [], machine: '' }

// %%
Engineer.prototype
// Out:
// {}

// %%
Engineer.constructor
// Out:
// [Function: Function]

// %%
eg1.constructor
// Out:
// [Function: Engineer]

// %%
function Engineer()
{
    WorkerBee.call(this)
    this.dept = "engineering";
    this.machine = "";
    //console.log(this)
}
Engineer.prototype = Object.create(WorkerBee.prototype);
Engineer.prototype.constructor = Engineer;

eg1 = new Engineer()
// Out:
// Engineer { name: '', dept: 'engineering', projects: [], machine: '' }

// %%
Engineer.prototype
// Out:
// WorkerBee { constructor: [Function: Engineer] }

// %%
function SalesPerson()
{
    WorkerBee.call(this);
    this.dept = "sales";
    this.quota = 100;
}
SalesPerson.prototype = Object.create(WorkerBee.prototype);
SalesPerson.prototype.constructor = SalesPerson;
// Out:
// [Function: SalesPerson]

// %%
s1 = SalesPerson()

// %%
typeof s1
// Out:
// 'undefined'

// %%
s1 = new SalesPerson()
typeof s1
// Out:
// 'object'

// %%
s1
// Out:
// SalesPerson { name: '', dept: 'sales', projects: [], quota: 100 }

// %%
SalesPerson.prototype.constructor = Engineer;
// Out:
// [Function: Engineer]

// %%
s1
// Out:
// WorkerBee { name: '', dept: 'sales', projects: [], quota: 100 }

// %%
s2 = new SalesPerson()
// Out:
// WorkerBee { name: '', dept: 'sales', projects: [], quota: 100 }

// %%
SalesPerson.prototype
// Out:
// WorkerBee { constructor: [Function: Engineer] }

// %%
emp = new Employee;
// Out:
// Employee { name: '', dept: 'general' }

// %%
sal = new SalesPerson
// Out:
// WorkerBee { name: '', dept: 'sales', projects: [], quota: 100 }

// %%
SalesPerson.prototype
// Out:
// WorkerBee { constructor: [Function: Engineer] }

// %%
sal2 = new SalesPerson;
// Out:
// WorkerBee { name: '', dept: 'sales', projects: [], quota: 100 }

// %%
sal2.dept
// Out:
// 'sales'

// %%
bis = new Object;
// Out:
// {}

// %%
bis
// Out:
// {}

// %%
bis.constructor
// Out:
// [Function: Object]

// %%
WorkerBee.prototype
// Out:
// Employee { constructor: [Function: WorkerBee] }

// %%
SalesPerson.constructor
// Out:
// [Function: Function]

// %%
SalesPerson.prototype
// Out:
// WorkerBee { constructor: [Function: Engineer] }

// %%
Employee.prototype.location = "Germany";
// Out:
// 'Germany'

// %%
e1
// Out:
// Employee { name: '', dept: 'general' }

// %%
e1 = new Employee;
// Out:
// Employee { name: '', dept: 'general' }

// %%
e1.location
// Out:
// 'Germany'

// %%
s1 = new SalesPerson();
// Out:
// WorkerBee { name: '', dept: 'sales', projects: [], quota: 100 }

// %%
s1.location
// Out:
// 'Germany'

// %%
SalesPerson.prototype
// Out:
// WorkerBee { constructor: [Function: Engineer] }

// %% [markdown]
// ##### If you add a new property to an object that is being used as the prototype for a constructor function, you add that property to all objects that inherit properties from the prototype. For example, you can add a specialty property to all employees with the following statement:
//
// Employee.prototype.specialty = 'none';

// %% [markdown]
// #### specify property values when you create an instance

// %%
function Employee (name, dept)
{
    this.name = name || "";
    this.dept = dept || "general";
}

// %%
e1 = new Employee("bishal")
// Out:
// Employee { name: 'bishal', dept: 'general' }

// %%
e1
// Out:
// Employee { name: 'bishal', dept: 'general' }

// %%
function Worker(){
    this.place = "goa";
}
Worker.prototype = new Employee;
//Worker.prototype.constructor = Worker;
// Out:
// Employee { name: '', dept: 'general' }

// %%
w1 = new Worker;
// Out:
// Employee { place: 'goa' }

// %%
w1.name
// Out:
// ''

// %%
w1.dept
// Out:
// 'general'

// %%
Worker.prototype.constructor
// Out:
// [Function: Employee]

// %%
Worker.prototype.constructor = Worker;
// Out:
// [Function: Worker]

// %%
function Engineer(name, projs, mach) {
  this.base = Worker;
  this.base(name, 'engineering', projs);
  this.machine = mach || '';
}
Engineer.prototype = new Worker
// Out:
// Worker { place: 'goa' }

// %%
var jane = new Engineer('Doe, Jane', ['navigator', 'javascript'], 'belau');

// %%
jane
// Out:
// Worker { base: [Function: Worker], place: 'goa', machine: 'belau' }

// %%
jane.__proto__
// Out:
// Worker { place: 'goa' }

// %%
jane.name
// Out:
// ''

// %% [raw]
// if you want to have default values for object properties and you want to be able to change the default values at run time, you should set the properties in the constructor's prototype, not in the constructor function itself.

// %%
jane.__proto__
// Out:
// Worker { place: 'goa' }

// %%
jane.__proto__.__proto__
// Out:
// Employee { name: '', dept: 'general', constructor: [Function: Worker] }

// %% [raw]
// person.age
// person.name.first
// Copy to Clipboard
// You can use
//
// person['age']
// person['name']['first']

// %%
let person = {
  name: ['Bob', 'Smith'],
  age: 32,
  bio() {
    console.log(`${this.name[0]} ${this.name[1]} is ${this.age} years old.`);
  },
  introduceSelf() {
    console.log(`Hi! I'm ${this.name[0]}.`);
  }
};

const myDataName = 'height';
const myDataValue = '1.75m';

person[myDataName] = myDataValue;
person
// Out:
// {
//   name: [ 'Bob', 'Smith' ],
//   age: 32,
//   bio: [Function: bio],
//   introduceSelf: [Function: introduceSelf],
//   height: '1.75m'
// }

// %%
person
// Out:
// {
//   name: [ 'Bob', 'Smith' ],
//   age: 32,
//   bio: [Function: bio],
//   introduceSelf: [Function: introduceSelf],
//   height: '1.75m'
// }

// %%
person.height
// Out:
// '1.75m'

// %%
var address = "Rüsselsheim";
person.address = address;
// Out:
// 'Rüsselsheim'

// %%
person
// Out:
// {
//   name: [ 'Bob', 'Smith' ],
//   age: 32,
//   bio: [Function: bio],
//   introduceSelf: [Function: introduceSelf],
//   height: '1.75m',
//   address: 'Rüsselsheim'
// }

// %% [markdown]
// ##### The this keyword refers to the current object the code is being written inside

// %% [markdown]
// #### object literals means dictionary

// %%
function createPerson(name) {
  const obj = {};
  obj.name = name;
  obj.introduceSelf = function() {
    console.log(`Hi! I'm ${this.name}.`);
  }
  return obj;
}

// %%
const salva = createPerson('Salva');
salva.name;
salva.introduceSelf();

const frankie = createPerson('Frankie');
frankie.name;
frankie.introduceSelf();
// Out:
// Hi! I'm Salva.
// Hi! I'm Frankie.

// %% [raw]
// This works fine but is a bit long-winded: we have to create an empty object, initialize it, and return it. A better way is to use a constructor. A constructor is just a function called using the new keyword. When you call a constructor, it will:
//
// create a new object
// bind this to the new object, so you can refer to this in your constructor code
// run the code in the constructor
// return the new object.

// %% [raw]
// Every object in JavaScript has a built-in property, which is called its prototype. The prototype is itself an object, so the prototype will have its own prototype, making what's called a prototype chain. The chain ends when we reach a prototype that has null for its own prototype.

// %%
function People()
{
    this.name = "person";
    this.age = 11;
}

function Professor()
{
    this.profession = "professor";
    this.salary = true;
}

// %%
Professor.prototype = Object.create(People.prototype)
// Out:
// People {}

// %%
Professor.prototype
// Out:
// People {}

// %%
Professor.prototype.constructor = Professor;
// Out:
// [Function: Professor]

// %%
p1 = new Professor;
p1
// Out:
// People { profession: 'professor', salary: true }

// %%
p1.name

// %%
p1.age

// %%
Object.__proto__(p1)

// %%
console.log(p1.name)
// Out:
// undefined

// %%
console.log(p1.name)
// Out:
// undefined

// %%
p1.__proto__
// Out:
// People { constructor: [Function: Professor] }

// %%
p1.name

// %%
let prf1 = new Professor;

// %%
prf1
// Out:
// People { profession: 'professor', salary: true }

// %%
prf1.__proto__
// Out:
// People {}

// %%
prf1.name

// %%
function People()
{
    this.name = "person";
    this.age = 11;
}

function Professor()
{
    this.profession = "professor";
    this.salary = true;
}
Professor.prototype = Object.create(People.prototype);
Professor.prototype.constructor
// Out:
// [Function: People]

// %%
let p1 = new Professor()

// %%
p1
// Out:
// People { profession: 'professor', salary: true }

// %%
p1.name

// %%
let p01 = new People;

// %%
p01
// Out:
// People { name: 'person', age: 11 }

// %%
p2 = new Professor;
// Out:
// People { profession: 'professor', salary: true }

// %%
p2.age

// %%
Professor.prototype
// Out:
// People {}

// %%
Professor.prototype.hasOwnProperty("age")
// Out:
// false

// %%
Professor.prototype = new People;
// Out:
// People { name: 'person', age: 11 }

// %%
p2
// Out:
// People { profession: 'professor', salary: true }

// %%
p2.name

// %%
p2.__proto__
// Out:
// People {}

// %%
p2
// Out:
// People { profession: 'professor', salary: true }

// %%
function Building()
{
    this.area = 1500;
    this.builder = "Apple";
}

// %%
function Hospital()
{
    this.service = "help"
}

//Hospital.prototype = Object.create(Building)

// %%
h1 = new Hospital();
// Out:
// Function { service: 'help' }

// %%
h1.service
// Out:
// 'help'

// %%
h1.area

// %%
Hospital.prototype = new Building;
// Out:
// Building { area: 1500, builder: 'Apple' }

// %%
h2 = new Hospital()
// Out:
// Building { service: 'help' }

// %%
h2.area
// Out:
// 1500

// %%
Building.__proto__
// Out:
// {}

// %%
Building.constructor
// Out:
// [Function: Function]

// %%
Building.prototype
// Out:
// {}

// %%
Hospital.prototype
// Out:
// {}

// %%
Hospital.prototype = new Building()
// Out:
// Building { area: 1500, builder: 'Apple' }

// %%
h2 = new Hospital()
// Out:
// Building { service: 'help' }

// %%
h2.area
// Out:
// 1500

// %%
function RedCross()
{
    this.helper = true;
    this.donation = true;
}

// %%
RedCross.prototype
// Out:
// {}

// %%
RedCross.prototype = Object.create(Hospital.prototype)
// Out:
// Building {}

// %%
r2 = new RedCross
// Out:
// Building { helper: true, donation: true }

// %%
r2.area
// Out:
// 1500

// %%
r2.services

// %%
r2.builder
// Out:
// 'Apple'

// %%
function Building()
{
    this.area = 1500;
    this.builder = "Apple";
}

function Hospital()
{
    this.service = "help"
}

// %%
Hospital.prototype = Object.create(Building.prototype)
Hospital.prototype.constructor = Hospital;
// Out:
// [Function: Hospital]

// %%
h1  = new Hospital;
// Out:
// Hospital { service: 'help' }

// %%
h1.area

// %%
function Employee() {
    this.name = '';
    this.dept = 'general';
}

// %%
function Manager() {
  Employee.call(this);
  this.reports = [];
}
Manager.prototype = Object.create(Employee.prototype);
Manager.prototype.constructor = Manager;

function WorkerBee() {
  Employee.call(this);
  this.projects = [];
}
WorkerBee.prototype = Object.create(Employee.prototype);
WorkerBee.prototype.constructor = WorkerBee;
// Out:
// [Function: WorkerBee]

// %%
function SalesPerson() {
   WorkerBee.call(this);
   this.dept = 'sales';
   this.quota = 100;
}
SalesPerson.prototype = Object.create(WorkerBee.prototype);
SalesPerson.prototype.constructor = SalesPerson;

function Engineer() {
   WorkerBee.call(this);
   this.dept = 'engineering';
   this.machine = '';
}
Engineer.prototype = Object.create(WorkerBee.prototype)
Engineer.prototype.constructor = Engineer;
// Out:
// [Function: Engineer]

// %%
var jim = new Employee;
// Parentheses can be omitted if the
// constructor takes no arguments.
// jim.name is ''
// jim.dept is 'general'

var sally = new Manager;
// sally.name is ''
// sally.dept is 'general'
// sally.reports is []

var mark = new WorkerBee;
// mark.name is ''
// mark.dept is 'general'
// mark.projects is []

var fred = new SalesPerson;
// fred.name is ''
// fred.dept is 'sales'
// fred.projects is []
// fred.quota is 100

var jane = new Engineer;
// jane.name is ''
// jane.dept is 'engineering'
// jane.projects is []
// jane.machine is ''

// %%
sally.name
// Out:
// ''

// %%
function Animal()
{
this.friendly = true;
}

// %%
function Dog()
{
this.name = "steves"
this.speaks = "barks"
}

// %%
Animal.prototype
// Out:
// {}

// %%
Dog.prototype = new Animal;
// Out:
// Animal { friendly: true }

// %%
Dog.prototype.constructor
// Out:
// [Function: Animal]

// %%
Dog.prototype.constructor = Dog;
// Out:
// [Function: Dog]

// %%
Dog.prototype.constructor
// Out:
// [Function: Dog]

// %%
d1 = new Dog;
// Out:
// Dog { name: 'steves', speaks: 'barks' }

// %%
d1.name
// Out:
// 'steves'

// %%
d1.friendly
// Out:
// true

// %% [markdown]
// ##### We have to be careful when initializing the prototype. Using childFunction.protoype = new Parent works and all the properties are available to the inherited object. Using child.prototype = Object.create(Parent.prototype) only works if you use Parent.call(this) inside the child function.

// %%
function Language()
{
    this.name = "empty lanugage"
}

function Deutsch()
{
    this.name = "Deutsch"
    this.difficulty = "medium"
}

Deutsch.prototype = new Language;
Deutsch.prototype.constructor = Deutsch;
// Out:
// [Function: Deutsch]

// %%
d1 = new Deutsch()
// Out:
// Deutsch { name: 'Deutsch', difficulty: 'medium' }

// %%
Deutsch.prototype.name
// Out:
// 'empty lanugage'

// %%
Deutsch.name
// Out:
// 'Deutsch'

// %%
class Person {

  name;

  constructor(name) {
    this.name = name;
  }

  introduceSelf() {
    console.log(`Hi! I'm ${this.name}`);
  }

}

// %%
const giles = new Person('Giles');

giles.introduceSelf(); // Hi! I'm Giles
// Out:
// Hi! I'm Giles

// %% [markdown]
// #### What happens in constructor
// create a new object.
// bind this to the new object, so you can refer to this in your constructor code.
// run the code in the constructor.
// return the new object.

// %% [raw]
// If you don't need to do any special initialization, you can omit the constructor, and a default constructor will be generated for you:

// %%
class Professor extends Person {

  teaches;

  constructor(name, teaches) {
    super(name);
    this.teaches = teaches;
  }

  introduceSelf() {
    console.log(`My name is ${this.name}, and I will be your ${this.teaches} professor.`);
  }

  grade(paper) {
    const grade = Math.floor(Math.random() * (5 - 1) + 1);
    console.log(grade);
  }

}

// %%
const walsh = new Professor('Walsh', 'Psychology');
walsh.introduceSelf();  // 'My name is Walsh, and I will be your Psychology professor'

walsh.grade('my paper'); // some random grade
// Out:
// My name is Walsh, and I will be your Psychology professor.
// 2

// %%
class Student extends Person {

  #year;

  constructor(name, year) {
    super(name);
    this.#year = year;
  }


  introduceSelf() {
    console.log(`Hi! I'm ${this.name}, and I'm in year ${this.#year}.`);
  }

  canStudyArchery() {
    return this.#year > 1;
  }

}

// %% [raw]
// You can have private methods as well as private data properties. Just like private data properties, their names start with #, and they can only be called by the object's own methods:

// %%
class Example {

  somePublicMethod() {
    this.#somePrivateMethod();
  }

  #somePrivateMethod() {
    console.log('You called me?');
  }

}

const myExample = new Example();

myExample.somePublicMethod(); // 'You called me?'

myExample.#somePrivateMethod(); // SyntaxError
// Out:
// evalmachine.<anonymous>:17
// myExample.#somePrivateMethod(); // SyntaxError
//          ^
//
// SyntaxError: Private field '#somePrivateMethod' must be declared in an enclosing class
//     at new Script (node:vm:100:7)
//     at createScript (node:vm:257:10)
//     at Object.runInThisContext (node:vm:305:10)
//     at run ([eval]:1054:15)
//     at onRunRequest ([eval]:888:18)
//     at onMessage ([eval]:848:13)
//     at process.emit (node:events:520:28)
//     at emit (node:internal/child_process:936:14)
//     at processTicksAndRejections (node:internal/process/task_queues:84:21)

// %%
class Shape {

  name;
  sides;
  sideLength;

constructor(name, sides, sideLength){
this.name = name || "";
this.sides = sides || "";
this.sideLength = sideLength || "";
}
 calcPerimeter() {
console.log(this.sides * this.sideLength);}

}

    

    class Square extends Shape 
    {
        constructor(sideLength)
        {
            super("square", 4, sideLength);
        }
        calcArea()
        {
            console.log(`Area : ${this.sideLength * this.sideLength}`);
        }

}

// %%
sq1 = new Square(5);
sq1.calcPerimeter();
// Out:
// 20

// %%
sq1.calcArea();
// Out:
// Area : 25
