# %%
nltk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_1613/3505366908.py in <module>
# ----> 1 nltk
#
# NameError: name 'nltk' is not defined

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.9/site-packages (3.6.5)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.9/site-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.9/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.9/site-packages (from nltk) (2021.11.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.9/site-packages (from nltk) (4.62.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
example_string = """
Muad'Dib learned rapidly because his first training was in how to learn.
And the first lesson of all was the basic trust that he could learn.
It's shocking to find how many people do not believe they can learn,
and how many more believe learning to be difficult."""

# %%
sent_tokenize(example_string)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_1624/4000217569.py in <module>
# ----> 1 sent_tokenize(example_string)
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#     108
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     748
#     749     # Load the resource.
# --> 750     opened_resource = _open(resource_url)
#     751
#     752     if format == "raw":
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in _open(resource_url)
#     874
#     875     if protocol is None or protocol.lower() == "nltk":
# --> 876         return find(path_, path + [""]).open()
#     877     elif protocol.lower() == "file":
#     878         # urllib might not use mode='rb', so handle this one ourselves:
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/Users/bisalgt/nltk_data'
#     - '/opt/anaconda3/nltk_data'
#     - '/opt/anaconda3/share/nltk_data'
#     - '/opt/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /Users/bisalgt/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sent_tokenize(example_string)
# Out:
# ["\nMuad'Dib learned rapidly because his first training was in how to learn.",
#  'And the first lesson of all was the basic trust that he could learn.',
#  "It's shocking to find how many people do not believe they can learn,\nand how many more believe learning to be difficult."]

# %%
word_tokenize(example_string)
# Out:
# ["Muad'Dib",
#  'learned',
#  'rapidly',
#  'because',
#  'his',
#  'first',
#  'training',
#  'was',
#  'in',
#  'how',
#  'to',
#  'learn',
#  '.',
#  'And',
#  'the',
#  'first',
#  'lesson',
#  'of',
#  'all',
#  'was',
#  'the',
#  'basic',
#  'trust',
#  'that',
#  'he',
#  'could',
#  'learn',
#  '.',
#  'It',
#  "'s",
#  'shocking',
#  'to',
#  'find',
#  'how',
#  'many',
#  'people',
#  'do',
#  'not',
#  'believe',
#  'they',
#  'can',
#  'learn',
#  ',',
#  'and',
#  'how',
#  'many',
#  'more',
#  'believe',
#  'learning',
#  'to',
#  'be',
#  'difficult',
#  '.']

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/bisalgt/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

tokenized_words = word_tokenize(example_string)

# %%
tokenized_words
# Out:
# ["Muad'Dib",
#  'learned',
#  'rapidly',
#  'because',
#  'his',
#  'first',
#  'training',
#  'was',
#  'in',
#  'how',
#  'to',
#  'learn',
#  '.',
#  'And',
#  'the',
#  'first',
#  'lesson',
#  'of',
#  'all',
#  'was',
#  'the',
#  'basic',
#  'trust',
#  'that',
#  'he',
#  'could',
#  'learn',
#  '.',
#  'It',
#  "'s",
#  'shocking',
#  'to',
#  'find',
#  'how',
#  'many',
#  'people',
#  'do',
#  'not',
#  'believe',
#  'they',
#  'can',
#  'learn',
#  ',',
#  'and',
#  'how',
#  'many',
#  'more',
#  'believe',
#  'learning',
#  'to',
#  'be',
#  'difficult',
#  '.']

# %%
stop_words = set(stopwords.words("english"))

# %%
filtered_list = []

# %%
for word in tokenized_words:
    if word.casefold() not in stop_words:
        filtered_list.append(word)

# %%
filtered_list
# Out:
# ["Muad'Dib",
#  'learned',
#  'rapidly',
#  'first',
#  'training',
#  'learn',
#  '.',
#  'first',
#  'lesson',
#  'basic',
#  'trust',
#  'could',
#  'learn',
#  '.',
#  "'s",
#  'shocking',
#  'find',
#  'many',
#  'people',
#  'believe',
#  'learn',
#  ',',
#  'many',
#  'believe',
#  'learning',
#  'difficult',
#  '.']

# %%
[word for word in tokenized_words if word.casefold() not in stop_words]
# Out:
# ["Muad'Dib",
#  'learned',
#  'rapidly',
#  'first',
#  'training',
#  'learn',
#  '.',
#  'first',
#  'lesson',
#  'basic',
#  'trust',
#  'could',
#  'learn',
#  '.',
#  "'s",
#  'shocking',
#  'find',
#  'many',
#  'people',
#  'believe',
#  'learn',
#  ',',
#  'many',
#  'believe',
#  'learning',
#  'difficult',
#  '.']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
stemmer = PorterStemmer()

# %%
string_for_stemming = """
The crew of the USS Discovery discovered many discoveries.
Discovering is what explorers do."""

# %%
words = word_tokenize(string_for_stemming)

# %%
[stemmer.stem(word) for word in words]
# Out:
# ['the',
#  'crew',
#  'of',
#  'the',
#  'uss',
#  'discoveri',
#  'discov',
#  'mani',
#  'discoveri',
#  '.',
#  'discov',
#  'is',
#  'what',
#  'explor',
#  'do',
#  '.']

# %%
sagan_quote = """
If you wish to make an apple pie from scratch,
you must first invent the universe."""

# %%
words_in_quote = word_tokenize(sagan_quote)

# %%
nltk.pos_tag(words_in_quote)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_1624/4004775773.py in <module>
# ----> 1 nltk.pos_tag(words_in_quote)
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     163     :rtype: list(tuple(str, str))
#     164     """
# --> 165     tagger = _get_tagger(lang)
#     166     return _pos_tag(tokens, tagset, tagger, lang)
#     167
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/tag/__init__.py in _get_tagger(lang)
#     105         tagger.load(ap_russian_model_loc)
#     106     else:
# --> 107         tagger = PerceptronTagger()
#     108     return tagger
#     109
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/tag/perceptron.py in __init__(self, load)
#     165         if load:
#     166             AP_MODEL_LOC = "file:" + str(
# --> 167                 find("taggers/averaged_perceptron_tagger/" + PICKLE)
#     168             )
#     169             self.load(AP_MODEL_LOC)
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource averaged_perceptron_tagger not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('averaged_perceptron_tagger')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load taggers/averaged_perceptron_tagger/averaged_perceptron_tagger.pickle
#
#   Searched in:
#     - '/Users/bisalgt/nltk_data'
#     - '/opt/anaconda3/nltk_data'
#     - '/opt/anaconda3/share/nltk_data'
#     - '/opt/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/bisalgt/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
nltk.pos_tag(words_in_quote)
# Out:
# [('If', 'IN'),
#  ('you', 'PRP'),
#  ('wish', 'VBP'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('an', 'DT'),
#  ('apple', 'NN'),
#  ('pie', 'NN'),
#  ('from', 'IN'),
#  ('scratch', 'NN'),
#  (',', ','),
#  ('you', 'PRP'),
#  ('must', 'MD'),
#  ('first', 'VB'),
#  ('invent', 'VB'),
#  ('the', 'DT'),
#  ('universe', 'NN'),
#  ('.', '.')]

# %%
nltk.help.upenn_tagset()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_1624/2029812029.py in <module>
# ----> 1 nltk.help.upenn_tagset()
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/help.py in upenn_tagset(tagpattern)
#      25
#      26 def upenn_tagset(tagpattern=None):
# ---> 27     _format_tagset("upenn_tagset", tagpattern)
#      28
#      29
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/help.py in _format_tagset(tagset, tagpattern)
#      44
#      45 def _format_tagset(tagset, tagpattern=None):
# ---> 46     tagdict = load("help/tagsets/" + tagset + ".pickle")
#      47     if not tagpattern:
#      48         _print_entries(sorted(tagdict), tagdict)
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     748
#     749     # Load the resource.
# --> 750     opened_resource = _open(resource_url)
#     751
#     752     if format == "raw":
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in _open(resource_url)
#     874
#     875     if protocol is None or protocol.lower() == "nltk":
# --> 876         return find(path_, path + [""]).open()
#     877     elif protocol.lower() == "file":
#     878         # urllib might not use mode='rb', so handle this one ourselves:
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource tagsets not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('tagsets')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load help/tagsets/PY3/upenn_tagset.pickle
#
#   Searched in:
#     - '/Users/bisalgt/nltk_data'
#     - '/opt/anaconda3/nltk_data'
#     - '/opt/anaconda3/share/nltk_data'
#     - '/opt/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %%
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package tagsets to /Users/bisalgt/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# True

# %% [raw]
# nltk.help.upenn_tagset()

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
words
# Out:
# ['The',
#  'crew',
#  'of',
#  'the',
#  'USS',
#  'Discovery',
#  'discovered',
#  'many',
#  'discoveries',
#  '.',
#  'Discovering',
#  'is',
#  'what',
#  'explorers',
#  'do',
#  '.']

# %%
[lemmatizer.lemmatize(word) for word in words]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/nltk/corpus/util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - '/Users/bisalgt/nltk_data'
#     - '/opt/anaconda3/nltk_data'
#     - '/opt/anaconda3/share/nltk_data'
#     - '/opt/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_1624/3056013709.py in <module>
# ----> 1 [lemmatizer.lemmatize(word) for word in words]
#
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_1624/3056013709.py in <listcomp>(.0)
# ----> 1 [lemmatizer.lemmatize(word) for word in words]
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/stem/wordnet.py in lemmatize(self, word, pos)
#      43         :return: The lemma of `word`, for the given `pos`.
#      44         """
# ---> 45         lemmas = wn._morphy(word, pos)
#      46         return min(lemmas, key=len) if lemmas else word
#      47
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/corpus/util.py in __getattr__(self, attr)
#     119             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     120
# --> 121         self.__load()
#     122         # This looks circular, but its not, since __load() changes our
#     123         # __class__ to something new:
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/corpus/util.py in __load(self)
#      84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
# ---> 86                     raise e
#      87
#      88         # Load the corpus.
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/corpus/util.py in __load(self)
#      79         else:
#      80             try:
# ---> 81                 root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82             except LookupError as e:
#      83                 try:
#
# /opt/anaconda3/lib/python3.9/site-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - '/Users/bisalgt/nltk_data'
#     - '/opt/anaconda3/nltk_data'
#     - '/opt/anaconda3/share/nltk_data'
#     - '/opt/anaconda3/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/bisalgt/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
[lemmatizer.lemmatize(word) for word in words]
# Out:
# ['The',
#  'crew',
#  'of',
#  'the',
#  'USS',
#  'Discovery',
#  'discovered',
#  'many',
#  'discovery',
#  '.',
#  'Discovering',
#  'is',
#  'what',
#  'explorer',
#  'do',
#  '.']

# %%
tokenized_words_tags = nltk.pos_tag(tokenized_words)

# %%
tokenized_words_tags
# Out:
# [("Muad'Dib", 'NNP'),
#  ('learned', 'VBD'),
#  ('rapidly', 'RB'),
#  ('because', 'IN'),
#  ('his', 'PRP$'),
#  ('first', 'JJ'),
#  ('training', 'NN'),
#  ('was', 'VBD'),
#  ('in', 'IN'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('learn', 'VB'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('lesson', 'NN'),
#  ('of', 'IN'),
#  ('all', 'DT'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('basic', 'JJ'),
#  ('trust', 'NN'),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('could', 'MD'),
#  ('learn', 'VB'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('shocking', 'VBG'),
#  ('to', 'TO'),
#  ('find', 'VB'),
#  ('how', 'WRB'),
#  ('many', 'JJ'),
#  ('people', 'NNS'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('believe', 'VB'),
#  ('they', 'PRP'),
#  ('can', 'MD'),
#  ('learn', 'VB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('how', 'WRB'),
#  ('many', 'JJ'),
#  ('more', 'JJR'),
#  ('believe', 'NNS'),
#  ('learning', 'VBG'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('difficult', 'JJ'),
#  ('.', '.')]

# %%
grammar = "NP: {<DT>?<JJ>*<NN>}"

# %%
chunk_parser = nltk.RegexpParser(grammar)

# %%
tree = chunk_parser.parse(tokenized_words_tags)

# %%
tree.draw()

# %%
# %matplotlib inline

# %%
tree.draw()
