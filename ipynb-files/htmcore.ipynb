# %%
import htm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_2318/1105234039.py in <module>
# ----> 1 import htm
#
# ModuleNotFoundError: No module named 'htm'

# %%
pwd
# Out:
# '/Users/bisalgt/Projects/playground/ipynb-files'

# %%
ls
# Out:
# async learn py.ipynb  learn js 2.ipynb      think py 2.ipynb
# htmcore.ipynb         learn js.ipynb        think py.ipynb
# learn async js.ipynb  learn-opencv.ipynb

# %%
cd ..
# Out:
# /Users/bisalgt/Projects/playground

# %%
ls
# Out:
# flask-videstreamer/ ipynb-files/        oldprojects/
# images/             js/

# %%
ls
# Out:
# flask-videstreamer/ images/             js/
# htmcore/            ipynb-files/        oldprojects/

# %%
cd htmcore/
# Out:
# /Users/bisalgt/Projects/playground/htmcore

# %%
ls
# Out:
# htm.core/

# %%
ls htm.core/
# Out:
# API_CHANGELOG.md            appveyor.yml
# API_DIFFERENCES.md          bindings/
# CHANGELOG.md                ci/
# CMakeLists.txt              docs/
# CONTRIBUTING.md             external/
# CommonCompilerConfig.cmake  githooks/
# DEPENDENCIES.md             py/
# DEVELOPER_NOTES.md          requirements.txt
# Dockerfile                  setup.cfg
# Dockerfile-pypi             setup.py
# LICENSE.txt                 src/
# README.md                   startupMSVC.bat
# RELEASE.md                  versioning.cmake
# VERSION

# %%
cd htm.core/
# Out:
# /Users/bisalgt/Projects/playground/htmcore/htm.core

# %%
ls
# Out:
# API_CHANGELOG.md            appveyor.yml
# API_DIFFERENCES.md          bindings/
# CHANGELOG.md                ci/
# CMakeLists.txt              docs/
# CONTRIBUTING.md             external/
# CommonCompilerConfig.cmake  githooks/
# DEPENDENCIES.md             py/
# DEVELOPER_NOTES.md          requirements.txt
# Dockerfile                  setup.cfg
# Dockerfile-pypi             setup.py
# LICENSE.txt                 src/
# README.md                   startupMSVC.bat
# RELEASE.md                  versioning.cmake
# VERSION

# %%
ls py/
# Out:
# htm/   tests/

# %%
pwd
# Out:
# '/Users/bisalgt/Projects/playground/ipynb-files'

# %%
ls
# Out:
# async learn py.ipynb         learn nltk.ipynb
# htmcore.ipynb                learn shell scripting.ipynb
# learn async js.ipynb         learn-opencv.ipynb
# learn js 2.ipynb             think py 2.ipynb
# learn js.ipynb               think py.ipynb

# %%
cd ::
# Out:
# [Errno 2] No such file or directory: '::'
# /Users/bisalgt/Projects/playground/ipynb-files

# %%
cd ..
# Out:
# /Users/bisalgt/Projects/playground

# %%
ls
# Out:
# README.md           htmcore/            ipynb-files/        oldprojects/
# flask-videstreamer/ images/             js/

# %%
cd htmcore/
# Out:
# /Users/bisalgt/Projects/playground/htmcore

# %%
ls
# Out:
# htm.core/

# %%
cd htm.core/
# Out:
# /Users/bisalgt/Projects/playground/htmcore/htm.core

# %%
ls
# Out:
# API_CHANGELOG.md            appveyor.yml
# API_DIFFERENCES.md          bindings/
# CHANGELOG.md                ci/
# CMakeLists.txt              docs/
# CONTRIBUTING.md             external/
# CommonCompilerConfig.cmake  githooks/
# DEPENDENCIES.md             py/
# DEVELOPER_NOTES.md          requirements.txt
# Dockerfile                  setup.cfg
# Dockerfile-pypi             setup.py
# LICENSE.txt                 src/
# README.md                   startupMSVC.bat
# RELEASE.md                  versioning.cmake
# VERSION

# %%
ls py/
# Out:
# htm/   tests/

# %%
# !python py/htm/encoders/scalar_encoder.py
# Out:
# Traceback (most recent call last):
#   File "/Users/bisalgt/Projects/playground/htmcore/htm.core/py/htm/encoders/scalar_encoder.py", line 16, in <module>
#     import htm.bindings.encoders
# ModuleNotFoundError: No module named 'htm'
