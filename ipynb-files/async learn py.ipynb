# %%
# !which python
# Out:
# /opt/anaconda3/bin/python

# %%
import asyncio

# %%
async def main():
    print("hello")
    await asyncio.sleep(1)
    print("async world")

# %%
asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_2253/149163935.py in <module>
# ----> 1 asyncio.run(main())
#
# /opt/anaconda3/lib/python3.9/asyncio/runners.py in run(main, debug)
#      31     """
#      32     if events._get_running_loop() is not None:
# ---> 33         raise RuntimeError(
#      34             "asyncio.run() cannot be called from a running event loop")
#      35
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
main()
# Out:
# <coroutine object main at 0x7fcb73756940>

# %%
await main()
# Out:
# hello
# async world

# %%
import time

# %%
async def say_after(delay, what):
    await asyncio.sleep(delay)
    print(what)

# %%
async def main():
    task1 = asyncio.create_task(say_after(1, "Hey"))
    task2 = asyncio.create_task(say_after(2, "how are you"))
    print(f"started at {time.strftime('%X')}")
    await task1
    await task2
    print(f"finished at {time.strftime('%X')}")

await main()
# Out:
# started at 22:57:45
# Hey
# how are you
# finished at 22:57:47

# %%
async def nested():
    return 42

async def main():

    nested()

    print(await nested())  

await main()
nested()
# Out:
# 42
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_2253/2401859926.py:6: RuntimeWarning: coroutine 'nested' was never awaited
#   nested()
# ...
# <coroutine object nested at 0x7fcb73c3d0c0>

# %% [raw]
# when a future is occured, corutine will wait for the future to complete or if exceptions is occured. Then only the corutine is handeled.

# %%
async def main():
    await asyncio.sleep(1)
    print("test it")
await main()
# Out:
# test it

# %%
task = asyncio.create_task(say_after(2, "how are you"))
asyncio.get_running_loop()
# Out:
# <_UnixSelectorEventLoop running=True closed=False debug=False>
# how are you

# %% [raw]
# Wrap the coroutine into a Task and schedule its execution
