# %% [markdown]
# ## Project to view webcam using opencv python

# %%
pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 46.0 MB 9.2 MB/s eta 0:00:011
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 as cv
import sys

# %%
pwd
# Out:
# '/Users/bisalgt/Projects/playground'

# %%
ls
# Out:
# Categorical Plots.ipynb*
# DataFrames 1.ipynb*
# DataFrames 2.ipynb*
# DataFrames 3.ipynb*
# Learn OpenCV.ipynb
# acmicpc team problem hrank.ipynb
# argparser_for_cli.py
# asyncp1.py
# check multiprocess & multithread.ipynb
# checker add dots of project capitalize.ipynb
# choclate feast hrk.ipynb
# clean_csv_to_db.ipynb
# cleaner and profanity for csv.ipynb
# concurrent_exec_asyncio.py
# corey pandas 1,2,3,4.ipynb
# corey-multi threading.ipynb
# coroutines.ipynb
# coroutines.py
# datas/
# file.pkl
# fluenpydict.ipynb
# fluentpthond1.ipynb
# fpy0.ipynb
# fpy1.ipynb
# fpyj1.ipynb
# func1.py
# func2.py
# graph1scatterplt.png
# hell.csv
# hello.py*
# hello.sh*
# hrank 2 person team.ipynb
# hrank encryption.ipynb
# hrank not divisible subset.ipynb
# hrank-cut the stick.ipynb
# hrank.ipynb
# hrankTaum and bday.ipynb
# hrk- minimum distance.ipynb
# insert_options_and_randomize_clean_csv_to_db.ipynb
# intermediatepy.ipynb
# interview challge.ipynb
# j1.ipynb
# j2prac.ipynb
# js/
# ...

# %%
ls *.png
# Out:
# graph1scatterplt.png

# %%
pwd
# Out:
# '/Users/bisalgt/Projects/playground'

# %%
cp /Users/bisalgt/Downloads/Yin_and_Yang_symbol.svg .

# %%
mv Yin_and_Yang_symbol.svg YingandYang.svg

# %%
mv YingandYang.svg yingandyand.png

# %%
ls *.png
# Out:
# graph1scatterplt.png  yingandyand.png

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_3834/172339134.py in <module>
#       3 img = cv.imread(cv.samples.findFile("YingandYang.svg"))
#       4 if img is None:
# ----> 5     sys.exit("Could not read the image.")
#       6 cv.imshow("Display window", img)
#       7 k = cv.waitKey(0)
#
# SystemExit: Could not read the image.

# %%
cp /Users/bisalgt/Desktop/overflowerror.png .

# %%
import cv2 as cv
import sys
img = cv.imread(cv.samples.findFile("overflowerror.png"))
if img is None:
    sys.exit("Could not read the image.")
cv.imshow("Display window", img)
cv.waitKey(0)
cv.destroyAllWindows()
cv.waitKey(1)
# Out:
# -1

# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: MacOSX

# %%
import cv2 as cv
import sys
img = cv.imread(cv.samples.findFile("overflowerror.png"))
if img is None:
    sys.exit("Could not read the image.")
cv.imshow("Display window", img)
cv.waitKey(0)
cv.destroyAllWindows()
# cv.waitKey(1)
