# %%
dict_word = {
    1: 'one',
    2: 'two',
    3: 'three',
    4: 'four',
    5: 'five',
    6: 'six', 
    7: 'seven',
    8: 'eight',
    9: 'nine',
    10: 'ten',
    11: 'eleven',
    12: 'twelve',
    13: 'thirteen',
    14: 'fourteen',
    15: 'fifteen',
    16: 'sixteen',
    17: 'seventeen',
    18: 'eighteen',
    19: 'nineteen',
    20: 'twenty',
    30: 'thirty',
    40: 'fourty',
    50: 'fifty'

}
def find_word(h, m):
    pass

# Complete the timeInWords function below.
def timeInWords(h, m):
    if m == 0:
        h = dict_word[h]
        return f"{h} o' clock"
    if m ==30:
        h = dict_word[h]
        return f"half past {h}"
    if m == 15:
        h = dict_word[h]
        return f"quarter past {h}"
    if m == 45:
        h = dict_word[h+1]
        return f"quarter to {h}"
    if m < 30:
        if m <=20:
            
            h = dict_word[h]
            if m < 2:
                m = dict_word[m]
                return f"{m} minute past {h}"
            m = dict_word[m]
            return f"{m} minutes past {h}"
        else:
            w = m%10
            m = dict_word[20]
            h = dict_word[h]
            w = dict_word[w]
            return f"{m} {w} minutes past {h}"
    if m > 30:
        m = 60-m
        h = dict_word[h+1]
        print(type(m), m)
        if m < 2:
            m = dict_word[m]
            return f"{m} minute to {h}"
        if m <= 20:
            m = dict_word[m]
            return f"{m} minutes to {h}"
        w1 = dict_word[20]
        w2 = dict_word[(m%10)]
        return f"{w1} {w2} minutes to {h}"
timeInWords(6,35)
# Out:
# <class 'int'> 25
# 'twenty five minutes to seven'
