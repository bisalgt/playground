# %%
ls
# Out:
# 'cleaner and profanity for csv.ipynb'   mongodb.ipynb
#  datas/                                'randomize columns.ipynb'
#  hrank.ipynb

# %%
ls datas/
# Out:
# class11datacollection.csv   cleaned_class11datacollection.csv
# Class11DataCollection.xlsx

# %%
import pandas as pd

file_name = 'datas/Class11DataCollection.xlsx'
df = pd.read_excel(file_name, sheet_name=None)
df['Biology']
# Out:
#      S.N.                                           Question  \
# 0       1  They are the remains or impressions of living ...
# 1       2  It is the study of fossils and their relations...
# 2       3  Man has been able to produce food in greater q...
# 3       4                          Taxonomy is the study of:
# 4       5                   Anatomy deals with the study of:
# ..    ...                                                ...
# 194   195  At the end of the electron transport chain dur...
# 195   196             During growth fibers elongate greatly:
# 196   197  Which of these is the naturally occurring auxins?
# 197   198          The application of auxin in small amount:
# 198   199  Which of these increases the growth rate of is...
#
#                                               Option A  \
# 0                                              Tissues
# 1                                           Embryology
# 2                                          Mathematics
# ...

# %%
df.keys()
# Out:
# dict_keys(['Physics', 'Chemistry', 'Biology', 'Account', 'Business Studies', 'Finance', 'Sociology', 'Math', 'Economics', 'English'])

# %%
df['Finance']
# Out:
#      S.N.                                           Question  \
# 0       1  The financial market where debt and stocks are...
# 1       2  The type of market in which securities with le...
# 2       3  The markets in which new securities are issued...
# 3       4  Which types of preference shares can be conver...
# 4       5  Bonds which are sold at very high discount and...
# ..    ...                                                ...
# 180   181  Centralized market place where agents can hace...
# 181   182  Treasury bonds and notes pay interest rate is ...
# 182   183  As compared to treasury bonds trading of munic...
# 183   184  Stocks or shares that are sold to investors wi...
# 184   185  Bonds that are backed by cash flow from projec...
#
#                     Option A                        Option B  \
# 0         Short term markets                 Capital markets
# 1               Money market                  Capital market
# ...
