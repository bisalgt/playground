# %%
'abcd'.translate('a'.maketrans('abc', 'bcd'))
# Out:
# 'bcdd'

# %%
x = -122

# %%
print("-%006d"%x)
# Out:
# --00122

# %%
a = {'b': 1}

# %%
del a

# %%
l1 = [1,2,3]

# %%
l2 = [1,2,3]

# %%
l1 is l2
# Out:
# False

# %%
'b' in a
# Out:
# True

# %%
s = {'ab', 'c ', 'd'}

# %%
'c' in s
# Out:
# False

# %%
''.isdigit()
# Out:
# False

# %%
2+4.00
# Out:
# 6.0

# %%
s1 = 'abc'
s2 = 'bcd'


s1.__add__(s2)
# Out:
# 'abcbcd'

# %%
s1*s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-d53a7f1503a6> in <module>
# ----> 1 s1*s2
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
s2 in s1
# Out:
# False

# %%
s1.__contains__(s2)
# Out:
# False

# %%
z = set('abc')

# %%
z.add('san')

# %%
z
# Out:
# {'a', 'b', 'c', 'san'}

# %%
z.update(set(['p', 'q']))

# %%
z
# Out:
# {'a', 'b', 'c', 'p', 'q', 'san'}

# %%
round(0.5)-round(-0.5)
# Out:
# 0

# %%
z.update([1, 2])

# %%
z
# Out:
# {1, 2, 'a', 'b', 'c', 'p', 'q', 'san'}

# %%
~101
# Out:
# -102

# %%
z.add(2)

# %%
z
# Out:
# {1, 2, 'a', 'b', 'c', 'p', 'q', 'san'}

# %%
z.add(4)

# %%
z
# Out:
# {1, 2, 4, 'a', 'b', 'c', 'p', 'q', 'san'}

# %%
t1= (1,2,3,4)
t2 = (1,2,4,3)

# %%
t1 < t2
# Out:
# True

# %%
float('10')
# Out:
# 10.0

# %%
int('10.4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-820d0c1a69ff> in <module>
# ----> 1 int('10.4')
#
# ValueError: invalid literal for int() with base 10: '10.4'

# %%
float('-infinity')
# Out:
# -inf

# %%
float('inf')
# Out:
# inf

# %%
z
# Out:
# {1, 2, 4, 'a', 'b', 'c', 'p', 'q', 'san'}

# %%
z.copy()
# Out:
# {1, 2, 4, 'a', 'b', 'c', 'p', 'q', 'san'}

# %%
l1*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
sum((1,2,3), 4)
# Out:
# 10

# %%
print('new' 'line')
# Out:
# newline

# %%
x = 456

# %%
print("%-006d"%x)
# Out:
# 456

# %%
'abcacefa'.split('a', 2)
# Out:
# ['', 'bc', 'cefa']

# %%
d = {'a':1, 'b':3}

# %%
d.pop('b')
# Out:
# 3

# %%
d.pop('a')
# Out:
# 1

# %%
x = 3

# %%
eval('x^2')
# Out:
# 1

# %%
a = [[]]*3

# %%
a
# Out:
# [[], [], []]

# %%
a = 1,2,3

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
'abc'.encode()
# Out:
# b'abc'

# %%
a = 40
b = 30

# %%
a = a^b

# %%
b = a^b

# %%
a = a^b

# %%
a, b
# Out:
# (30, 40)

# %%
'hell{0!r} and {1!s}'.format('hey', 'how')
# Out:
# "hell'hey' and how"

# %%
d = {'ab': 1, 'b': 3}

# %%
del d['b']

# %%
d
# Out:
# {'ab': 1}

# %%
'abcdef'.find('cd')
# Out:
# 2

# %%
c = d.copy()

# %%
c is d
# Out:
# False

# %%
'abcde'.split('cd', 0)
# Out:
# ['abcde']

# %%
x = 8

# %%
x>>2
# Out:
# 2

# %%
d
# Out:
# {'ab': 1, 'b': 3}

# %%
sorted(d)
# Out:
# ['ab', 'b']

# %%
'abcdef'.center(7, "1")
# Out:
# '1abcdef'

# %%
'helo'.partition('lo')
# Out:
# ('he', 'lo', '')
