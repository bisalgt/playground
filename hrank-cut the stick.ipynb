# %%
def cutTheSticks(arr):
    result = []
    while len(arr)>0:
        result.append(len(arr))
        minimum = min(arr)
        arr.sort()
        print(arr)
        if max(arr)<= minimum:
            break
        for i in arr:
            if i > minimum:
                arr = arr[arr.index(i):]
                break
            
    return result

cutTheSticks([5,4,4,2,2,8])
# Out:
# [2, 2, 4, 4, 5, 8]
# [4, 4, 5, 8]
# [5, 8]
# [8]
# [6, 4, 2, 1]

# %%
a = list(range(5))
for i in a:
    print(a)
    if i < 3:
        a.remove(i)
a
# Out:
# [0, 1, 2, 3, 4]
# [1, 2, 3, 4]
# [1, 3, 4]
# [1, 3, 4]

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
def cut_the_stick(arr):
    sort(arr)
    while len(arr)>0:
        minimum = min(arr)
# Out:
#   File "<ipython-input-13-fa58a136926a>", line 2
#     while len(arr)>0:
#                      ^
# SyntaxError: unexpected EOF while parsing

# %%
adef cutTheSticks(arr):
    result = []
    while len(arr)>0:
        print(arr)
        result.append(len(arr))
        minimum = min(arr)
        print(minimum, '============')
        a = True
        length=len(arr)
        while length:
#             print('INside for loop', arr)
            if i <= minimum:
                print('Insiede if ', i, '+++++')
                print(i,'------')
                arr.remove(i)
                
#         print(arr, result)
    return result

cutTheSticks([5,4,4,2,2,8])

# %%
def find_position_to_delete(arr,p):
    for i in arr:
        if i <= p:
            arr.remove(i)
            


def cutTheSticks(arr):
    result = []
    sort(arr)
    a = True
    while a:
        mi = min(arr)
        
        

cutTheSticks([5,4,4,2,2,8])
