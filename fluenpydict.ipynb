# %% [raw]
# Since Python 3.3, the types module provides a wrapper class called MappingProxy
# Type , which, given a mapping, returns a mappingproxy instance that is a read-only but
# dynamic view of the original mapping. This means that updates to the original mapping
# can be seen in the mappingproxy , but changes cannot be made through it

# %%
from types import MappingProxyType

# %%
d = {1:'A'}

# %%
d_proxy = MappingProxyType(d)

# %%
d_proxy
# Out:
# mappingproxy({1: 'A'})

# %%
d_proxy[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-6f9dce4cd735> in <module>
# ----> 1 d_proxy[2]
#
# KeyError: 2

# %%
d_proxy
# Out:
# mappingproxy({1: 'A'})

# %%
d_proxy[2]= 'B'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-6440fe2577d0> in <module>
# ----> 1 d_proxy[2]= 'B'
#
# TypeError: 'mappingproxy' object does not support item assignment

# %%
d_proxy
# Out:
# mappingproxy({1: 'A'})

# %%
d[2] = 'B'

# %%
d
# Out:
# {1: 'A', 2: 'B'}

# %%
d_proxy
# Out:
# mappingproxy({1: 'A', 2: 'B'})

# %% [markdown]
# ### set

# %%
l = ['a', 'b', 'a', 'c', 'a', 'd', 'e', 'f', 'd']

# %%
from collections import Counter

ct = Counter(l)

# %%
ct
# Out:
# Counter({'a': 3, 'b': 1, 'c': 1, 'd': 2, 'e': 1, 'f': 1})

# %%
set(l)
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f'}

# %% [raw]
# Set elements must be hashable. The set type is not hashable, but frozenset is, so you
# can have frozenset elements inside a set .

# %%
fs = frozenset(l)

# %%
fs
# Out:
# frozenset({'a', 'b', 'c', 'd', 'e', 'f'})

# %%
fs.join()

# %%
s = set(l)

# %%
dir(fs)
# Out:
# ['__and__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'copy',
#  'difference',
#  'intersection',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'symmetric_difference',
#  'union']

# %%
fs.intersection(s)
# Out:
# frozenset({'a', 'b', 'c', 'd', 'e', 'f'})

# %%
s.intersection(fs)
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f'}

# %%
s.difference(fs)
# Out:
# set()

# %%
s.difference_update(fs)

# %%
s
# Out:
# set()

# %%
fs
# Out:
# frozenset({'a', 'b', 'c', 'd', 'e', 'f'})

# %%
fs.issuperset(s)
# Out:
# True

# %% [raw]
# In addition to guaranteeing uniqueness, the set types implement the essential set oper‐
# ations as infix operators, so, given two sets a and b , a | b returns their union, a & b
# computes the intersection, and a - b the difference.

# %%
s = {'a', 'b', 'a', 'c', 's'}

# %%
s
# Out:
# {'a', 'b', 'c', 's'}

# %%
s|fs
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f', 's'}

# %%
s&fs
# Out:
# {'a', 'b', 'c'}

# %%
s-fs
# Out:
# {'s'}

# %%
fs-s
# Out:
# frozenset({'d', 'e', 'f'})

# %%
s.__le__(fs)
# Out:
# False

# %%
s <=(fs)
# Out:
# False

# %%
s >=(fs)
# Out:
# False

# %%
s.isdisjoint(fs)
# Out:
# False

# %%
s.difference(fs)
# Out:
# {'s'}

# %%
s.add('g')

# %%
s.add({'h', 'i'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-ea39a71e0b8c> in <module>
# ----> 1 s.add({'h', 'i'})
#
# TypeError: unhashable type: 'set'

# %%
s.add(frozenset(['h', 'i']))

# %%
s
# Out:
# {'a', 'b', 'c', frozenset({'h', 'i'}), 'g', 's'}

# %%
i = s.__iter__()

# %%
type(i)
# Out:
# set_iterator

# %%
for _ in i:
    print(_)
# Out:
# g
# c
# a
# frozenset({'i', 'h'})
# b
# s

# %%
s.remove('h')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-348733f25b58> in <module>
# ----> 1 s.remove('h')
#
# KeyError: 'h'

# %%
s.discard('j')

# %%
s.discard('h')

# %%
s
# Out:
# {'a', 'b', 'c', frozenset({'h', 'i'}), 'g', 's'}

# %%
s.pop()
# Out:
# 'g'

# %%
s.remove('g')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-c850a1145646> in <module>
# ----> 1 s.remove('g')
#
# KeyError: 'g'

# %%
len(s)
# Out:
# 5

# %%
s.__len__()
# Out:
# 5

# %%
for i in s:
    print(i)
# Out:
# c
# a
# frozenset({'i', 'h'})
# b
# s

# %% [raw]
# A hash table is a sparse array (i.e., an array that always has empty cells). In standard data
# structure texts, the cells in a hash table are often called “buckets.” In a dict hash table,
# there is a bucket for each item, and it contains two fields: a reference to the key and a
# reference to the value of the item. Because all buckets have the same size, access to an
# individual bucket is done by offset.

# %%
hash(1)
# Out:
# 1

# %% [raw]
# the hash value of an int that fits
# in a machine word is the value of the int itself.`

# %%
hash(1.0000)
# Out:
# 1

# %%
hash(1.0001)
# Out:
# 230584300921345

# %%
hash(1.0002)
# Out:
# 461168601842689
