# %%
def not_divisible_subset(arr, k):
    for k in range(1,len(arr)-1):
        for i in range(len(arr)):
            print(i, (len(arr)-(len(arr)-k)+i) % 5)
            if ((len(arr)-(len(arr)-k)+i) % len(arr)) < i:
                print('if', arr[i:]+ arr[:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaning', arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:i])
            else:

                print('else',arr[i:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaining', arr[:i], arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:])
            
not_divisible_subset([1,2,3,4,5],5)
# Out:
# 0 1
# else [1, 2]
# remaining [] [3, 4, 5]
# 1 2
# else [2, 3]
# remaining [1] [4, 5]
# 2 3
# else [3, 4]
# remaining [1, 2] [5]
# 3 4
# else [4, 5]
# remaining [1, 2, 3] []
# 4 0
# if [5, 1]
# remaning [2, 3, 4]
# 0 2
# else [1, 2, 3]
# remaining [] [4, 5]
# 1 3
# else [2, 3, 4]
# remaining [1] [5]
# 2 4
# else [3, 4, 5]
# remaining [1, 2] []
# 3 0
# if [4, 5, 1]
# remaning [2, 3]
# 4 1
# if [5, 1, 2]
# remaning [3, 4]
# 0 3
# else [1, 2, 3, 4]
# remaining [] [5]
# 1 4
# else [2, 3, 4, 5]
# remaining [1] []
# 2 0
# if [3, 4, 5, 1]
# remaning [2]
# 3 1
# if [4, 5, 1, 2]
# remaning [3]
# 4 2
# if [5, 1, 2, 3]
# remaning [4]

# %%
def not_divisible_subset(arr, k2):
    for k in range(len(arr)-3,0, -1):
        for i in range(len(arr)):
            print(i, (len(arr)-(len(arr)-k)+i) % 5)
            if ((len(arr)-(len(arr)-k)+i) % len(arr)) < i:
                print('if', arr[i:]+ arr[:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaning', arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:i])
            else:

                print('else',arr[i:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaining', arr[:i], arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:])
            
not_divisible_subset([1,2,3,4,5,6],5)
# Out:
# 0 3
# else [1, 2, 3, 4]
# remaining [] [5, 6]
# 1 4
# else [2, 3, 4, 5]
# remaining [1] [6]
# 2 0
# else [3, 4, 5, 6]
# remaining [1, 2] []
# 3 1
# if [4, 5, 6, 1]
# remaning [2, 3]
# 4 2
# if [5, 6, 1, 2]
# remaning [3, 4]
# 5 3
# if [6, 1, 2, 3]
# remaning [4, 5]
# 0 2
# else [1, 2, 3]
# remaining [] [4, 5, 6]
# 1 3
# else [2, 3, 4]
# remaining [1] [5, 6]
# 2 4
# else [3, 4, 5]
# remaining [1, 2] [6]
# 3 0
# else [4, 5, 6]
# remaining [1, 2, 3] []
# 4 1
# if [5, 6, 1]
# remaning [2, 3, 4]
# 5 2
# if [6, 1, 2]
# remaning [3, 4, 5]
# 0 1
# else [1, 2]
# remaining [] [3, 4, 5, 6]
# 1 2
# else [2, 3]
# remaining [1] [4, 5, 6]
# 2 3
# else [3, 4]
# remaining [1, 2] [5, 6]
# 3 4
# else [4, 5]
# remaining [1, 2, 3] [6]
# 4 0
# else [5, 6]
# remaining [1, 2, 3, 4] []
# 5 1
# if [6, 1]
# remaning [2, 3, 4, 5]

# %%
def not_divisible_subset(arr, k2):
    for k in range(len(arr)-3,-1, -1):
        combined_list = []
        for i in range(len(arr)):
            initial_list = []
            remaining_list = []
            print(i, (len(arr)-(len(arr)-k)+i) % 5)
            if ((len(arr)-(len(arr)-k)+i) % len(arr)) < i:
                initial_list = arr[i:]+ arr[:((len(arr)-(len(arr)-k)+i) % len(arr))+1]
                remaining_list = arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:i]
                print('if', arr[i:]+ arr[:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaning', arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:i])
            else:
                initial_list = arr[i:((len(arr)-(len(arr)-k)+i) % len(arr))+1]
                remaining_list = arr[:i]+ arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:]
                print('else',arr[i:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaining', arr[:i], arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:])
            for i in remaining_list:
                matrix = set([*initial_list, i])
                if matrix not in combined_list:
                    combined_list.append(matrix)
        combined_list = [ list(i) for i in combined_list]
        print(combined_list, '-----------------------') 
not_divisible_subset([1,2,3],5)
# Out:
# 0 0
# else [1]
# remaining [] [2, 3]
# 1 1
# else [2]
# remaining [1] [3]
# 2 2
# else [3]
# remaining [1, 2] []
# [[1, 2], [1, 3], [2, 3]] -----------------------

# %%
def not_divisible_subset(arr, k2):
    for k in range(len(arr)-3,-1, -1):
        combined_list = []
        for i in range(len(arr)):
            initial_list = []
            remaining_list = []
            print(i, (len(arr)-(len(arr)-k)+i) % 5)
            if ((len(arr)-(len(arr)-k)+i) % len(arr)) < i:
                initial_list = arr[i:]+ arr[:((len(arr)-(len(arr)-k)+i) % len(arr))+1]
                remaining_list = arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:i]
                
            else:
                initial_list = arr[i:((len(arr)-(len(arr)-k)+i) % len(arr))+1]
                remaining_list = arr[:i]+ arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:]
                
            for i in remaining_list:
                matrix = set([*initial_list, i])
                if matrix not in combined_list:
                    combined_list.append(matrix)
        combined_list = [ list(i) for i in combined_list]
        print(combined_list, '-----------------------') 
not_divisible_subset([1,2,3],5)

# %%
def check_divisibility(arr):
    for i in arr:
        for j in arr:
            if i  != j:
                print(i, j)
check_divisibility([1,2,3,4])
# Out:
# 1 2
# 1 3
# 1 4
# 2 1
# 2 3
# 2 4
# 3 1
# 3 2
# 3 4
# 4 1
# 4 2
# 4 3

# %%
def check_not_divisibility(arr, k):
    for i in arr:
        for j in arr:
            if i  != j:
                print(i, j)
                if (i+j) % k == 0:
                    return False
    return True
check_not_divisibility([1,2,3], 3)
# Out:
# 1 2
# False

# %%
def is_not_divisible_single_arr(arr,k):
    for i in arr:
        for j in arr:
            if i  != j:
                 
                if (i+j) % k == 0:
                    print(i,j, arr, '---------------------------')
                    return False
    return True

def is_not_divisible(arrays, k):
    print(len(arrays[0]), '========================')
    if len(arrays[0])==11:
        print(len(arrays), '++++++++++++++++++++++++++++')
        for arr in arrays:
            if is_not_divisible_single_arr(arr, k):
                return len(arr)
    return False

def not_divisible_subset(arr, k2):
    for k in range(len(arr)-3,-1, -1):
        combined_list = []
        for i in range(len(arr)):
            initial_list = []
            remaining_list = []
#             print(i, (len(arr)-(len(arr)-k)+i) % 5)
            if ((len(arr)-(len(arr)-k)+i) % len(arr)) < i:
                initial_list = arr[i:]+ arr[:((len(arr)-(len(arr)-k)+i) % len(arr))+1]
                remaining_list = arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:i]
                
            else:
                initial_list = arr[i:((len(arr)-(len(arr)-k)+i) % len(arr))+1]
                remaining_list = arr[:i]+ arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:]
                
            for i in remaining_list:
                matrix = set([*initial_list, i])
                if matrix not in combined_list:
                    combined_list.append(matrix)
        print(len(combined_list[0]), '===============',len(combined_list))
#         combined_list = [ list(i) for i in combined_list]
        result = is_not_divisible(combined_list, k2)
        if result:
            return result
# not_divisible_subset([278, 576, 496, 727, 410, 124, 338, 149, 209, 702, 282, 718, 771, 575, 436], 7)
# not_divisible_subset([1,7,2,4], 3)
not_divisible_subset([278, 576, 496, 727, 410, 124, 338, 149, 209, 702, 282, 718, 771, 575, 436], 7)
# Out:
# 14 =============== 15
# 14 ========================
# 13 =============== 30
# 13 ========================
# 12 =============== 45
# 12 ========================
# 11 =============== 60
# 11 ========================
# 60 ++++++++++++++++++++++++++++
# 576 278 {576, 282, 496, 209, 338, 149, 278, 727, 410, 124, 702} ---------------------------
# 576 278 {576, 718, 496, 209, 338, 149, 278, 727, 410, 124, 702} ---------------------------
# 576 278 {576, 771, 496, 209, 338, 149, 278, 727, 410, 124, 702} ---------------------------
# 576 278 {576, 496, 209, 338, 149, 278, 727, 410, 124, 702, 575} ---------------------------
# 576 278 {576, 496, 209, 338, 436, 149, 278, 727, 410, 124, 702} ---------------------------
# 576 124 {576, 282, 718, 496, 209, 338, 149, 727, 410, 124, 702} ---------------------------
# 576 124 {576, 771, 282, 496, 209, 338, 149, 727, 410, 124, 702} ---------------------------
# ...

# %%
for i in range(2):
    for j in range(4):
        for k in range(2):
            if i==j==k:
                print('hreer')
                break
            print(i,j,k)
# Out:
# hreer
# 0 1 0
# 0 1 1
# 0 2 0
# 0 2 1
# 0 3 0
# 0 3 1
# 1 0 0
# 1 0 1
# 1 1 0
# hreer
# 1 2 0
# 1 2 1
# 1 3 0
# 1 3 1

# %%
def repeatedString(s, n):
    l = len(s)
    if n<=l:
        return s[:n+1].count('a')
    div =n//l
    rem = n%l
    c = s.count('a')*div + s[:rem].count('a')
    return c

# %%
a = 'bishalii'
a.count('i')
# Out:
# 3

# %%
repeatedString('a', 1000000000000)
# Out:
# 1000000000000

# %%
def jumpingOnClouds(c):
    pos = 0
    jump = 0
    while pos < len(c)-1:
        for i in range(pos, len(c)):
            if i+2 <= len(c)-1 and c[i+2] != 1:
                jump += 1
                pos = i+2
                print(jump, pos, '=====')
                break
            elif i+1 <= len(c)-1 and c[i+1] != 1:
                jump += 1
                pos = i+1
                print(jump, pos, '==+++++++==')
                break
    return jump

jumpingOnClouds([0, 0, 0, 1, 0, 0])
# Out:
# 1 2 =====
# 2 4 =====
# 3 5 ==+++++++==
# 3

# %%
def equalizeArray(arr):
    s = list(set(arr))
    max_rep = arr[0]
    count = arr.count(arr[0])
    for i in s:
        if arr.count(i) > count:
            count = arr.count(i)
            max_rep = i
    print(max_rep, count)
    
equalizeArray([1,2,2,3,3,3,4,4,4,4,4])
# Out:
# 4 5

# %%
def equalizeArray(arr):
    s = list(set(arr))
    max_rep = arr[0]
    count = arr.count(arr[0])
    for i in s:
        if arr.count(i) > count:
            count = arr.count(i)
            max_rep = i
    i = 0
    delete = 0
    while arr:
        print(arr, i)
        if arr[i] != max_rep:
            arr.remove(arr[i])
            delete += 1
            continue
        i += 1
        if len(arr) == count:
            return delete
            
    
equalizeArray([3,3,2,1,3])
# Out:
# [3, 3, 2, 1, 3] 0
# [3, 3, 2, 1, 3] 1
# [3, 3, 2, 1, 3] 2
# [3, 3, 1, 3] 2
# [3, 3, 3] 2
# 2

# %%
def equalizeArray(arr):
    s = list(set(arr))
    max_rep = arr[0]
    count = arr.count(arr[0])
    for i in s:
        if arr.count(i) > count:
            count = arr.count(i)
            max_rep = i
    i = 0
    delete = 0
    sorted_arr = sorted(arr)
    indx1 = sorted_arr.index(max_rep)
    indx2 = len(sorted_arr)-1-sorted_arr[::-1].index(max_rep)
    l = len(sorted_arr[:indx1])+ len(sorted_arr[indx2+1:])
#     print(sorted_arr, indx1, indx2, l)
    return l
            
    
equalizeArray([3,3,2,1,3])
# Out:
# 2

# %%
def queensAttack(n, k, r_q, c_q, obstacles):
    q_position = []
    row_postions = [[r_q,i] for i in range(1, n+1)]
    col_positons = [[i, c_q] for i in range(1, n+1)]
    print(row_postions)
    print(col_positons)

queensAttack(5, 3, 4, 3, [[5, 5], [4, 2], [2, 3]])
# Out:
# [[4, 1], [4, 2], [4, 3], [4, 4], [4, 5]]
# [[1, 3], [2, 3], [3, 3], [4, 3], [5, 3]]

# %%
def queensAttack(n, k, r_q, c_q, obstacles):
    q_position = []
    row_postions = [[r_q,i] for i in range(1, n+1)]
    col_positons = [[i, c_q] for i in range(1, n+1)]
    
    diagonal1 = []
    diagonal2 = []
    c = c_q
    d = 0
    for r in range(r_q,0,-1):
        
        print(r)
        if r>=1:
            c = c_q-d
            if c >= 1:
                print([r,c])
                diagonal1.append([r,c])
        d += 1
    e = 1
    print(r_q+1, n+1)
    for r in range(r_q+1, n+1):
        print('-------')
        if r <=5:
            c = c_q + e
            if c <=5:
                print([r,c])
                diagonal1.append([r,c])
        e += 1
    print(diagonal1)

queensAttack(5, 3, 4, 3, [[5, 5], [4, 2], [2, 3]])
# Out:
# 4
# [4, 3]
# 3
# [3, 2]
# 2
# [2, 1]
# 1
# 5 6
# -------
# [5, 4]
# [[4, 3], [3, 2], [2, 1], [5, 4]]

# %%
def queensAttack(n, k, r_q, c_q, obstacles):
    q_position = []
    row_postions = [[r_q,i] for i in range(1, n+1)]
    col_positons = [[i, c_q] for i in range(1, n+1)]
    
    diagonal1 = []
    diagonal2 = []
    d = 0
    for r in range(r_q,0,-1):
        if r>=1:
            c = c_q-d
            if c >= 1:
                diagonal1.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q + e
            if c <=n:
                diagonal1.append([r,c])
        e += 1
    
    
    
    
    d = 0
    for r in range(r_q,0,-1):
        if r>=1:
            c = c_q+d
            if c <= n:
                diagonal2.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q - e
            if c >=1:
                diagonal2.append([r,c])
        e += 1
        
    print(diagonal1)
    print(diagonal2)
    
    

queensAttack(5, 3, 4, 3, [[5, 5], [4, 2], [2, 3]])
# Out:
# [[4, 3], [3, 2], [2, 1], [5, 4]]
# [[4, 3], [3, 4], [2, 5], [5, 2]]

# %%
def queensAttack(n, k, r_q, c_q, obstacles):
    q_position = []
    row_postions = [[r_q,i] for i in range(1, n+1)]
    col_positons = [[i, c_q] for i in range(1, n+1)]
    
    diagonal1 = []
    diagonal2 = []
    d = 0
    for r in range(r_q,0,-1):
        if r>=1:
            c = c_q-d
            if c >= 1:
                diagonal1.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q + e
            if c <=n:
                diagonal1.append([r,c])
        e += 1
    
    
    
    
    d = 0
    for r in range(r_q,0,-1):
        if r>=1:
            c = c_q+d
            if c <= n:
                diagonal2.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q - e
            if c >=1:
                diagonal2.append([r,c])
        e += 1
        
    print(diagonal1)
    print(diagonal2)
    
    # to check for obstacle and deleting
    print(row_postions, '_____________________')
    for obj in obstacles:
        i, j = obj
        # check for row 
        if i == r_q:
            if j  - c_q > 0:
                matrix_to_remove = [[i, k] for k in range(j,n+1)]
                print(matrix_to_remove)
                
            if j - c_q < 0:
                matrix_to_remove = [[i, k] for k in range(1, j+1)]
            row_postions = [r for r in row_postions if r not in matrix_to_remove]
    print(row_postions, '++++++++')

queensAttack(5, 3, 4, 3, [[5, 5], [4, 2], [2, 3]])
# Out:
# [[4, 3], [3, 2], [2, 1], [5, 4]]
# [[4, 3], [3, 4], [2, 5], [5, 2]]
# [[4, 1], [4, 2], [4, 3], [4, 4], [4, 5]] _____________________
# [[4, 3], [4, 4], [4, 5]] ++++++++

# %%
def queensAttack(n, k, r_q, c_q, obstacles):
    q_position = []
    row_postions = [[r_q,i] for i in range(1, n+1)]
    col_positons = [[i, c_q] for i in range(1, n+1)]
    
    diagonal1 = []
    diagonal2 = []
    d = 0
    for r in range(r_q,0,-1):
        if r>=1:
            c = c_q-d
            if c >= 1:
                diagonal1.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q + e
            if c <=n:
                diagonal1.append([r,c])
        e += 1
    
    
    
    
    d = 0
    for r in range(r_q,0,-1):
        if r>=1:
            c = c_q+d
            if c <= n:
                diagonal2.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q - e
            if c >=1:
                diagonal2.append([r,c])
        e += 1
        
    print(diagonal1)
    print(diagonal2)
    
    # to check for obstacle and deleting
    for obj in obstacles:
        i, j = obj
        # check for row 
        if i == r_q:
            if j  - c_q > 0:
                matrix_to_remove = [[i, k] for k in range(j,n+1)]
                print(matrix_to_remove)
                
            if j - c_q < 0:
                matrix_to_remove = [[i, k] for k in range(1, j+1)]
            row_postions = [r for r in row_postions if r not in matrix_to_remove]
    
        # check for column
        
        if j == c_q:
            print(col_positons, '----------')
            if i - r_q > 0:
                matrix_to_remove = [[k, j] for k in range(i, n+1)]
            if i - r_q < 0:
                matrix_to_remove = [[k,j] for k in range(1, i+1)]
            col_positons = [c for c in col_positons if c not in matrix_to_remove]
            print(col_positons, '++++++++++++')
        
        # check for diagonal1
        
        

queensAttack(5, 3, 4, 3, [[5, 5], [4, 2], [2, 3]])
# Out:
# [[4, 3], [3, 2], [2, 1], [5, 4]]
# [[4, 3], [3, 4], [2, 5], [5, 2]]
# [[1, 3], [2, 3], [3, 3], [4, 3], [5, 3]] ----------
# [[3, 3], [4, 3], [5, 3]] ++++++++++++

# %%
def queensAttack(n, k, r_q, c_q, obstacles):
    q_position = []
    row_postions = [[r_q,i] for i in range(1, n+1)]
    col_positons = [[i, c_q] for i in range(1, n+1)]
    
    diagonal1 = []
    diagonal2 = []
    d = 0
    for r in range(r_q,0,-1):
        if r>=1:
            c = c_q-d
            if c >= 1:
                diagonal1.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q + e
            if c <=n:
                diagonal1.append([r,c])
        e += 1
    
    
    
    
    d = 0
    for r in range(r_q,0,-1):
        if r>=1:
            c = c_q+d
            if c <= n:
                diagonal2.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q - e
            if c >=1:
                diagonal2.append([r,c])
        e += 1
    
    # to check for obstacle and deleting
    for obj in obstacles:
        i, j = obj
        # check for row 
        if i == r_q:
            if j  - c_q > 0:
                matrix_to_remove = [[i, k] for k in range(j,n+1)]
                
            if j - c_q < 0:
                matrix_to_remove = [[i, k] for k in range(1, j+1)]
            row_postions = [r for r in row_postions if r not in matrix_to_remove]
            continue
    
        # check for column
        
        if j == c_q:
            if i - r_q > 0:
                matrix_to_remove = [[k, j] for k in range(i, n+1)]
            if i - r_q < 0:
                matrix_to_remove = [[k,j] for k in range(1, i+1)]
            col_positons = [c for c in col_positons if c not in matrix_to_remove]
            continue
            
        # check for diagonal1
        if i - r_q == j - c_q:
            print(i, j)
            print(diagonal1, '--------------')
            if i - r_q > 0:
                d = i - r_q
                matrix_to_remove = [[p,p-d] for p in range(i, n+1) ]
            if i -  r_q < 0:
                d =  r_q - i
                matrix_to_remove = [[p,p-d] for p in range(i,1,-1) if p-d >=1]
            diagonal1 = [k for k in diagonal1 if k not in matrix_to_remove]
            print(diagonal1, '+_+_++++++++++++++')
            continue
            
            
        print(diagonal1, '++++++++++===')

queensAttack(5, 3, 4, 3, [[5, 4], [4, 2], [3, 2]])
# Out:
# 5 4
# [[4, 3], [3, 2], [2, 1], [5, 4]] --------------
# [[4, 3], [3, 2], [2, 1]] +_+_++++++++++++++
# 3 2
# [[4, 3], [3, 2], [2, 1]] --------------
# [[4, 3]] +_+_++++++++++++++

# %%
def queensAttack(n, k, r_q, c_q, obstacles):
    q_position = []
    row_postions = [[r_q,i] for i in range(1, n+1)]
    col_positons = [[i, c_q] for i in range(1, n+1)]
    
    diagonal1 = []
    diagonal2 = []
    d = 0
    for r in range(r_q,0,-1):
        if r>=1:
            c = c_q-d
            if c >= 1:
                diagonal1.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q + e
            if c <=n:
                diagonal1.append([r,c])
        e += 1
    
    
    
    
    d = 0
    for r in range(r_q,0,-1):
        if r>=1:
            c = c_q+d
            if c <= n:
                diagonal2.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q - e
            if c >=1:
                diagonal2.append([r,c])
        e += 1
    
    # to check for obstacle and deleting
    for obj in obstacles:
        i, j = obj
        # check for row 
        if i == r_q:
            if j  - c_q > 0:
                matrix_to_remove = [[i, k] for k in range(j,n+1)]
                
            if j - c_q < 0:
                matrix_to_remove = [[i, k] for k in range(1, j+1)]
            row_postions = [r for r in row_postions if r not in matrix_to_remove]
            continue
    
        # check for column
        
        if j == c_q:
            if i - r_q > 0:
                matrix_to_remove = [[k, j] for k in range(i, n+1)]
            if i - r_q < 0:
                matrix_to_remove = [[k,j] for k in range(1, i+1)]
            col_positons = [c for c in col_positons if c not in matrix_to_remove]
            continue
            
        # check for diagonal1
        if i - r_q == j - c_q:
            if i - r_q > 0:
                d = i - r_q
                matrix_to_remove = [[p,p-d] for p in range(i, n+1) if p-d >=1]
            if i -  r_q < 0:
                d =  r_q - i
                matrix_to_remove = [[p,p-d] for p in range(i,1,-1) if p-d >=1]
            diagonal1 = [k for k in diagonal1 if k not in matrix_to_remove]
            continue
        
        # check for diagonal2
        if i -r_q == c_q - j:
            if i - r_q > 0:
                d = i - r_q
                matrix_to_remove = [[p,c_q+r_q-p] for p in range(i, n+1) if (r_q+c_q-p) <=n]
            if i -  r_q < 0:
                d =  r_q - i
                matrix_to_remove = [[p, r_q+c_q-p] for p in range(i,0,-1) if (r_q+c_q-p) <=n]
            diagonal2 = [k for k in diagonal2 if k not in matrix_to_remove]
            continue

queensAttack(5, 3, 4, 3, [[2, 5], [4, 2], [3, 2]])
# Out:
# hrerer
# [[2, 5]]

# %%
def queensAttack(n, k, r_q, c_q, obstacles):
    q_position = []
    row_postions = [[r_q,i] for i in range(1, n+1) if i != 3]
    col_positons = [[i, c_q] for i in range(1, n+1) if i != 4]
    
    diagonal1 = []
    diagonal2 = []
    d = 1
    for r in range(r_q-1,0,-1):
        if r>=1:
            c = c_q-d
            if c >= 1:
                diagonal1.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q + e
            if c <=n:
                diagonal1.append([r,c])
        e += 1
    
    
    
    
    d = 1
    for r in range(r_q-1,0,-1):
        if r>=1:
            c = c_q+d
            if c <= n:
                diagonal2.append([r,c])
        d += 1
    e = 1
    for r in range(r_q+1, n+1):
        if r <=n:
            c = c_q - e
            if c >=1:
                diagonal2.append([r,c])
        e += 1
    
    print(row_postions)
    print(col_positons)
    print(diagonal1)
    print(diagonal2)
    
    
    # to check for obstacle and deleting
    for obj in obstacles:
        i, j = obj
        # check for row 
        if i == r_q:
            if j  - c_q > 0:
                matrix_to_remove = [[i, k] for k in range(j,n+1)]
                
            if j - c_q < 0:
                matrix_to_remove = [[i, k] for k in range(1, j+1)]
            row_postions = [r for r in row_postions if r not in matrix_to_remove]
            continue
    
        # check for column
        
        if j == c_q:
            if i - r_q > 0:
                matrix_to_remove = [[k, j] for k in range(i, n+1)]
            if i - r_q < 0:
                matrix_to_remove = [[k,j] for k in range(1, i+1)]
            col_positons = [c for c in col_positons if c not in matrix_to_remove]
            continue
            
        # check for diagonal1
        if i - r_q == j - c_q:
            if i - r_q > 0:
                d = i - r_q
                matrix_to_remove = [[p,p-d] for p in range(i, n+1) if p-d >=1]
            if i -  r_q < 0:
                d =  r_q - i
                matrix_to_remove = [[p,p-d] for p in range(i,1,-1) if p-d >=1]
            diagonal1 = [k for k in diagonal1 if k not in matrix_to_remove]
            continue
        
        # check for diagonal2
        if i -r_q == c_q - j:
            if i - r_q > 0:
                d = i - r_q
                matrix_to_remove = [[p,c_q+r_q-p] for p in range(i, n+1) if (r_q+c_q-p) <=n]
            if i -  r_q < 0:
                d =  r_q - i
                matrix_to_remove = [[p, r_q+c_q-p] for p in range(i,0,-1) if (r_q+c_q-p) <=n]
            diagonal2 = [k for k in diagonal2 if k not in matrix_to_remove]
            continue
        
    return len(row_postions) + len(col_positons) + len(diagonal1) + len(diagonal2)

queensAttack(5, 3, 4, 3, [[2, 5], [4, 2], [3, 2]])
# Out:
# [[4, 1], [4, 2], [4, 4], [4, 5]]
# [[1, 3], [2, 3], [3, 3], [5, 3]]
# [[3, 2], [2, 1], [5, 4]]
# [[3, 4], [2, 5], [5, 2]]
# 9
