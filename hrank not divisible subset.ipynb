# %%
def not_divisible_subset(arr, k):
    for k in range(1,len(arr)-1):
        for i in range(len(arr)):
            print(i, (len(arr)-(len(arr)-k)+i) % 5)
            if ((len(arr)-(len(arr)-k)+i) % len(arr)) < i:
                print('if', arr[i:]+ arr[:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaning', arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:i])
            else:

                print('else',arr[i:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaining', arr[:i], arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:])
            
not_divisible_subset([1,2,3,4,5],5)
# Out:
# 0 1
# else [1, 2]
# remaining [] [3, 4, 5]
# 1 2
# else [2, 3]
# remaining [1] [4, 5]
# 2 3
# else [3, 4]
# remaining [1, 2] [5]
# 3 4
# else [4, 5]
# remaining [1, 2, 3] []
# 4 0
# if [5, 1]
# remaning [2, 3, 4]
# 0 2
# else [1, 2, 3]
# remaining [] [4, 5]
# 1 3
# else [2, 3, 4]
# remaining [1] [5]
# 2 4
# else [3, 4, 5]
# remaining [1, 2] []
# 3 0
# if [4, 5, 1]
# remaning [2, 3]
# 4 1
# if [5, 1, 2]
# remaning [3, 4]
# 0 3
# else [1, 2, 3, 4]
# remaining [] [5]
# 1 4
# else [2, 3, 4, 5]
# remaining [1] []
# 2 0
# if [3, 4, 5, 1]
# remaning [2]
# 3 1
# if [4, 5, 1, 2]
# remaning [3]
# 4 2
# if [5, 1, 2, 3]
# remaning [4]

# %%
def not_divisible_subset(arr, k2):
    for k in range(len(arr)-3,0, -1):
        for i in range(len(arr)):
            print(i, (len(arr)-(len(arr)-k)+i) % 5)
            if ((len(arr)-(len(arr)-k)+i) % len(arr)) < i:
                print('if', arr[i:]+ arr[:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaning', arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:i])
            else:

                print('else',arr[i:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaining', arr[:i], arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:])
            
not_divisible_subset([1,2,3,4,5,6],5)
# Out:
# 0 3
# else [1, 2, 3, 4]
# remaining [] [5, 6]
# 1 4
# else [2, 3, 4, 5]
# remaining [1] [6]
# 2 0
# else [3, 4, 5, 6]
# remaining [1, 2] []
# 3 1
# if [4, 5, 6, 1]
# remaning [2, 3]
# 4 2
# if [5, 6, 1, 2]
# remaning [3, 4]
# 5 3
# if [6, 1, 2, 3]
# remaning [4, 5]
# 0 2
# else [1, 2, 3]
# remaining [] [4, 5, 6]
# 1 3
# else [2, 3, 4]
# remaining [1] [5, 6]
# 2 4
# else [3, 4, 5]
# remaining [1, 2] [6]
# 3 0
# else [4, 5, 6]
# remaining [1, 2, 3] []
# 4 1
# if [5, 6, 1]
# remaning [2, 3, 4]
# 5 2
# if [6, 1, 2]
# remaning [3, 4, 5]
# 0 1
# else [1, 2]
# remaining [] [3, 4, 5, 6]
# 1 2
# else [2, 3]
# remaining [1] [4, 5, 6]
# 2 3
# else [3, 4]
# remaining [1, 2] [5, 6]
# 3 4
# else [4, 5]
# remaining [1, 2, 3] [6]
# 4 0
# else [5, 6]
# remaining [1, 2, 3, 4] []
# 5 1
# if [6, 1]
# remaning [2, 3, 4, 5]

# %%
def not_divisible_subset(arr, k2):
    for k in range(len(arr)-3,-1, -1):
        combined_list = []
        for i in range(len(arr)):
            initial_list = []
            remaining_list = []
            print(i, (len(arr)-(len(arr)-k)+i) % 5)
            if ((len(arr)-(len(arr)-k)+i) % len(arr)) < i:
                initial_list = arr[i:]+ arr[:((len(arr)-(len(arr)-k)+i) % len(arr))+1]
                remaining_list = arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:i]
                print('if', arr[i:]+ arr[:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaning', arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:i])
            else:
                initial_list = arr[i:((len(arr)-(len(arr)-k)+i) % len(arr))+1]
                remaining_list = arr[:i]+ arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:]
                print('else',arr[i:((len(arr)-(len(arr)-k)+i) % len(arr))+1])
                print('remaining', arr[:i], arr[((len(arr)-(len(arr)-k)+i) % len(arr))+1:])
            for i in remaining_list:
                matrix = [*initial_list, i]
                if matrix not in combined_list:
                    combined_list.append(matrix)
        print(combined_list, '-----------------------') 
not_divisible_subset([1,2,3],5)
# Out:
# 0 0
# else [1]
# remaining [] [2, 3]
# 1 1
# else [2]
# remaining [1] [3]
# 2 2
# else [3]
# remaining [1, 2] []
# [[1, 2], [1, 3], [2, 1], [2, 3], [3, 1], [3, 2]] -----------------------
