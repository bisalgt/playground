# %%
d = {'one':1, 'two':2, 'three':3}

# %%
d.setdefault('one')
# Out:
# 1

# %%
d.setdefault('one', 2)
# Out:
# 1

# %%
d
# Out:
# {'one': 1, 'two': 2, 'three': 3}

# %%
d.setdefault('four', 4)
# Out:
# 4

# %%
d
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4}

# %%
d.setdefault('five', []).append(5)

# %%
d
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': [5]}

# %%
d.setdefault('five', []).append(5)

# %%
d
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': [5, 5]}

# %%
l = [1,2,3,4]

# %%
from collections import defaultdict

d = defaultdict(list)

# %%
d
# Out:
# defaultdict(list, {})

# %%
d[1]
# Out:
# []

# %%
d
# Out:
# defaultdict(list, {1: []})

# %%
d[2]
# Out:
# []

# %%
d
# Out:
# defaultdict(list, {1: [], 2: []})

# %%
d[3] = [2,3,4]

# %%
d
# Out:
# defaultdict(list, {1: [], 2: [], 3: [2, 3, 4]})

# %%
from selenium import webdriver
import time
import csv

driver = webdriver.Chrome("F:\\Python-Jupyter-Notebook\Python Basic\Selenium Practice\chromedriver")
link = "https://www.examveda.com/mcq-question-on-javascript/"
link2 = "mcq-question-on-"
main_link = link.replace(link2,"")
    
driver.get(link)
data_list = driver.find_elements_by_xpath("/html/body/div[1]/section[1]/div/div[2]/div[1]/article")
sites = []
for n,data in enumerate(data_list):
    value = data.text
    new_val = value.replace(" ", "-").lower()
    sites.append(new_val)

# with open("SiteList.csv", "w", encoding="utf-8", newline = "") as csvfile:
#     spamwriter = csv.writer(csvfile, delimiter=' ', quoting=csv.QUOTE_MINIMAL)
#     for data in data_list:
#         value = data.text
#         spamwriter.writerow([value,])
print(sites)
driver.quit()
