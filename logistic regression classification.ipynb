# %%
import sklearn
import numpy as np

# %%
iris = sklearn.datasets.load_iris()
# dir(sklearn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-021f6a1ca40b> in <module>
# ----> 1 iris = sklearn.datasets.load_iris()
#       2 # dir(sklearn)
#
# AttributeError: module 'sklearn' has no attribute 'datasets'

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %%
X = iris.data[:, :2]

# %%
y = (iris.target != 0) * 1

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))
# z = np.dot(X, theta)
# h = sigmoid(z)

# %%
X.shape
# Out:
# (150, 2)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datas/data_classification.csv')

# %%
df.head()
# Out:
#    4.8550642421469092  9.6399615658447146  1
# 0            8.625440            0.058927  0
# 1            3.828192            0.723199  0
# 2            7.150955            3.899420  1
# 3            6.477900            8.198181  1
# 4            1.922270            1.331427  0

# %%
df.shape
# Out:
# (99, 3)

# %%
X = df.iloc[:, [0,1]].copy()

# %%
X.columns = ['studied', 'slept']

# %%
y = df.iloc[:, 2].copy()

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
#      ..
# 94    0
# 95    1
# 96    0
# 97    1
# 98    0
# Name: 1, Length: 99, dtype: int64

# %% [raw]
# import seaborn as sns
# sns.set()
# sns.relplot(x=X.iloc[:,0], y=X.iloc[:,1], hue=y.iloc[0], data = X)

# %%
df.columns = ['studied', 'slept', 'pass']

# %%
sns.relplot(x='studied', y='slept',hue='pass', data=df )

# %%
def sigmoid(z):
     return 1.0 / (1 + np.exp(-z))

# %%
theta = np.array([1,2,3])

# %%
X = pd.concat([pd.Series(np.ones(df.shape[0])), df[['studied', 'slept']]], axis=1)

# %%
X.head()
# Out:
#      0   studied     slept
# 0  1.0  8.625440  0.058927
# 1  1.0  3.828192  0.723199
# 2  1.0  7.150955  3.899420
# 3  1.0  6.477900  8.198181
# 4  1.0  1.922270  1.331427

# %%
z = theta*X

# %%
sigmoid(z)
# Out:
#            0   studied     slept
# 0   0.731059  1.000000  0.544080
# 1   0.731059  0.999527  0.897486
# 2   0.731059  0.999999  0.999992
# 3   0.731059  0.999998  1.000000
# 4   0.731059  0.979052  0.981913
# ..       ...       ...       ...
# 94  0.731059  0.511138  0.999656
# 95  0.731059  1.000000  1.000000
# 96  0.731059  0.999371  1.000000
# 97  0.731059  1.000000  1.000000
# 98  0.731059  0.983067  0.999993
#
# [99 rows x 3 columns]

# %%
np.array([1,2,3])*np.array([[1,2,3], [1,2,3]])
# Out:
# array([[1, 4, 9],
#        [1, 4, 9]])

# %%
def predict(X, theta):
    z = (X*theta).sum(axis=1)
    return sigmoid(z)

# %%
cost_1 = -(y*np.log(predict(X, theta)))

# %%
np.log(predict(X, theta))
# Out:
# 0          0.0
# studied    0.0
# slept      0.0
# dtype: float64

# %%
predict(X, theta)
# Out:
# 0     1.000000
# 1     0.999980
# 2     1.000000
# 3     1.000000
# 4     0.999855
#         ...
# 94    0.999879
# 95    1.000000
# 96    1.000000
# 97    1.000000
# 98    1.000000
# Length: 99, dtype: float64

# %%
cost_1 = -y*np.log(predict(X, theta))

# %%
cost_2 = -(1-y)*np.log(1-predict(X, theta))
# Out:
# /home/bishal/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
cost = (1/X.shape[0])*(cost_1+cost_2).sum()

# %%
cost
# Out:
# 8.516645640926768

# %%
theta
# Out:
# array([1, 2, 3])

# %%
alpha = 0.0001
m = X.shape[0]
def gradient_descent():
    z
    sigmoid
    theta = theta-((alpha/m)*)
# Out:
#   File "<ipython-input-121-7f3de381b1f1>", line 2
#     for j in theta:
#                    ^
# SyntaxError: unexpected EOF while parsing

# %%
alpha = 0.0001
m = X.shape[0]

(alpha/m)*
# Out:
# 1.01010101010101e-06

# %%
h =sigmoid(z).sum(axis=1)
(h-y)
# Out:
# 0     2.275139
# 1     2.628072
# 2     1.731050
# 3     1.731056
# 4     2.692023
#         ...
# 94    2.241853
# 95    1.731058
# 96    2.730429
# 97    1.731058
# 98    2.714118
# Length: 99, dtype: float64

# %%
(h-y)*X.iloc[:, 1]
# Out:
# 0     19.624072
# 1     10.060762
# 2     12.378658
# 3     11.213610
# 4      5.174794
#         ...
# 94     0.049948
# 95    13.209078
# 96    10.061623
# 97    12.955689
# 98     5.511582
# Length: 99, dtype: float64

# %%
cost_matrix = []
alpha = 0.01
m = X.shape[0]
theta = np.ones(3)
def sigmoid(z):
     return 1.0 / (1 + np.exp(-z))
for i in range(500):
    z = (X*theta).sum(axis=1)
    h = sigmoid(z)
    cost_1 = -y*np.log(predict(X, theta))
    cost_2 = -(1-y)*np.log(1-predict(X, theta))
    cost = (1/X.shape[0])*(cost_1+cost_2).sum()
    print(cost, theta)
    cost_matrix.append(cost)
    for j in range(3):
        theta[j] = theta[j]-((alpha/m)*((h-y)*X.iloc[:, j]).sum())
# Out:
# 3.678180397238511 [1. 1. 1.]
# 3.6244110249822117 [0.99547313 0.98399139 0.98384591]
# 3.5706536853320037 [0.99094724 0.96798413 0.96769386]
# 3.5169092458839395 [0.98642237 0.95197832 0.951544  ]
# 3.4631786486331535 [0.9818986  0.93597409 0.9353965 ]
# 3.4094629176186406 [0.977376   0.91997153 0.91925152]
# 3.3557631675014994 [0.97285463 0.90397079 0.90310925]
# 3.3020806132046325 [0.96833457 0.88797202 0.8869699 ]
# 3.2484165807593484 [0.96381591 0.87197537 0.87083368]
# 3.1947725195373855 [0.95929874 0.85598102 0.85470084]
# 3.141150016063188 [0.95478315 0.83998916 0.83857163]
# 3.0875508096392563 [0.95026926 0.82400001 0.82244634]
# 3.033976810053191 [0.94575717 0.80801382 0.80632527]
# 2.9804301176729546 [0.94124702 0.79203085 0.79020878]
# 2.9269130462925186 [0.93673893 0.77605139 0.77409722]
# 2.873428149144521 [0.93223304 0.76007578 0.757991  ]
# 2.8199782485626494 [0.92772953 0.74410438 0.74189057]
# 2.766566469858262 [0.92322854 0.72813762 0.72579642]
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(np.arange(500), cost_matrix)

# %%
import matplotlib.pyplot as plt
plt.plot(np.arange(500), cost_matrix)
