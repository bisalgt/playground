# %%
# Complete the chocolateFeast function below.
def chocolateFeast(n, c, m):
    count = 0
    wrappers = 0
    if n < c:
        return 0
    count = n//c
    wrappers = count
    if m > wrappers:
        return count
    while wrappers >= m:
        print(wrappers, count)
        exchange_wrap = wrappers//m
        remaning_wrap = wrappers%m
        wrappers -= exchange_wrap*m
        count += exchange_wrap
        wrappers += exchange_wrap
    
    return (count)
chocolateFeast(10,2,5)
# Out:
# 5 5
# 6

# %%
def serviceLane(n, cases):
    for i in cases:
        print(min(width[(i[0]):i[1]+1]))

# %%
# Complete the workbook function below.
def workbook(n, k, arr):
    special = 0
    page = 0
    
    for i in arr:
        if i >= k:
            special += 1
    return special

# workbook(5, 3, [4, 2, 6, 1, 10])
workbook(10, 5, [3, 8, 15, 11, 14, 1, 9, 2, 24, 31])
# Out:
# 7

# %%
# Complete the workbook function below.
def workbook(n, k, arr):
    special = 0
    pages = 0
    for i in range(n):
        print(arr[i])
        ch_pr = arr[i]
        if k >= ch_pr:
            pages += 1
            if pages in range(1, ch_pr+1):
                special += 1
        if ch_pr > k:
            if ch_pr%k==0:
                s = 1
                e = k
                for j in range(int(ch_pr/k)):
                    pages += 1
                    if pages in range(s, e+1):
                        special += 1
                    s = e+1
                    e += k
#                 pages += ch_pr/k
            else:
                s = 1
                e = k
                for j in range(int(ch_pr//k)):
                    print(pages, special , 'here')
                    pages += 1
                    if pages in range(s, e+1):
                        special += 1
                    if  e+k < ch_pr//k:
                        s = e+1
                        e += k
                    else:
                        break
                pages += 1
                if pages in range(s, e+2):
                    special += 1
        
    return special
                
                
                

workbook(5, 3, [4, 2, 6, 1, 10])
# workbook(10, 5, [3, 8, 15, 11, 14, 1, 9, 2, 24, 31])
# Out:
# 4
# 0 0 here
# 2
# 6
# 1
# 10
# 6 3 here
# 3

# %%
# Complete the workbook function below.
def workbook(n, k, arr):
    special = 0
    pages = 0
    for i in range(n):
        print(arr[i], '----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---')
        ch_pr = arr[i]
        if k >= ch_pr:
            print('if ---------')
            pages += 1
            if pages in range(1, ch_pr+1):
                special += 1
        elif ch_pr > k:
            print('elif-------')
            if ch_pr%k==0:
                print('elif if , ------')
                s = 1
                e = k
                for j in range(int(ch_pr/k)):
                    pages += 1
                    if pages in range(s, e+1):
                        special += 1
                    s = e+1
                    e += k
#                 pages += ch_pr/k
            else:
                print('elif else, ----------')
                s = 1
                e = k
                ranger = int(ch_pr//k)
                for j in range(ranger):
                    print(pages,'pages', special,  'special' , 'here')
                    pages += 1
                    if pages in range(s, e+1):
                        print('inside here special elif else for if', special)
                        special += 1
                        print('special', special, '=-=-=-=-')
                    print()
                    if  e+k < (ch_pr):
                        print('incremental loop _000000000000000000-----------')
                        s = e+1
                        e += k
                    else:
                        s = e
                        break
                pages += 1
                if pages in range(s, ch_pr+1):
                    print(s, ch_pr, '_+_+_+_+_+_+_+_+_+_+_+_+_+_')
                    special += 1
        print(pages, '+++++++++++++++++++++++++==', special)  
    return special
                
                
                

# workbook(5, 3, [4, 2, 6, 1, 10])
# workbook(10, 5, [3, 8, 15, 11, 14, 1, 9, 2, 24, 31])
# workbook(67, 50, a)
# Out:
# 1 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 1 +++++++++++++++++++++++++== 1
# 24 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 2 +++++++++++++++++++++++++== 2
# 1 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 3 +++++++++++++++++++++++++== 2
# 2 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 4 +++++++++++++++++++++++++== 2
# 3 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 5 +++++++++++++++++++++++++== 2
# 1 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 6 +++++++++++++++++++++++++== 2
# 1 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 7 +++++++++++++++++++++++++== 2
# 75 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# elif-------
# elif else, ----------
# 7 pages 2 special here
# inside here special elif else for if 2
# special 3 =-=-=-=-
#
# 9 +++++++++++++++++++++++++== 3
# 1 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 10 +++++++++++++++++++++++++== 3
# ...

# %%
a = '''1 24 1 2 3 1 1 75 1 100 100 19 53 100 63 100 22 70 3 100 100 26 100 100 6 49 100 100 71 14 100 32 98 92 100 44 100 100 100 36 84 46 100 100 100 100 34 100 87 62 55 97 100 100 100 85 100 100 100 76 100 2 97 100 82 100 2'''
a = a.split(' ')
a = [int(i) for i in a]

# %%
67 50

# %%
# a = '''1 24 1 2 3 1 1 75 1 100 100 19 53 100 63 100 22 70 3 100 100 26 100 100 6 49 100 100 71 14 100 32 98 92 100 44 100 100 100 36 84 46 100 100 100 100 34 100 87 62 55 97 100 100 100 85 100 100 100 76 100 2 97 100 82 100 2'''
a = '''1 8 19 15 2 29 3 2 25 2 19 26 17 33 22'''
a = a.split(' ')
a = [int(i) for i in a]
a
# Out:
# [1, 8, 19, 15, 2, 29, 3, 2, 25, 2, 19, 26, 17, 33, 22]

# %%
# Complete the workbook function below.
def workbook(n, k, arr):
    special = 0
    pages = 0
    for i in range(n):
        print(arr[i], '----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---')
        ch_pr = arr[i]
        if k >= ch_pr:
            print('if ---------')
            pages += 1
            if pages in range(1, ch_pr+1):
                special += 1
        elif ch_pr > k:
            print('elif-------')
            if ch_pr%k==0:
                print('elif if , ------')
                s = 1
                e = k
                for j in range(int(ch_pr/k)):
                    pages += 1
                    if pages in range(s, e+1):
                        special += 1
                    s = e+1
                    e += k
#                 pages += ch_pr/k
            else:
                print('elif else, ----------')
                s = 1
                e = k
                ranger = int(ch_pr//k)
                for j in range(ranger):
                    print(pages,'pages', special,  'special' , 'here')
                    pages += 1
                    if pages in range(s, e+1):
                        print('inside here special elif else for if', special)
                        special += 1
                        print('special', special, '=-=-=-=-')
                    print()
                    if  e+k < (ch_pr):
                        print('incremental loop _000000000000000000-----------')
                        s = e+1
                        e += k
                    else:
                        s = e
                        break
                pages += 1
                if pages in range(s, ch_pr+1):
                    print(s, ch_pr, '_+_+_+_+_+_+_+_+_+_+_+_+_+_')
                    special += 1
        print(pages, '+++++++++++++++++++++++++==', special)  
    return special
                
                
                

# workbook(5, 3, [4, 2, 6, 1, 10])
# workbook(10, 5, [3, 8, 15, 11, 14, 1, 9, 2, 24, 31])
# workbook(67, 50, a)
# [1, 8, 19, 15, 2, 29, 3, 2, 25, 2, 19, 26, 17, 33, 22]
workbook(15, 20, a)
# Out:
# 1 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 1 +++++++++++++++++++++++++== 1
# 8 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 2 +++++++++++++++++++++++++== 2
# 19 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 3 +++++++++++++++++++++++++== 3
# 15 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 4 +++++++++++++++++++++++++== 4
# 2 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 5 +++++++++++++++++++++++++== 4
# 29 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# elif-------
# elif else, ----------
# 5 pages 4 special here
# inside here special elif else for if 4
# special 5 =-=-=-=-
#
# 7 +++++++++++++++++++++++++== 5
# 3 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 8 +++++++++++++++++++++++++== 5
# 2 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# if ---------
# 9 +++++++++++++++++++++++++== 5
# 25 ----XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX---
# elif-------
# elif else, ----------
# 9 pages 5 special here
# ...
