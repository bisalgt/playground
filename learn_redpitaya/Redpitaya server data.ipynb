# %%
import socket

msgFromClient       = "-v"

bytesToSend         = str.encode(msgFromClient)

serverAddressPort   = ("192.168.178.25", 61231)

bufferSize          = 1024

# Create a UDP socket at client side
UDPClientSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

 

# Send to server using created UDP socket

UDPClientSocket.sendto(bytesToSend, serverAddressPort)

 

msgFromServer, addressFromServer = UDPClientSocket.recvfrom(bufferSize)

print(addressFromServer)

# message = msgFromServer.decode()

msg = "Message from Server ---{}".format(msgFromServer)

print(msg)



UDPClientSocket.close()
# Out:
# ('192.168.178.25', 61231)
# ...

# %%
type(msgFromServer)
# Out:
# bytes

# %%
dir(msgFromServer)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'center',
#  'count',
#  'decode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'fromhex',
#  'hex',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdigit',
#  'islower',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
# ...

# %%
msgFromServer.decode()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_7768/1974607493.py in <module>
# ----> 1 msgFromServer.decode()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 2: invalid start byte

# %%
len(msgFromServer)
# Out:
# 1024

# %%
msg = msgFromServer[10:]

# %%
msg.decode('utf-8', 'ignore')
# Out:
# '?\x00\x00?\x00\x00\x00D\x00\x00\x00\x00(kI\x00\x00@A\x00\x00\x00\x00\x00\x00\x00\x00v?\x00\x00\x00\x00\x00\x00\x00\x00Ga>\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x02\x00\x01\x00'

# %%
import socket

msgFromClient       = "-v"

bytesToSend         = str.encode(msgFromClient)

serverAddressPort   = ("192.168.178.25", 61231)

bufferSize          = 1024

# Create a UDP socket at client side
UDPClientSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

 

# Send to server using created UDP socket

UDPClientSocket.sendto(bytesToSend, serverAddressPort)

 

msgFromServer, addressFromServer = UDPClientSocket.recvfrom(bufferSize)

print(addressFromServer)

# message = msgFromServer.decode()

msg = "Message from Server ---{}".format(msgFromServer)

print(msg)



UDPClientSocket.close()
# Out:
# ('192.168.178.25', 61231)
# ...

# %%
import socket

msgFromClient       = "-v"

bytesToSend         = str.encode(msgFromClient)

serverAddressPort   = ("192.168.178.25", 61231)

bufferSize          = 1024

# Create a UDP socket at client side
UDPClientSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

 

# Send to server using created UDP socket

UDPClientSocket.sendto(bytesToSend, serverAddressPort)

 

msgFromServer, addressFromServer = UDPClientSocket.recvfrom(bufferSize)

print(addressFromServer)

# message = msgFromServer.decode()

msg = "Message from Server ---{}".format(msgFromServer)

print(msg)



UDPClientSocket.close()
# Out:
# ('192.168.178.25', 61231)
# ...

# %%
import socket

msgFromClient       = "-v"

bytesToSend         = str.encode(msgFromClient)

serverAddressPort   = ("192.168.178.25", 61231)

bufferSize          = 1024

# Create a UDP socket at client side
UDPClientSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

 

# Send to server using created UDP socket

UDPClientSocket.sendto(bytesToSend, serverAddressPort)

 

msgFromServer, addressFromServer = UDPClientSocket.recvfrom(bufferSize)

print(addressFromServer)

# message = msgFromServer.decode()

msg = "Message from Server ---{}".format(msgFromServer)

print(msg)



UDPClientSocket.close()
# Out:
# ('192.168.178.25', 61231)
# ...

# %%
import socket

msgFromClient       = "-v"

bytesToSend         = str.encode(msgFromClient)

serverAddressPort   = ("192.168.178.25", 61231)

bufferSize          = 1024

# Create a UDP socket at client side
UDPClientSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

 

# Send to server using created UDP socket

UDPClientSocket.sendto(bytesToSend, serverAddressPort)

 

msgFromServer, addressFromServer = UDPClientSocket.recvfrom(bufferSize)

print(addressFromServer)

# message = msgFromServer.decode()

msg = "Message from Server ---{}".format(msgFromServer)

print(msg)



UDPClientSocket.close()
# Out:
# ('192.168.178.25', 61231)
# ...

# %%
import socket

msgFromClient       = "-v"

bytesToSend         = str.encode(msgFromClient)

serverAddressPort   = ("192.168.178.25", 61231)

bufferSize          = 1024

# Create a UDP socket at client side
UDPClientSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

 

# Send to server using created UDP socket

UDPClientSocket.sendto(bytesToSend, serverAddressPort)

 

msgFromServer, addressFromServer = UDPClientSocket.recvfrom(bufferSize)

print(addressFromServer)

# message = msgFromServer.decode()

msg = "Message from Server ---{}".format(msgFromServer)

print(msg)



UDPClientSocket.close()
# Out:
# ('192.168.178.25', 61231)
# ...

# %%
import socket

msgFromClient       = "-v"

bytesToSend         = str.encode(msgFromClient)

serverAddressPort   = ("192.168.178.25", 61231)

bufferSize          = 1024

# Create a UDP socket at client side
UDPClientSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

 

# Send to server using created UDP socket

UDPClientSocket.sendto(bytesToSend, serverAddressPort)

 

msgFromServer, addressFromServer = UDPClientSocket.recvfrom(bufferSize)

print(addressFromServer)

# message = msgFromServer.decode()

msg = "Message from Server ---{}".format(msgFromServer)

print(msg)



UDPClientSocket.close()
# Out:
# ('192.168.178.25', 61231)
# ...

# %%
import socket

msgFromClient       = "-v"

bytesToSend         = str.encode(msgFromClient)

serverAddressPort   = ("192.168.178.25", 61231)

bufferSize          = 1024

# Create a UDP socket at client side
UDPClientSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

 

# Send to server using created UDP socket

UDPClientSocket.sendto(bytesToSend, serverAddressPort)

 

msgFromServer, addressFromServer = UDPClientSocket.recvfrom(bufferSize)

print(addressFromServer)

# message = msgFromServer.decode()

msg = "Message from Server ---{}".format(msgFromServer)

print(msg)



UDPClientSocket.close()
# Out:
# ('192.168.178.25', 61231)
# ...

# %%
def prepare_bytes_on_string(array):
    output = ''
    for i in range(0, len(array), 1):
        #Just as a reminder:
        #hex(x)                    #value: '0xffffbfde1605'
        #hex(x)[2:]                #value: 'ffffbfde1605'
        #hex(x)[2:].decode('hex')  #value: '\xff\xff\xbf\xde\x16\x05'
        output += hex(array[i])[2:].decode('hex')
    return output

bytes_array = [0x38, 0xcd, 0x87, 0xc0]
val = prepare_bytes_on_string(bytes_array)
output = unpack('f', val)
print(output)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_7768/844026529.py in <module>
#      10
#      11 bytes_array = [0x38, 0xcd, 0x87, 0xc0]
# ---> 12 val = prepare_bytes_on_string(bytes_array)
#      13 output = unpack('f', val)
#      14 print(output)
#
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_7768/844026529.py in prepare_bytes_on_string(array)
#       6         #hex(x)[2:]                #value: 'ffffbfde1605'
#       7         #hex(x)[2:].decode('hex')  #value: '\xff\xff\xbf\xde\x16\x05'
# ----> 8         output += hex(array[i])[2:].decode('hex')
#       9     return output
#      10
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
type(msgFromServer)
# Out:
# bytes

# %%
len(msgFromServer)
# Out:
# 1024

# %%
hex(msgFromServer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_7768/1994346918.py in <module>
# ----> 1 hex(msgFromServer)
#
# TypeError: 'bytes' object cannot be interpreted as an integer

# %%
import struct

struct.unpack('>bhl', b'\x01\x00\x02\x00\x00\x00\x03')
# Out:
# (1, 2, 3)

# %%
struct.unpack('>bhl', msgFromServer[:7])
# Out:
# (0, 128, 1107296256)

# %%
for i in range(128):
    msg = struct.unpack('>bhl', msgFromServer[i*7:i*7+7])
    print('----------')
    print(i*7,i*7+7)
    print(msg)
# Out:
# ----------
# 0 7
# (0, 128, 1107296256)
# ----------
# 7 14
# (71, 0, -2143354880)
# ----------
# 14 21
# (-128, 16128, 17408)
# ----------
# 21 28
# (0, 0, 678161993)
# ----------
# 28 35
# (0, 64, 1090519040)
# ----------
# 35 42
# (0, 0, 49586)
# ----------
# 42 49
# (117, 16128, 0)
# ----------
# 49 56
# (0, 0, -1371053762)
# ----------
# 56 63
# (0, 0, 0)
# ----------
# 63 70
# (0, -769, -184551937)
# ----------
# 70 77
# (-9, -12, -589834)
# ----------
# 77 84
# (-1, -1537, -150995969)
# ----------
# 84 91
# (-8, -5, -131081)
# ----------
# 91 98
# (-1, -769, 0)
# ----------
# 98 105
# (-15, -8, -786441)
# ----------
# 105 112
# (-1, -3073, -201329665)
# ----------
# 112 119
# (-11, -10, -786447)
# ----------
# 119 126
# (-1, -3841, -402658561)
# ----------
# 126 133
# (-12, -6, -590070)
# ----------
# 133 140
# (0, 2816, -150995713)
# ----------
# 140 147
# (-15, -19, -327683)
# ----------
# 147 154
# (-1, -769, 33619711)
# ----------
# 154 161
# (0, 255, -16449534)
# ...

# %%
struct.calcsize('>bhl')
# Out:
# 7

# %%
struct.unpack('>I', msgFromServer[:4])
# Out:
# (32834,)

# %%
struct.unpack('>I', msgFromServer[4:8])
# Out:
# (71,)

# %%
for i in struct.iter_unpack('>I', msgFromServer):
    print(i)
# Out:
# (32834,)
# (71,)
# (32831,)
# (32831,)
# (68,)
# (0,)
# (678161993,)
# (16449,)
# (0,)
# (0,)
# (3249698111,)
# (0,)
# (0,)
# (2923913534,)
# (0,)
# (0,)
# (4244632831,)
# (4127193087,)
# (4110415615,)
# (4143970815,)
# (4143971327,)
# (4177525759,)
# (4261410815,)
# (4244570112,)
# (61951,)
# (4177523711,)
# (4160746495,)
# (4093637631,)
# (4127192831,)
# (4093637119,)
# (4043302911,)
# (3942642943,)
# (4211078911,)
# (167774976,)
# (4143971583,)
# (4060081663,)
# (4211080703,)
# (4244570624,)
# (4278124544,)
# (4294903040,)
# (33554944,)
# (184550912,)
# (4211080959,)
# (134218752,)
# (100728575,)
# (134283263,)
# (33556480,)
# (150995200,)
# (4227856895,)
# (4294966015,)
# (4160746751,)
# (4244635391,)
# (33619711,)
# (4227856383,)
# (4127130112,)
# (65279,)
# (4076860159,)
# (4093639167,)
# (4160745215,)
# (4143968255,)
# (4160684288,)
# (4093575936,)
# (100727807,)
# (4244570112,)
# (33619199,)
# (100663552,)
# (4278189311,)
# (4227792896,)
# (4160749055,)
# (4244635135,)
# ...

# %%
import socket

msgFromClient       = "-v"

bytesToSend         = str.encode(msgFromClient)

serverAddressPort   = ("192.168.178.25", 61231)

bufferSize          = 1024
data = bytearray()

# Create a UDP socket at client side
UDPClientSocket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

 

# Send to server using created UDP socket

UDPClientSocket.sendto(bytesToSend, serverAddressPort)

 
while True:
    packet = UDPClientSocket.recv(bufferSize)
    print(packet)
    print(len(packet))
    if not packet:
        break
    data.extend(packet)


# message = msgFromServer.decode()

msg = "Message from Server ---{}".format(data)

print(msg)



UDPClientSocket.close()
# Out:
# b'\x00\x00\x80B\x00\x00\x00G\x00\x00\x80?\x00\x00\x80?\x00\x00\x00D\x00\x00\x00\x00(k\xeeI\x00\x00@A\x00\x00\x00\x00\x00\x00\x00\x00\xe8\xcbv?\x00\x00\x00\x00\x00\x00\x00\x00\xaeGa>\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\xfa\xff\x02\x00\xfc\xff\xfc\xff\x00\x00\xfc\xff\xf8\xff\xf8\xff\xf9\xff\xf5\xff\xf3\xff\xfa\xff\xf5\xff\xf7\xff\xf2\xff\xf9\xff\xfe\xff\xfe\xff\x06\x00\r\x00\xf8\xff\x08\x00\x00\x00\x08\x00\x03\x00\x0c\x00\x05\x00\x08\x00\n\x00\x04\x00\x02\x00\x02\x00\x05\x00\x08\x00\xfd\xff\x07\x00\x08\x00\x02\x00\x02\x00\xff\xff\xff\xff\x02\x00\xff\xff\n\x00\x04\x00\x02\x00\x0b\x00\x02\x00\x07\x00\xff\xff\t\x00\x01\x00\xff\xff\t\x00\x03\x00\x06\x00\x06\x00\x00\x00\x00\x00\x02\x00\x01\x00\xfb\xff\x02\x00\xff\xff\x06\x00\xfa\xff\xf8\xff\xf9\xff\xfc\xff\xff\xff\xf7\xff\xfc\xff\xfd\xff\x04\x00\xfc\xff\r\x00\n\x00\x04\x00\r\x00\x08\x00\n\x00\x0c\x00\r\x00\x08\x00\r\x00\x0f\x00\x03\x00\x08\x00\x01\x00\x0c\x00\t\x00\x06\x00\n\x00\x07\x00\r\x00\x13\x00\x08\x00\x06\x00\x07\x00\x0c\x00\x0b\
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j2/btvpfzmj4qz1wgrt07rpzszr0000gn/T/ipykernel_7996/391604064.py in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data
# Out:
# bytearray(b'\x00\x00\x80B\x00\x00\x00G\x00\x00\x80?\x00\x00\x80?\x00\x00\x00D\x00\x00\x00\x00(k\xeeI\x00\x00@A\x00\x00\x00\x00\x00\x00\x00\x00\xe8\xcbv?\x00\x00\x00\x00\x00\x00\x00\x00\xaeGa>\x00\x00\x00\x00\x00\x00\x00\x00\x05\x00\xfa\xff\x02\x00\xfc\xff\xfc\xff\x00\x00\xfc\xff\xf8\xff\xf8\xff\xf9\xff\xf5\xff\xf3\xff\xfa\xff\xf5\xff\xf7\xff\xf2\xff\xf9\xff\xfe\xff\xfe\xff\x06\x00\r\x00\xf8\xff\x08\x00\x00\x00\x08\x00\x03\x00\x0c\x00\x05\x00\x08\x00\n\x00\x04\x00\x02\x00\x02\x00\x05\x00\x08\x00\xfd\xff\x07\x00\x08\x00\x02\x00\x02\x00\xff\xff\xff\xff\x02\x00\xff\xff\n\x00\x04\x00\x02\x00\x0b\x00\x02\x00\x07\x00\xff\xff\t\x00\x01\x00\xff\xff\t\x00\x03\x00\x06\x00\x06\x00\x00\x00\x00\x00\x02\x00\x01\x00\xfb\xff\x02\x00\xff\xff\x06\x00\xfa\xff\xf8\xff\xf9\xff\xfc\xff\xff\xff\xf7\xff\xfc\xff\xfd\xff\x04\x00\xfc\xff\r\x00\n\x00\x04\x00\r\x00\x08\x00\n\x00\x0c\x00\r\x00\x08\x00\r\x00\x0f\x00\x03\x00\x08\x00\x01\x00\x0c\x00\t\x00\x06\x00\n\x00\x07\x00\r\x00\x13\x00\x08\x00\x06\x00\x07\x00\x0
# ...

# %%
packet
# Out:
# b'\x00\x00\x80B\x00\x00\x00G\x00\x00\x80?\x00\x00\x80?\x00\x00\x00D\x00\x00\x00\x00(k\xeeI\x00\x00@A\x00\x00\x00\x00\x00\x00\x00\x00\xe8\xcbv?\x00\x00\x00\x00\x00\x00\x00\x00\xaeGa>\
# ...

# %%
import struct
print(len(packet))

for i in struct.iter_unpack('!I', packet[]):
    print(i)
# Out:
# 1024
# (32834,)
# (71,)
# (32831,)
# (32831,)
# (68,)
# (0,)
# (678161993,)
# (16449,)
# (0,)
# (0,)
# (3905648191,)
# (0,)
# (0,)
# (2923913534,)
# (0,)
# (0,)
# (4127193087,)
# (4026527743,)
# (3959420159,)
# (3959417855,)
# (3959422975,)
# (4009750527,)
# (4160744959,)
# (4160746751,)
# (4160747519,)
# (4244633599,)
# (4076861695,)
# (4244634623,)
# (4244571648,)
# (4227857151,)
# (4194302719,)
# (4227794176,)
# (4261412095,)
# (4160748543,)
# (33618431,)
# (4127193599,)
# (4244633599,)
# (4211076607,)
# (4194301695,)
# (4244633855,)
# (4160749055,)
# (4110416383,)
# (4177523455,)
# (4060082943,)
# (4009748991,)
# (4026527743,)
# (3992973311,)
# (4043307007,)
# (4009752063,)
# (4211078911,)
# (4127191295,)
# (4060083199,)
# (4060083711,)
# (4160744447,)
# (4043305215,)
# (3925864959,)
# (4127190783,)
# (4127193087,)
# (4160746495,)
# (4160745983,)
# (4060083199,)
# (4160745471,)
# (4060084735,)
# (4244634111,)
# (4043305471,)
# (4076860415,)
# (4009750271,)
# (3976193791,)
# ...

# %%
import struct
print(len(packet))

data = packet[64:]
len(data)
# Out:
# 1024
# 960

# %%
960/2
# Out:
# 480.0

# %%
for i in struct.iter_unpack('!h', data):
    print(i)
# Out:
# (-2561,)
# (-2049,)
# (-4097,)
# (-4097,)
# (-5121,)
# (-2817,)
# (-5121,)
# (-5121,)
# (-5121,)
# (-1,)
# (-4353,)
# (-4097,)
# (-2049,)
# (-4609,)
# (-2049,)
# (-2817,)
# (-2049,)
# (-2049,)
# (-769,)
# (-2049,)
# (-3329,)
# (-1793,)
# (-769,)
# (-1025,)
# (-769,)
# (1536,)
# (-1025,)
# (-1281,)
# (-1537,)
# (-1281,)
# (-1025,)
# (1280,)
# (-513,)
# (-769,)
# (-2049,)
# (-1025,)
# (512,)
# (-1537,)
# (-2561,)
# (-1537,)
# (-769,)
# (-2049,)
# (-1281,)
# (-4609,)
# (-1537,)
# (-2305,)
# (-769,)
# (-1793,)
# (-2049,)
# (-513,)
# (-2817,)
# (-1537,)
# (-1793,)
# (-3329,)
# (-3585,)
# (-3329,)
# (-4353,)
# (-5633,)
# (-4097,)
# (-4097,)
# (-4609,)
# (-4097,)
# (-3841,)
# (-2049,)
# (-4353,)
# (-2561,)
# (-1281,)
# (-2305,)
# (-2561,)
# (-3841,)
# (-3585,)
# (-3073,)
# (-3585,)
# (-2561,)
# (-2049,)
# (-5121,)
# (-3841,)
# (-3841,)
# (-5633,)
# (-3585,)
# (-2561,)
# (-4353,)
# (-2561,)
# (-2049,)
# (-2049,)
# (-3073,)
# (-2049,)
# (-3585,)
# (-3585,)
# (-3073,)
# (-2049,)
# (-4097,)
# ...

# %%
len(packet)
# Out:
# 1024

# %%
struct.unpack('!i', packet[4:8])
# Out:
# (71,)

# %%
struct.unpack('!I', packet[4:8])
# Out:
# (71,)

# %%
struct.unpack('!l', packet[4:8])
# Out:
# (71,)

# %%
struct.unpack('!L', packet[4:8])
# Out:
# (71,)

# %%
for i in struct.iter_unpack('!l', packet[:64]):
    print(i)
# Out:
# (32834,)
# (71,)
# (32831,)
# (32831,)
# (68,)
# (0,)
# (678161993,)
# (16449,)
# (0,)
# (0,)
# (-389319105,)
# (0,)
# (0,)
# (-1371053762,)
# (0,)
# (0,)

# %%
import socket



buffer_size = 65536

msg_from_client = "-a 1"

bytes_to_send = str.encode(msg_from_client)

server_address_port = ("192.168.178.25", 61231)


# Create a UDP socket at client side
udp_client_socket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

# Send to server using created UDP socket

udp_client_socket.sendto(bytes_to_send, server_address_port)

packet = udp_client_socket.recv(buffer_size)

print(len(packet))

udp_client_socket.close()
# Out:
# 32832

# %%
header = packet[:64]

# %%
for i in struct.iter_unpack('!i', packet[:8]):
    print(i)
# Out:
# (32834,)
# (71,)

# %%
header_length = struct.unpack('!l', packet[:4])[0]

# %%
header_length
# Out:
# 32834

# %%
header_buffer = packet[0:header_length]

# %%
data_buffer = packet[header_length:]

# %%
type(packet[:4])
# Out:
# bytes

# %%
type(header_length)
# Out:
# tuple

# %%
header_length
# Out:
# 32834

# %%
len(data_buffer)
# Out:
# 0

# %%
len(header_buffer)
# Out:
# 32832

# %%
import sys

# %%
sys.byteorder
# Out:
# 'little'

# %%
type(packet)
# Out:
# bytes

# %%
len(packet)
# Out:
# 32832

# %%
l = []
for i in struct.iter_unpack('@f', packet[:64]):
    l.append(i)
print(l)
# Out:
# [(64.0,), (32768.0,), (1.0,), (1.0,), (512.0,), (0.0,), (1953125.0,), (12.0,), (0.0,), (0.0,), (0.29069042205810547,), (0.0,), (0.0,), (0.2199999988079071,), (0.0,), (0.0,)]

# %%
l = []
for i in struct.iter_unpack('@h', packet[64:]):
    l.append(i)
print(l)
# Out:
# [(-36,), (-27,), (-28,), (-28,), (-26,), (-24,), (-21,), (-34,), (-36,), (-31,), (-25,), (-25,), (-27,), (-38,), (-33,), (-33,), (-38,), (-28,), (-29,), (-30,), (-26,), (-29,), (-25,), (-36,), (-32,), (-33,), (-29,), (-27,), (-32,), (-21,), (-26,), (-20,), (-24,), (-30,), (-15,), (-26,), (-23,), (-25,), (-26,), (-21,), (-24,), (-20,), (-19,), (-22,), (-24,), (-15,), (-23,), (-18,), (-21,), (-15,), (-21,), (-22,), (-26,), (-18,), (-22,), (-23,), (-18,), (-15,), (-15,), (-18,), (-11,), (-25,), (-15,), (-19,), (-24,), (-18,), (-23,), (-24,), (-21,), (-20,), (-30,), (-26,), (-24,), (-27,), (-28,), (-32,), (-22,), (-29,), (-26,), (-27,), (-34,), (-30,), (-33,), (-29,), (-32,), (-28,), (-28,), (-32,), (-19,), (-10,), (-19,), (-20,), (-18,), (-9,), (-29,), (-21,), (-20,), (-19,), (-17,), (-20,), (-20,), (-27,), (-22,), (-8,), (-19,), (-9,), (-11,), (-12,), (-10,), (-15,), (-13,), (-14,), (-15,), (-10,), (-19,), (-14,), (-16,), (-19,), (-9,), (-15,), (-19,), (-9,), (-15,), (-9,), (-5,), (-10
# ...

# %%
print(len(l))
# Out:
# 16384

# %%
for i in struct.iter_unpack('n', packet[64:]):
    print(i)
# Out:
# (-5066626890989585,)
# (-6192552567701523,)
# (-4785207748788249,)
# (-5066609711251478,)
# (-7318443885658144,)
# (-8162894585004061,)
# (-8725891783917594,)
# (-5348114753454105,)
# (-4503659757436937,)
# (-5348084688158741,)
# (-2814818488090642,)
# (-3659226237763601,)
# (-3940701214408718,)
# (-3096263399112711,)
# (-3377759851118611,)
# (-2814784127434763,)
# (-4222193371447311,)
# (-5629572549509132,)
# (-3940735574474769,)
# (-4503638282600469,)
# (-5629581139640339,)
# (-4222159011315733,)
# (-3940684034211859,)
# (-3377734080790541,)
# (-2814797012271124,)
# (-2251847058522127,)
# (-1125895612792841,)
# (-1125904202465290,)
# (-2251816994471947,)
# (-2533317740789775,)
# (-1688884220395529,)
# (-1970311952531469,)
# (-2251859943555085,)
# (-2814779832533004,)
# (-2814809897566226,)
# (-844502240460816,)
# (-2251799814602767,)
# (-3096267694276613,)
# (-1688884220526600,)
# (1407340523552766,)
# (-2251834173947912,)
# (-2533313445101566,)
# (1125908496842752,)
# ...

# %%
header_length = struct.unpack('!l', packet[:4])[0]

# %%
packet
# Out:
# b'\x00\x00\x80B\x00\x00\x00G\x00\x00\x80?\x00\x00\x80?\x00\x00\x00D\x00\x00\x00\x00(k\xeeI\x00\x00@A\x00\x00\x00\x00\x00\x00\x00\x00`\xd5\x94>\x00\x00\x00\x00\x00\x00\x00\x00\xaeGa>\
# ...

# %%
struct.unpack('ccc', packet[:3])
# Out:
# (b'\x00', b'\x00', b'\x80')

# %%
data = [i[0] for i in l]

# %%
len(data)
# Out:
# 16384

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data)
