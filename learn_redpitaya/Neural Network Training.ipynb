# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler

# Read CSV file into a Pandas dataframe
data = pd.read_csv("final_dataframe_complete_experiment.csv", header=None)

# Split features and target variable
X = data.iloc[:, 1:]
y = data.iloc[:, 0]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=23)

# Preprocess data by scaling the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Define a neural network model
model = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=1000)

# Define hyperparameters to tune using GridSearchCV
param_grid = {
    'hidden_layer_sizes': [(100,), (50, 50), (100, 50), (64, 64, 64)],
    'activation': ['relu', 'tanh', 'logistic'],
    'alpha': [0.0001, 0.001, 0.01],
}

# Perform hyperparameter tuning using GridSearchCV
grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)

# Print the best hyperparameters and score
print("Best hyperparameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Train the model with the best hyperparameters on the full dataset
best_model = MLPClassifier(hidden_layer_sizes=grid_search.best_params_['hidden_layer_sizes'],
                           activation=grid_search.best_params_['activation'],
                           alpha=grid_search.best_params_['alpha'],
                           max_iter=500)
best_model.fit(X, y)
# Out:
# /Users/bisalgt/Projects/playground/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/bisalgt/Projects/playground/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/bisalgt/Projects/playground/env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best hyperparameters: {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100,)}
# Best score: 0.8740276869865827
# MLPClassifier(activation='logistic', alpha=0.01, max_iter=500)

# %%
# Train the model with the best hyperparameters on the full dataset
best_model = MLPClassifier(hidden_layer_sizes=grid_search.best_params_['hidden_layer_sizes'],
                           activation=grid_search.best_params_['activation'],
                           alpha=grid_search.best_params_['alpha'],
                           max_iter=500)
best_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.01, max_iter=500)

# %%
# Train the model with the best hyperparameters on the full dataset
best_model = MLPClassifier(hidden_layer_sizes=grid_search.best_params_['hidden_layer_sizes'],
                           activation=grid_search.best_params_['activation'],
                           alpha=grid_search.best_params_['alpha'],
                           max_iter=500, 
                          learning_rate="adaptive")
best_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.01, learning_rate='adaptive',
#               max_iter=500)

# %%
ytrain_pred = best_model.predict_proba(X_train)
print('MLP train roc-auc: {}'.format(roc_auc_score(y_train, ytrain_pred[:,1])))
ytest_pred = best_model.predict_proba(X_test)
print('MLP test roc-auc: {}'.format(roc_auc_score(y_test, ytest_pred[:,1])))
# Taking prediciton of positive class only
ytest_pred = ytest_pred[:, 1]
auc_score = roc_auc_score(y_test, ytest_pred)
#Confusion Matrix
y_pred = best_model.predict(X_test)
mlp_conf_matx = confusion_matrix(y_test, y_pred)
mlp_f1_score = f1_score(y_test, y_pred)
print("Confusion Matrix : ", mlp_conf_matx)
print("Precision Score : ", precision_score(y_test, y_pred))
print("Recall Score : ", recall_score(y_test, y_pred))
print("Accuracy Score : ", accuracy_score(y_test, y_pred))
print("F1 Score : ", mlp_f1_score)
# summarize scores
mlp_fpr, mlp_tpr, thresholds5 = roc_curve(y_test, ytest_pred)
# Out:
# MLP train roc-auc: 0.9834508635423896
# MLP test roc-auc: 0.9460604244025135
# Confusion Matrix :  [[16554  3074]
#  [ 1550 18504]]
# Precision Score :  0.8575400871257762
# Recall Score :  0.9227086865463249
# Accuracy Score :  0.8834736152411673
# F1 Score :  0.8889315910837816

# %%
# After the learning_rate is adaptive
ytrain_pred = best_model.predict_proba(X_train)
print('MLP train roc-auc: {}'.format(roc_auc_score(y_train, ytrain_pred[:,1])))
ytest_pred = best_model.predict_proba(X_test)
print('MLP test roc-auc: {}'.format(roc_auc_score(y_test, ytest_pred[:,1])))
# Taking prediciton of positive class only
ytest_pred = ytest_pred[:, 1]
auc_score = roc_auc_score(y_test, ytest_pred)
#Confusion Matrix
y_pred = best_model.predict(X_test)
mlp_conf_matx = confusion_matrix(y_test, y_pred)
mlp_f1_score = f1_score(y_test, y_pred)
print("Confusion Matrix : ", mlp_conf_matx)
print("Precision Score : ", precision_score(y_test, y_pred))
print("Recall Score : ", recall_score(y_test, y_pred))
print("Accuracy Score : ", accuracy_score(y_test, y_pred))
print("F1 Score : ", mlp_f1_score)
# summarize scores
mlp_fpr, mlp_tpr, thresholds5 = roc_curve(y_test, ytest_pred)
# Out:
# MLP train roc-auc: 0.9784753124791414
# MLP test roc-auc: 0.9442207359672394
# Confusion Matrix :  [[16874  2754]
#  [ 2115 17939]]
# Precision Score :  0.8669115159715846
# Recall Score :  0.8945347561583724
# Accuracy Score :  0.8772995312736254
# F1 Score :  0.8805065403587994

# %%
# Train the model with the best hyperparameters on the full dataset
best_model = MLPClassifier(hidden_layer_sizes=(128, 128, 128, 128),
                           activation="relu",
                           alpha=0.01,
                           max_iter=1000, 
                          learning_rate="adaptive",
                          batch_size=32)
best_model.fit(X_train, y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=32,
#               hidden_layer_sizes=(128, 128, 128, 128), learning_rate='adaptive',
#               max_iter=1000)

# %%
# After the learning_rate is adaptive
ytrain_pred = best_model.predict_proba(X_train)
print('MLP train roc-auc: {}'.format(roc_auc_score(y_train, ytrain_pred[:,1])))
ytest_pred = best_model.predict_proba(X_test)
print('MLP test roc-auc: {}'.format(roc_auc_score(y_test, ytest_pred[:,1])))
# Taking prediciton of positive class only
ytest_pred = ytest_pred[:, 1]
auc_score = roc_auc_score(y_test, ytest_pred)
#Confusion Matrix
y_pred = best_model.predict(X_test)
mlp_conf_matx = confusion_matrix(y_test, y_pred)
mlp_f1_score = f1_score(y_test, y_pred)
print("Confusion Matrix : ", mlp_conf_matx)
print("Precision Score : ", precision_score(y_test, y_pred))
print("Recall Score : ", recall_score(y_test, y_pred))
print("Accuracy Score : ", accuracy_score(y_test, y_pred))
print("F1 Score : ", mlp_f1_score)
# summarize scores
mlp_fpr, mlp_tpr, thresholds5 = roc_curve(y_test, ytest_pred)
# Out:
# MLP train roc-auc: 0.993666083078636
# MLP test roc-auc: 0.9521337426649289
# Confusion Matrix :  [[16995  2633]
#  [ 1707 18347]]
# Precision Score :  0.8744995233555768
# Recall Score :  0.9148798244739205
# Accuracy Score :  0.8906305125749711
# F1 Score :  0.8942340498123508

# %%
# Read CSV file into a Pandas dataframe
data = pd.read_csv("final_dataframe_complete_experiment.csv", header=None)

# Split features and target variable
X = data.iloc[:, 1:]
y = data.iloc[:, 0]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=23)

# Preprocess data by scaling the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train the model with the best hyperparameters on the full dataset
best_model = MLPClassifier(hidden_layer_sizes=(64, 64, 64),
                           activation="relu",
                           alpha=0.01,
                           max_iter=1000, 
                          learning_rate="adaptive",
                          batch_size=32)
best_model.fit(X_train, y_train)

# After the learning_rate is adaptive
ytrain_pred = best_model.predict_proba(X_train)
print('MLP train roc-auc: {}'.format(roc_auc_score(y_train, ytrain_pred[:,1])))
ytest_pred = best_model.predict_proba(X_test)
print('MLP test roc-auc: {}'.format(roc_auc_score(y_test, ytest_pred[:,1])))
# Taking prediciton of positive class only
ytest_pred = ytest_pred[:, 1]
auc_score = roc_auc_score(y_test, ytest_pred)
#Confusion Matrix

# Set a threshold of 0.6 for class 1
y_pred = (ytest_pred[:, 1] > 0.6).astype(int)
mlp_conf_matx = confusion_matrix(y_test, y_pred)
mlp_f1_score = f1_score(y_test, y_pred)
# Calculate the confusion matrix and ROC AUC score
cm = confusion_matrix(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

# Calculate the false positive rate, true positive rate, and thresholds for the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# Define a figure with three subplots
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))

# Plot the confusion matrix in the first subplot
axs[0].matshow(cm, cmap=plt.cm.Blues)
axs[0].set_xlabel('Predicted')
axs[0].set_ylabel('True')
axs[0].set_xticklabels([''] + ['0', '1'])
axs[0].set_yticklabels([''] + ['0', '1'])

plt.show()
# Out:
# MLP train roc-auc: 0.9870564332873786
# MLP test roc-auc: 0.9535341166264509
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 36
#      32 auc_score = roc_auc_score(y_test, ytest_pred)
#      33 #Confusion Matrix
#      34
#      35 # Set a threshold of 0.6 for class 1
# ---> 36 y_pred = (ytest_pred[:, 1] > 0.6).astype(int)
#      37 mlp_conf_matx = confusion_matrix(y_test, y_pred)
#      38 mlp_f1_score = f1_score(y_test, y_pred)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
import tensorflow as tf

cifar = tf.keras.datasets.cifar100
(x_train, y_train), (x_test, y_test) = cifar.load_data()
model = tf.keras.applications.ResNet50(
    include_top=True,
    weights=None,
    input_shape=(32, 32, 3),
    classes=100,)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(optimizer="adam", loss=loss_fn, metrics=["accuracy"])
model.fit(x_train, y_train, epochs=5, batch_size=64)
# Out:
# ...
# 169001437/169001437 [==============================] - 7s 0us/step
# Metal device set to: Apple M1
# 2023-03-25 10:18:03.999822: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-25 10:18:04.000234: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/5
# 2023-03-25 10:18:05.540258: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# ...

# %%
# !pip install --upgrade numpy
# Out:
# ...
#   Using cached numpy-1.24.2-cp310-cp310-macosx_11_0_arm64.whl (13.9 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.3
#     Uninstalling numpy-1.22.3:
#       Successfully uninstalled numpy-1.22.3
# ...
