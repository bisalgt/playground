# %%
def acmTeam(topic):
    indx = []
    teams = []
    for i in topic:
        ind2 = []
        for p in range(len(i)):
            if i[p] == '1':
                ind2.append(p)
        indx.append(ind2)
    
    for p1 in range(len(topic)):
        
        for p2 in range(p1,len(topic)):
            if [p1, p2] not in teams and p1 != p2:
                teams.append([p1,p2])
    print(teams)
    print(indx)
    
acmTeam(['11', '22', '33', '44'])
# Out:
# [[0, 1], [0, 2], [0, 3], [1, 2], [1, 3], [2, 3]]
# [[0, 1], [], [], []]

# %%
'abcaade'.count('a')
# Out:
# 3

# %%
a = 'abc'
a[2]
# Out:
# 'c'

# %%
import concurrent.futures 
def acmTeam(topic):
    indx = []
    
    
    def fun1():
        global indx
        for i in topic:
            ind2 = []
            for p in range(len(i)):
                if i[p] == '1':
                    ind2.append(p)
            indx.append(ind2)
    def fun2():
        teams = []
        
        for p1 in range(len(topic)):
            for p2 in range(p1,len(topic)):
                if [p1, p2] not in teams and p1 != p2:
                    teams.append([p1,p2])
    
    with concurrent.futures.ProcessPoolExecutor() as executor:
        t1 = executor.submit(fun1)
        t2 = executor.submit(fun2)

#     import multiprocessing

#     p1 =multiprocessing.Process(target=fun1)
#     p2 = multiprocessing.Process(target=fun2)
#     p1.start()
#     p2.start()
#     p1.join()
#     p2.join()
    
#     print(t1, t2)
    print(indx)
    

    total_max_teams = 0
    max_topics = len(indx[0])
#     count_max = 0
    for i,j in teams:
        
        count = len(set(indx[i]+indx[j]))
        
        if count >= max_topics:
            max_topics = count
        else:
            teams.remove([i,j])
    
    
    for i,j in teams:
        
        count = len(set(indx[i]+indx[j]))
        if count >= max_topics:
            total_max_teams += 1
    
    print(teams)
    print(indx)
    print(max_topics, total_max_teams)
            
        
    
    
acmTeam(['10101', '11100', '11010', '00101'])

# %%
len((1,2,2))
# Out:
# 3

# %%
def acmTeam(topic):
    indx = []
    teams = []
    for i in topic:
        ind2 = []
        for p in range(len(i)):
            if i[p] == '1':
                ind2.append(p)
        indx.append(ind2)
    
    for p1 in range(len(topic)):    
        for p2 in range(p1,len(topic)):
            if [p1, p2] not in teams and p1 != p2:
                teams.append([p1,p2])
    print(teams)
    print(indx)
    
    total_max_teams = 0
    max_topics = len(indx[0])
#     count_max = 0
    for i,j in teams:
        
        count = len(set(indx[i]+indx[j]))
        
        if count >= max_topics:
            max_topics = count
        else:
            teams.remove([i,j])
    
    
    for i,j in teams:
        
        count = len(set(indx[i]+indx[j]))
        if count >= max_topics:
            total_max_teams += 1
        
    
    
    # print(max_topics)
    # print(total_max_teams)
    return max_topics, total_max_teams
acmTeam(['10101', '11100', '11010', '00101'])
# Out:
# [[0, 1], [0, 2], [0, 3], [1, 2], [1, 3], [2, 3]]
# [[0, 2, 4], [0, 1, 2], [0, 1, 3], [2, 4]]
# (5, 2)

# %%
def acmTeam(topic):
    teams = []
    sub_counts = []
    
    for p1 in range(len(topic)):    
        for p2 in range(p1,len(topic)):
            c = 0
            if [p1, p2] not in teams and p1 != p2:
                
                teams.append([p1,p2])
                
                s = (int(topic[p1])+int(topic[p2]))
                c = str(s).count('1') + str(s).count('2')
#                 print(c)
                
            sub_counts.append(c)
        
#     print(sub_counts)
#     print(teams)
    m = max(sub_counts)
    
    st = ''.join(f'{sub_counts}')
    print('--',st)
    c = st.count(f'{m}')
    return m,c         

#     return max_topics, total_max_teams
acmTeam(['11101', '10101', '11001', '10111', '10000', '01110'])
# Out:
# -- [0, 4, 4, 5, 4, 5, 0, 4, 4, 3, 5, 0, 5, 3, 5, 0, 4, 5, 0, 4, 0]
# (5, 6)

# %%
import time
start = time.perf_counter()
a = 11011
b = 10000
print(str(a+b))
c = a+b
str(c).count('2')+str(c).count('1')
stop ==
# Out:
# 21011
# 4

# %%
a = bin(11011)
b = bin(10000)
# a|b
print(type(a), type(b))
print((a), b)
print(a|b)
# Out:
# <class 'str'> <class 'str'>
# 0b10101100000011 0b10011100010000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-a1cd911dfd56> in <module>
#       4 print(type(a), type(b))
#       5 print((a), b)
# ----> 6 print(a|b)
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %%
import requests
from bs4 import BeautifulSoup
data = requests.get('https://hr-testcases-us-east-1.s3.amazonaws.com/3179/input05.txt?AWSAccessKeyId=AKIAJ4WZFDFQTZRGO3QA&Expires=1589613847&Signature=yuDrwZDzEuvEgr5U0xQRlgq%2Bcao%3D&response-content-type=text%2Fplain').content
d = BeautifulSoup(data)
d
# Out:
# <?xml version="1.0" encoding="UTF-8"?><html><body><error><code>AccessDenied</code><message>Request has expired</message><expires>2020-05-16T07:24:07Z</expires><servertime>2020-05-16T07:34:04Z</servertime><requestid>15FA918166183230</requestid><hostid>MhZZGOB8hkQEYoNRYT6auHAhifrZe26VGpqNMspSBesuewZdI5Rzo/2tJ0hh40IfswceZGcxY0A=</hostid></error></body></html>

# %%


# %%
import collections
def acmTeam(topic):
    teams = []
    sub_counts = []
    
    for p1 in range(len(topic)):    
        for p2 in range(p1,len(topic)):
            c = 0
            if [p1, p2] not in teams and p1 != p2:
                
                teams.append([p1,p2])
                
                s = (int(topic[p1])+int(topic[p2]))
                ct = collections.Counter(str(s))
                c = ct['1'] + ct['2']
#                 print(c)
                
            sub_counts.append(c)
        
#     print(sub_counts)
#     print(teams)
    m = max(sub_counts)
    
    st = ''.join(f'{sub_counts}')
    print('--',st)
    c = st.count(f'{m}')
    return m,c         

#     return max_topics, total_max_teams
acmTeam(['11101', '10101', '11001', '10111', '10000', '01110'])
# Out:
# -- [0, 4, 4, 5, 4, 5, 0, 4, 4, 3, 5, 0, 5, 3, 5, 0, 4, 5, 0, 4, 0]
# (5, 6)

# %%
import collections

a = '12321231231232'
c = collections.Counter(a)
c['1']+c['2']
# Out:
# 10
