# %%
import pandas as pd

melb_data = pd.read_csv('datas/melb_data.csv')

# %%
melb_data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
X = melb_data.Landsize

# %%
y = melb_data.Price

# %%
import matplotlib.pyplot as plt

# %%
X.shape
# Out:
# (13580,)

# %%
X = X[X.notna()]

# %%
X.shape
# Out:
# (13580,)

# %%
y.shape
# Out:
# (13580,)

# %%
y = y[y.notna()]

# %%
y.shape
# Out:
# (13580,)

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot(X, y, 'r+')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.arange(30).reshape(5,6), index=list('abcde'), columns=list('qwerty'))

# %%
df.loc['a']
# Out:
# q    0
# w    1
# e    2
# r    3
# t    4
# y    5
# Name: a, dtype: int64

# %%
df.iloc[0]
# Out:
# q    0
# w    1
# e    2
# r    3
# t    4
# y    5
# Name: a, dtype: int64

# %%
# Data Loading Code Hidden Here
import pandas as pd

# Load data
melbourne_file_path = 'datas/melb_data.csv'
melbourne_data = pd.read_csv(melbourne_file_path) 
# Filter rows with missing price values
filtered_melbourne_data = melbourne_data.dropna(axis=0)
# Choose target and features
y = filtered_melbourne_data.Price
melbourne_features = ['Rooms', 'Bathroom', 'Landsize', 'BuildingArea', 
                        'YearBuilt', 'Lattitude', 'Longtitude']
X = filtered_melbourne_data[melbourne_features]

from sklearn.tree import DecisionTreeRegressor
# Define model
melbourne_model = DecisionTreeRegressor()
# Fit model
melbourne_model.fit(X, y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
from sklearn.metrics import mean_absolute_error

predicted_home_prices = melbourne_model.predict(X)
mean_absolute_error(y, predicted_home_prices)
# Out:
# 434.71594577146544

# %% [raw]
# For dividing the data to training and testing data we use train test split from sklearn model selection so that it would be more generic practically

# %%
from sklearn.model_selection import train_test_split

# split data into training and validation data, for both features and target
# The split is based on a random number generator. Supplying a numeric value to
# the random_state argument guarantees we get the same split every time we
# run this script.
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
# Define model
melbourne_model = DecisionTreeRegressor()
# Fit model
melbourne_model.fit(train_X, train_y)

# get predicted prices on validation data
val_predictions = melbourne_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 259703.6223369916

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  347380
# Max leaf nodes: 50  		 Mean Absolute Error:  258171
# Max leaf nodes: 500  		 Mean Absolute Error:  243495
# Max leaf nodes: 5000  		 Mean Absolute Error:  254983

# %%
a = [1,2,3]
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# # Random forest model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

forest_model = RandomForestRegressor(random_state=1)
forest_model.fit(train_X, train_y)
melb_preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, melb_preds))
# Out:
# 191669.7536453626

# %%
import pandas as pd

# %%
df = pd.read_csv('datas/melb_data.csv')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13580, step=1)

# %%
data = """
a, b, c
1, 2, 3
4, 5, 6
"""

# %%
from io import StringIO

# %%
StringIO(data)

# %%
df = pd.read_csv(StringIO(data), index_col=0)

# %%
df
# Out:
#     b   c
# a
# 1   2   3
# 4   5   6

# %%
pd.read_csv(StringIO(data))
# Out:
#    a   b   c
# 0  1   2   3
# 1  4   5   6

# %%
pd.read_csv(StringIO(data), index_col=None)
# Out:
#    a   b   c
# 0  1   2   3
# 1  4   5   6

# %%
pd.read_csv()

# %%
data = """
a, b, c
1, "****2", 3
4, 5, 6
"""

# %%
pd.read_csv(StringIO(data), index_col=None, escapechar='*')
# Out:
#    a       b   c
# 0  1   "**2"   3
# 1  4       5   6

# %%
a = ['name', 'age', 'salary']
b = [['bishal', 23, 23333], ['hemant', 33, 232323], ['manish', 32, 323232]]

# %%
d = dict(zip(a, i) for i in b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-eaa7ce841914> in <module>
# ----> 1 d = dict(zip(a, i) for i in b)
#
# ValueError: dictionary update sequence element #0 has length 3; 2 is required

# %%
d = [dict(zip(a, i)) for i in b]

# %%
d = pd.read_html('https://www.worldometers.info/coronavirus/', match='Total Cases')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-53-e08e33a25075> in <module>
# ----> 1 d = pd.read_html('https://www.worldometers.info/coronavirus/', match='Total Cases')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     893
#     894         try:
# --> 895             tables = p.parse_tables()
#     896         except ValueError as caught:
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.arange(10)

# %%
y = np.arange(11,21)

# %%
plt.scatter(x, y)

# %%
plt.scatter(x, y, c='r')

# %%
plt.scatter(x, y, c='r')
plt.xlabel('X axis')
plt.ylabel('y axis')
plt.title('Graph no 1')
# Out:
# Text(0.5, 1.0, 'Graph no 1')

# %%
plt.savefig('graph1scatterplt.png')

# %%
plt.plot(x, y)

# %%
y = x**2

# %%
plt.plot(x, y)

# %%
plt.plot(x, y, 'r')

# %%
plt.plot(x, y, 'r--')

# %%
plt.plot(x, y, 'ro')

# %%
plt.plot(x, y, 'ro--')

# %%
plt.plot(x, y, 'r', linestyle='dashed')

# %%
plt.plot(x, y, 'r', linewidth=2)

# %%
plt.plot(x, y, 'r', linewidth=2, markersize=12)

# %%
plt.plot(x, y , 'r*', linestyle='dashed', markersize=14)

# %% [raw]
# scatter creates scatter plot
# plot creates smooth line, can be changed as above

# %% [markdown]
# ## creating subplots

# %%
plt.subplot(2,2,1)
plt.plot(x, y, 'r')
plt.subplot(2,2,4)
plt.plot(x, y, 'g')

# %%
x = np.arange(0, 4*np.pi, 0.1)
y = np.sin(x)

plt.plot(x,y, 'r')

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 200 artists>

# %%
x = np.arange(10)

# %%
y = np.arange(11,21)

# %%
plt.bar(x,y, color='r')
# Out:
# <BarContainer object of 10 artists>

# %%
x = 10*np.floor(np.random.randn(6,1))

# %%
plt.hist(x)
# Out:
# (array([1., 0., 0., 2., 0., 0., 1., 0., 0., 2.]),
#  array([-20., -17., -14., -11.,  -8.,  -5.,  -2.,   1.,   4.,   7.,  10.]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe54665fe50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe545c91c90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fe54665fd10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe54644a6d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe54644ac10>],
#  'means': []}

# %%
d = pd.DataFrame(x)

# %%
d.describe()
# Out:
#                0
# count   6.000000
# mean   -3.333333
# std    12.110601
# min   -20.000000
# 25%   -10.000000
# 50%    -5.000000
# 75%     7.500000
# max    10.000000

# %%
plt.boxplot(x, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe545e91610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe545e915d0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7fe546315450>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe548d02490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe546136d90>],
#  'means': []}

# %%
plt.boxplot(x, vert=False, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe545ec2ed0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fe545e31690>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7fe545ec2610>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe545ec2f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe545e0d5d0>],
#  'means': []}

# %%
labels = ['ruby', 'python', 'c++', 'javascript']

sizes = [222, 333, 121, 300]
colors = ['gold', 'red', 'lightcoral', 'yellow']

explode = (0.1,0,0,0.2)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, shadow=True, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe5466309d0>,
# ...
#  [Text(0.9064394367841722, 0.7863634957463328, 'ruby'),
#   Text(-0.8819437828153657, 0.657400307235495, 'python'),
#   Text(-0.7497953209280472, -0.8048645704181586, 'c++'),
#   Text(0.7395433607960018, -1.069147144925597, 'javascript')],
#  [Text(0.5287563381241004, 0.4587120391853608, '22.7%'),
#   Text(-0.48106024517201756, 0.3585819857648154, '34.1%'),
#   Text(-0.408979265960753, -0.43901703840990464, '12.4%'),
#   Text(0.4551036066436934, -0.657936704569598, '30.7%')])
