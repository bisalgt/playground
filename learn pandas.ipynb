# %%
import pandas as pd

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %% [raw]
# Series
# A Series, is a sequence of data values. If a DataFrame is a table, a Series is a list. And in fact you can create one with nothing more than a list:

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [raw]
# A Series is, in essence, a single column of a DataFrame. So you can assign column values to the Series the same way as before, using an index parameter. However, a Series does not have a column name, it only has one overall name

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [raw]
# The pd.read_csv() function is well-endowed, with over 30 optional parameters you can specify. For example, you can see in this dataset that the CSV file has a built-in index, which pandas did not pick up on automatically. To make pandas use that column for the index (instead of creating a new one from scratch), we can specify an index_col.

# %%
pd.DataFrame({'apples': 50, 'banans': 34})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-51853692c1d0> in <module>
# ----> 1 pd.DataFrame({'apples': 50, 'banans': 34})
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ...

# %%
pd.DataFrame({'apples': 50, 'banans': 34}, index=[0,])
# Out:
#    apples  banans
# 0      50      34

# %%
pd.DataFrame({'apples': [50], 'banans': [34]})
# Out:
#    apples  banans
# 0      50      34

# %%
pd.Series(['4 cups', '1 cup', '2 large', '1 can'], index=['Flour', 'Milk', 'Eggs', 'Spam'],)
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# dtype: object

# %%
a = pd.Series(['4 cups', '1 cup', '2 large', '1 can'], index=['Flour', 'Milk', 'Eggs', 'Spam'],name='Items')

# %%
print(a)
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Items, dtype: object

# %%
a.name
# Out:
# 'Items'

# %%
a.index
# Out:
# Index(['Flour', 'Milk', 'Eggs', 'Spam'], dtype='object')

# %%
a
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Items, dtype: object

# %%
import pandas as pd
df = pd.DataFrame({'a':[1,2,3,4], 'b': [3,4,2,6], 'c': [23, 2, 5, 1], 'd': [1,32,12,22]})

# %%
df
# Out:
#    a  b   c   d
# 0  1  3  23   1
# 1  2  4   2  32
# 2  3  2   5  12
# 3  4  6   1  22

# %%
df.iloc[0]
# Out:
# a     1
# b     3
# c    23
# d     1
# Name: 0, dtype: int64

# %%
df.iloc[:, 0]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df.iloc[[1,2], 0:]
# Out:
#    a  b  c   d
# 1  2  4  2  32
# 2  3  2  5  12

# %% [raw]
# Negative numbers can be used in selection. This will start counting forwards from the end of the values.

# %% [markdown]
# ## first parameter is row, [second is column ]

# %%
df.iloc[-1]
# Out:
# a     4
# b     6
# c     1
# d    22
# Name: 3, dtype: int64

# %%
df.iloc[-2:]
# Out:
#    a  b  c   d
# 2  3  2  5  12
# 3  4  6  1  22

# %% [markdown]
# ## iloc : index based selection

# %% [markdown]
# ## loc: label based selection

# %%
df.iloc[0, 'a']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    2009         else:
# -> 2010             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    2011
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-9e0d7aad7a2f> in <module>
# ----> 1 df.iloc[0, 'a']
#
# ...

# %%
df.loc[0, 'a']
# Out:
# 1

# %%
df.loc[:, 'a']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df.a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %% [raw]
# iloc is conceptually simpler than loc because it ignores the dataset's indices. When we use iloc we treat the dataset like a big matrix (a list of lists), one that we have to index into by position. loc, by contrast, uses the information in the indices to do its work. Since your dataset usually has meaningful indices, it's usually easier to do things using loc instead.

# %%
df.loc[0, ['a', 'c']]
# Out:
# a     1
# c    23
# Name: 0, dtype: int64

# %%
df.iloc[2:4]
# Out:
#    a  b  c   d
# 2  3  2  5  12
# 3  4  6  1  22

# %%
df.loc[2:4]
# Out:
#    a  b  c   d
# 2  3  2  5  12
# 3  4  6  1  22

# %%
df[2:4]
# Out:
#    a  b  c   d
# 2  3  2  5  12
# 3  4  6  1  22

# %%
df.iloc[0:3]
# Out:
#    a  b   c   d
# 0  1  3  23   1
# 1  2  4   2  32
# 2  3  2   5  12

# %%
df.loc[0:3]
# Out:
#    a  b   c   d
# 0  1  3  23   1
# 1  2  4   2  32
# 2  3  2   5  12
# 3  4  6   1  22

# %% [raw]
# iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10.

# %%
df.loc[0, 'a':'d']
# Out:
# a     1
# b     3
# c    23
# d     1
# Name: 0, dtype: int64

# %%
df.loc[0, 'a':]
# Out:
# a     1
# b     3
# c    23
# d     1
# Name: 0, dtype: int64

# %%
df.index = ['i1', 'i2', 'i3', 'i4']

# %%
df
# Out:
#     a  b   c   d
# i1  1  3  23   1
# i2  2  4   2  32
# i3  3  2   5  12
# i4  4  6   1  22

# %%
df.iloc[0, 0]
# Out:
# 1

# %%
df.loc['i1', 'a']
# Out:
# 1

# %%
df.set_index('a')
# Out:
#    b   c   d
# a
# 1  3  23   1
# 2  4   2  32
# 3  2   5  12
# 4  6   1  22

# %%
df
# Out:
#     a  b   c   d
# i1  1  3  23   1
# i2  2  4   2  32
# i3  3  2   5  12
# i4  4  6   1  22

# %%
import numpy as np
df['e'] = np.array([1,2,1,3])

# %%
df
# Out:
#     a  b   c   d  e
# i1  1  3  23   1  1
# i2  2  4   2  32  2
# i3  3  2   5  12  1
# i4  4  6   1  22  3

# %%
df['e'] == 1
# Out:
# i1     True
# i2    False
# i3     True
# i4    False
# Name: e, dtype: bool

# %% [raw]
# This operation produced a Series of True/False booleans based on the country of each record. This result can then be used inside of loc to select the relevant data:

# %%
df.loc[df['e']==1]
# Out:
#     a  b   c   d  e
# i1  1  3  23   1  1
# i3  3  2   5  12  1

# %%
df.loc[(df['e']==1) & (df.c >10)]
# Out:
#     a  b   c  d  e
# i1  1  3  23  1  1

# %%
df.loc[(df['e']==1) | (df.c >10)]
# Out:
#     a  b   c   d  e
# i1  1  3  23   1  1
# i3  3  2   5  12  1

# %% [raw]
# Pandas comes with a few built-in conditional selectors, two of which we will highlight here.
#
# The first is isin. isin is lets you select data whose value "is in" a list of values.

# %%
df.loc[df.a.isin([1,3])]
# Out:
#     a  b   c   d  e
# i1  1  3  23   1  1
# i3  3  2   5  12  1

# %% [raw]
# The second is isnull (and its companion notnull). These methods let you highlight values which are (or are not) empty (NaN).

# %%
df.isnull()
# Out:
#         a      b      c      d      e
# i1  False  False  False  False  False
# i2  False  False  False  False  False
# i3  False  False  False  False  False
# i4  False  False  False  False  False

# %%
df.notnull()
# Out:
#        a     b     c     d     e
# i1  True  True  True  True  True
# i2  True  True  True  True  True
# i3  True  True  True  True  True
# i4  True  True  True  True  True

# %%
df.isna()
# Out:
#         a      b      c      d      e
# i1  False  False  False  False  False
# i2  False  False  False  False  False
# i3  False  False  False  False  False
# i4  False  False  False  False  False

# %%
import numpy as np

df.loc['i3', 'b'] = np.nan

# %%
df.isnull()
# Out:
#         a      b      c      d      e
# i1  False  False  False  False  False
# i2  False  False  False  False  False
# i3  False   True  False  False  False
# i4  False  False  False  False  False

# %%
df.isna()
# Out:
#         a      b      c      d      e
# i1  False  False  False  False  False
# i2  False  False  False  False  False
# i3  False   True  False  False  False
# i4  False  False  False  False  False

# %%
df.notna()
# Out:
#        a      b     c     d     e
# i1  True   True  True  True  True
# i2  True   True  True  True  True
# i3  True  False  True  True  True
# i4  True   True  True  True  True

# %%
df.notnull()
# Out:
#        a      b     c     d     e
# i1  True   True  True  True  True
# i2  True   True  True  True  True
# i3  True  False  True  True  True
# i4  True   True  True  True  True

# %%
df = pd.read_csv('datas/melb_data.csv')

# %%
df.Price.describe()
# Out:
# count    1.358000e+04
# mean     1.075684e+06
# std      6.393107e+05
# min      8.500000e+04
# 25%      6.500000e+05
# 50%      9.030000e+05
# 75%      1.330000e+06
# max      9.000000e+06
# Name: Price, dtype: float64

# %%
df.SellerG.describe()
# Out:
# count      13580
# unique       268
# top       Nelson
# freq        1565
# Name: SellerG, dtype: object

# %%
df.Price.mean()
# Out:
# 1075684.079455081

# %%
df.Price.unique()
# Out:
# array([1480000., 1035000., 1465000., ..., 1288000., 1263500., 1323000.])

# %%
df.SellerG.value_counts()
# Out:
# Nelson           1565
# Jellis           1316
# hockingstuart    1167
# Barry            1011
# Ray               701
#                  ...
# Darras              1
# Mitchell            1
# North               1
# Xynergy             1
# Roger               1
# Name: SellerG, Length: 268, dtype: int64

# %%
mean = df.Price.mean()

df.Price.map(lambda x: x-mean)
# Out:
# 0        4.043159e+05
# 1       -4.068408e+04
# 2        3.893159e+05
# 3       -2.256841e+05
# 4        5.243159e+05
#              ...
# 13575    1.693159e+05
# 13576   -4.468408e+04
# 13577    9.431592e+04
# 13578    1.424316e+06
# 13579    2.093159e+05
# Name: Price, Length: 13580, dtype: float64

# %%
def divide_by_10000(x):
    return x/10000

# %%
df.Price.apply(divide_by_10000)
# Out:
# 0        148.0
# 1        103.5
# 2        146.5
# 3         85.0
# 4        160.0
#          ...
# 13575    124.5
# 13576    103.1
# 13577    117.0
# 13578    250.0
# 13579    128.5
# Name: Price, Length: 13580, dtype: float64

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df[['Rooms', 'Price', 'BuildingArea']].apply(divide_by_10000)
# Out:
#         Rooms  Price  BuildingArea
# 0      0.0002  148.0           NaN
# 1      0.0002  103.5        0.0079
# 2      0.0003  146.5        0.0150
# 3      0.0003   85.0           NaN
# 4      0.0004  160.0        0.0142
# ...       ...    ...           ...
# 13575  0.0004  124.5           NaN
# 13576  0.0003  103.1        0.0133
# 13577  0.0003  117.0           NaN
# 13578  0.0004  250.0        0.0157
# 13579  0.0004  128.5        0.0112
#
# [13580 rows x 3 columns]

# %%
df[['Rooms', 'Price', 'BuildingArea']].apply(divide_by_10000, axis='rows')
# Out:
#         Rooms  Price  BuildingArea
# 0      0.0002  148.0           NaN
# 1      0.0002  103.5        0.0079
# 2      0.0003  146.5        0.0150
# 3      0.0003   85.0           NaN
# 4      0.0004  160.0        0.0142
# ...       ...    ...           ...
# 13575  0.0004  124.5           NaN
# 13576  0.0003  103.1        0.0133
# 13577  0.0003  117.0           NaN
# 13578  0.0004  250.0        0.0157
# 13579  0.0004  128.5        0.0112
#
# [13580 rows x 3 columns]

# %%
df[['Rooms', 'Price', 'BuildingArea']].apply(divide_by_10000, axis='columns')
# Out:
#         Rooms  Price  BuildingArea
# 0      0.0002  148.0           NaN
# 1      0.0002  103.5        0.0079
# 2      0.0003  146.5        0.0150
# 3      0.0003   85.0           NaN
# 4      0.0004  160.0        0.0142
# ...       ...    ...           ...
# 13575  0.0004  124.5           NaN
# 13576  0.0003  103.1        0.0133
# 13577  0.0003  117.0           NaN
# 13578  0.0004  250.0        0.0157
# 13579  0.0004  128.5        0.0112
#
# [13580 rows x 3 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv('datas/melb_data.csv')

# %%
df['Rooms'].astype('category')
# Out:
# 0        2
# 1        2
# 2        3
# 3        3
# 4        4
#         ..
# 13575    4
# 13576    3
# 13577    3
# 13578    4
# 13579    4
# Name: Rooms, Length: 13580, dtype: category
# Categories (9, int64): [1, 2, 3, 4, ..., 6, 7, 8, 10]

# %%
mask1 = df['Rooms'] == 4
mask2 = df['Price'] > 100000

# %%
df[mask1].head()
# Out:
#           Suburb          Address  Rooms Type      Price Method    SellerG  \
# 4     Abbotsford      55a Park St      4    h  1600000.0     VB     Nelson
# 20    Abbotsford  3/72 Charles St      4    h  1330000.0     PI        Kay
# 30    Abbotsford     31 Turner St      4    h  1542000.0      S    Collins
# 46  Airport West    36 Roberts Rd      4    h   785000.0      S  Considine
# 63  Airport West   6 Kittyhawk St      4    h   773000.0      S       Brad
#
#           Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 4    4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# 20  18/03/2017       2.5    3067.0  ...       2.0  2.0     780.0
# 30  24/09/2016       2.5    3067.0  ...       3.0  1.0       0.0
# 46   6/08/2016      13.5    3042.0  ...       1.0  2.0     597.0
# 63  17/09/2016      13.5    3042.0  ...       3.0  4.0     531.0
#
#     BuildingArea  YearBuilt    CouncilArea Lattitude  Longtitude  \
# ...

# %%
df[mask2].head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df[mask1&mask2].head()
# Out:
#           Suburb          Address  Rooms Type      Price Method    SellerG  \
# 4     Abbotsford      55a Park St      4    h  1600000.0     VB     Nelson
# 20    Abbotsford  3/72 Charles St      4    h  1330000.0     PI        Kay
# 30    Abbotsford     31 Turner St      4    h  1542000.0      S    Collins
# 46  Airport West    36 Roberts Rd      4    h   785000.0      S  Considine
# 63  Airport West   6 Kittyhawk St      4    h   773000.0      S       Brad
#
#           Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 4    4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# 20  18/03/2017       2.5    3067.0  ...       2.0  2.0     780.0
# 30  24/09/2016       2.5    3067.0  ...       3.0  1.0       0.0
# 46   6/08/2016      13.5    3042.0  ...       1.0  2.0     597.0
# 63  17/09/2016      13.5    3042.0  ...       3.0  4.0     531.0
#
#     BuildingArea  YearBuilt    CouncilArea Lattitude  Longtitude  \
# ...

# %%
df[df['Rooms'] == 3].head()
# Out:
#         Suburb           Address  Rooms Type      Price Method SellerG  \
# 2   Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3   Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 6   Abbotsford      124 Yarra St      3    h  1876000.0      S  Nelson
# 11  Abbotsford   40 Nicholson St      3    h  1350000.0     VB  Nelson
# 16  Abbotsford       42 Henry St      3    h  1200000.0      S  Jellis
#
#           Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 2    4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3    4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 6    7/05/2016       2.5    3067.0  ...       2.0  0.0     245.0
# 11  12/11/2016       2.5    3067.0  ...       2.0  2.0     214.0
# 16  16/07/2016       2.5    3067.0  ...       2.0  1.0     113.0
#
#     BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 2          150.0     1900.0        Yarra  -37.8093    144.9944
# ...

# %%
df[df['Rooms']==4 & df['Price']<=150000].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     273         #  (xint or xbool) and (yint or bool)
# --> 274         result = op(x, y)
#     275     except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
# ...

# %%
df[(df['Rooms']==4) & (df['Price']<=150000)].head()
# Out:
#          Suburb          Address  Rooms Type     Price Method SellerG  \
# 1805  Caulfield       30 Pyne St      4    h  131000.0     PI  Rodney
# 1927     Coburg  171 Moreland Rd      4    h  145000.0     PI  Jellis
#
#             Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 1805  25/02/2017       8.9    3162.0  ...       1.0  2.0     499.0
# 1927   4/06/2016       7.8    3058.0  ...       1.0  1.0     536.0
#
#       BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 1805         155.0     1920.0    Glen Eira  -37.8864    145.0242
# 1927         164.0     1910.0     Moreland  -37.7555    144.9658
#
#                  Regionname Propertycount
# 1805  Southern Metropolitan        2379.0
# 1927  Northern Metropolitan       11204.0
#
# [2 rows x 21 columns]

# %%
mask1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 13575     True
# 13576    False
# 13577    False
# 13578     True
# 13579     True
# Name: Rooms, Length: 13580, dtype: bool

# %%
mask2
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 13575    True
# 13576    True
# 13577    True
# 13578    True
# 13579    True
# Name: Price, Length: 13580, dtype: bool

# %%
mask3 = df['Landsize'] >400

# %%
df[mask1&(mask2|mask3)].head()
# Out:
#           Suburb          Address  Rooms Type      Price Method    SellerG  \
# 4     Abbotsford      55a Park St      4    h  1600000.0     VB     Nelson
# 20    Abbotsford  3/72 Charles St      4    h  1330000.0     PI        Kay
# 30    Abbotsford     31 Turner St      4    h  1542000.0      S    Collins
# 46  Airport West    36 Roberts Rd      4    h   785000.0      S  Considine
# 63  Airport West   6 Kittyhawk St      4    h   773000.0      S       Brad
#
#           Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 4    4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# 20  18/03/2017       2.5    3067.0  ...       2.0  2.0     780.0
# 30  24/09/2016       2.5    3067.0  ...       3.0  1.0       0.0
# 46   6/08/2016      13.5    3042.0  ...       1.0  2.0     597.0
# 63  17/09/2016      13.5    3042.0  ...       3.0  4.0     531.0
#
#     BuildingArea  YearBuilt    CouncilArea Lattitude  Longtitude  \
# ...

# %% [raw]
# returns true if the list of values are present in dataframe

# %%
df.isin([4,'Airport West', 'Collins', 1])
# Out:
#        Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0       False    False  False  False  False   False    False  False     False
# 1       False    False  False  False  False   False    False  False     False
# 2       False    False  False  False  False   False    False  False     False
# 3       False    False  False  False  False   False    False  False     False
# 4       False    False   True  False  False   False    False  False     False
# ...       ...      ...    ...    ...    ...     ...      ...    ...       ...
# 13575   False    False   True  False  False   False    False  False     False
# 13576   False    False  False  False  False   False    False  False     False
# 13577   False    False  False  False  False   False    False  False     False
# 13578   False    False   True  False  False   False    False  False     False
# 13579   False    False   True  False  False   False    False  False     False
#
# ...

# %%
df.isnull()
# Out:
#        Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0       False    False  False  False  False   False    False  False     False
# 1       False    False  False  False  False   False    False  False     False
# 2       False    False  False  False  False   False    False  False     False
# 3       False    False  False  False  False   False    False  False     False
# 4       False    False  False  False  False   False    False  False     False
# ...       ...      ...    ...    ...    ...     ...      ...    ...       ...
# 13575   False    False  False  False  False   False    False  False     False
# 13576   False    False  False  False  False   False    False  False     False
# 13577   False    False  False  False  False   False    False  False     False
# 13578   False    False  False  False  False   False    False  False     False
# 13579   False    False  False  False  False   False    False  False     False
#
# ...

# %%
df.notna()
# Out:
#        Suburb  Address  Rooms  Type  Price  Method  SellerG  Date  Distance  \
# 0        True     True   True  True   True    True     True  True      True
# 1        True     True   True  True   True    True     True  True      True
# 2        True     True   True  True   True    True     True  True      True
# 3        True     True   True  True   True    True     True  True      True
# 4        True     True   True  True   True    True     True  True      True
# ...       ...      ...    ...   ...    ...     ...      ...   ...       ...
# 13575    True     True   True  True   True    True     True  True      True
# 13576    True     True   True  True   True    True     True  True      True
# 13577    True     True   True  True   True    True     True  True      True
# 13578    True     True   True  True   True    True     True  True      True
# 13579    True     True   True  True   True    True     True  True      True
#
# ...

# %%
df.notnull()
# Out:
#        Suburb  Address  Rooms  Type  Price  Method  SellerG  Date  Distance  \
# 0        True     True   True  True   True    True     True  True      True
# 1        True     True   True  True   True    True     True  True      True
# 2        True     True   True  True   True    True     True  True      True
# 3        True     True   True  True   True    True     True  True      True
# 4        True     True   True  True   True    True     True  True      True
# ...       ...      ...    ...   ...    ...     ...      ...   ...       ...
# 13575    True     True   True  True   True    True     True  True      True
# 13576    True     True   True  True   True    True     True  True      True
# 13577    True     True   True  True   True    True     True  True      True
# 13578    True     True   True  True   True    True     True  True      True
# 13579    True     True   True  True   True    True     True  True      True
#
# ...

# %%
df[df.notnull()].shape
# Out:
# (13580, 21)

# %%
df.shape
# Out:
# (13580, 21)

# %%
df[df.notna()].shape
# Out:
# (13580, 21)

# %%
df['Rooms'].between(3,5).head()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Rooms, dtype: bool

# %%
df['Rooms'].duplicated()
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 13575     True
# 13576     True
# 13577     True
# 13578     True
# 13579     True
# Name: Rooms, Length: 13580, dtype: bool

# %%
a = df['Rooms']

# %%
a.drop_duplicates().size
# Out:
# 9

# %%
a.size
# Out:
# 13580

# %%
a.unique()
# Out:
# array([ 2,  3,  4,  1,  6,  5,  8,  7, 10])

# %%
a.nunique()
# Out:
# 9

# %%
df['Price'].unique()
# Out:
# array([1480000., 1035000., 1465000., ..., 1288000., 1263500., 1323000.])

# %%
df['Price'].unique().shape
# Out:
# (2204,)

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.tail()
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=13580, step=1)

# %%
d1 = df[['Landsize', 'Rooms', 'Address', 'Price']]

# %%
d1.head()
# Out:
#    Landsize  Rooms           Address      Price
# 0     202.0      2      85 Turner St  1480000.0
# 1     156.0      2   25 Bloomburg St  1035000.0
# 2     134.0      3      5 Charles St  1465000.0
# 3      94.0      3  40 Federation La   850000.0
# 4     120.0      4       55a Park St  1600000.0

# %%
d1.dropna()
# Out:
# array([[False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False],
#        ...,
#        [False, False, False, False],
#        [False, False, False, False],
#        [False, False, False, False]])

# %%
d1.columns
# Out:
# Index(['Landsize', 'Rooms', 'Address', 'Price'], dtype='object')

# %%
df.set_index('Rooms', inplace=True)

# %%
df.head()
# Out:
#            Suburb           Address Type      Price Method SellerG       Date  \
# Rooms
# 2      Abbotsford      85 Turner St    h  1480000.0      S  Biggin  3/12/2016
# 2      Abbotsford   25 Bloomburg St    h  1035000.0      S  Biggin  4/02/2016
# 3      Abbotsford      5 Charles St    h  1465000.0     SP  Biggin  4/03/2017
# 3      Abbotsford  40 Federation La    h   850000.0     PI  Biggin  4/03/2017
# 4      Abbotsford       55a Park St    h  1600000.0     VB  Nelson  4/06/2016
#
#        Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# Rooms
# 2           2.5    3067.0       2.0       1.0  1.0     202.0           NaN
# 2           2.5    3067.0       2.0       1.0  0.0     156.0          79.0
# 3           2.5    3067.0       3.0       2.0  0.0     134.0         150.0
# 3           2.5    3067.0       3.0       2.0  1.0      94.0           NaN
# 4           2.5    3067.0       3.0       1.0  2.0     120.0         142.0
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    Rooms      Suburb           Address Type      Price Method SellerG  \
# 0      2  Abbotsford      85 Turner St    h  1480000.0      S  Biggin
# 1      2  Abbotsford   25 Bloomburg St    h  1035000.0      S  Biggin
# 2      3  Abbotsford      5 Charles St    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.loc[0, 'Rooms']
# Out:
# 2

# %%
df.loc[: 4]
# Out:
#    Rooms      Suburb           Address Type      Price Method SellerG  \
# 0      2  Abbotsford      85 Turner St    h  1480000.0      S  Biggin
# 1      2  Abbotsford   25 Bloomburg St    h  1035000.0      S  Biggin
# 2      3  Abbotsford      5 Charles St    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.loc[[0,1,4]]
# Out:
#    Rooms      Suburb          Address Type      Price Method SellerG  \
# 0      2  Abbotsford     85 Turner St    h  1480000.0      S  Biggin
# 1      2  Abbotsford  25 Bloomburg St    h  1035000.0      S  Biggin
# 4      4  Abbotsford      55a Park St    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 4        4019.0
#
# ...

# %%
1 in df.index
# Out:
# True

# %%
df.iloc[0, 0]
# Out:
# 2

# %%
df.iloc[0,10]
# Out:
# 2.0

# %%
df.iloc[:, 2:5]
# Out:
#                 Address Type      Price
# 0          85 Turner St    h  1480000.0
# 1       25 Bloomburg St    h  1035000.0
# 2          5 Charles St    h  1465000.0
# 3      40 Federation La    h   850000.0
# 4           55a Park St    h  1600000.0
# ...                 ...  ...        ...
# 13575      12 Strada Cr    h  1245000.0
# 13576     77 Merrett Dr    h  1031000.0
# 13577       83 Power St    h  1170000.0
# 13578      96 Verdon St    h  2500000.0
# 13579        6 Agnes St    h  1285000.0
#
# [13580 rows x 3 columns]

# %%
df.iloc[3:]
# Out:
#        Rooms         Suburb           Address Type      Price Method  \
# 3          3     Abbotsford  40 Federation La    h   850000.0     PI
# 4          4     Abbotsford       55a Park St    h  1600000.0     VB
# 5          2     Abbotsford    129 Charles St    h   941000.0      S
# 6          3     Abbotsford      124 Yarra St    h  1876000.0      S
# 7          2     Abbotsford     98 Charles St    h  1636000.0      S
# ...      ...            ...               ...  ...        ...    ...
# 13575      4  Wheelers Hill      12 Strada Cr    h  1245000.0      S
# 13576      3   Williamstown     77 Merrett Dr    h  1031000.0     SP
# 13577      3   Williamstown       83 Power St    h  1170000.0      S
# 13578      4   Williamstown      96 Verdon St    h  2500000.0     PI
# 13579      4     Yarraville        6 Agnes St    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.iloc[[2,3,4]]
# Out:
#    Rooms      Suburb           Address Type      Price Method SellerG  \
# 2      3  Abbotsford      5 Charles St    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# ...

# %%
df.iloc[[2,3,4], 3:6]
# Out:
#   Type      Price Method
# 2    h  1465000.0     SP
# 3    h   850000.0     PI
# 4    h  1600000.0     VB

# %%
df.at[0, 'Price']
# Out:
# 1480000.0

# %%
df.iat[0, 4]
# Out:
# 1480000.0

# %%
df.ix[]

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.drop(labels=['Suburb', 'Address', 'Rooms', 'Type', 'Method', 'SellerG'], axis=1, inplace=True)

# %%
# Out:
#            Price        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0      1480000.0   3/12/2016       2.5    3067.0       2.0       1.0  1.0
# 1      1035000.0   4/02/2016       2.5    3067.0       2.0       1.0  0.0
# 2      1465000.0   4/03/2017       2.5    3067.0       3.0       2.0  0.0
# 3       850000.0   4/03/2017       2.5    3067.0       3.0       2.0  1.0
# 4      1600000.0   4/06/2016       2.5    3067.0       3.0       1.0  2.0
# ...          ...         ...       ...       ...       ...       ...  ...
# 13575  1245000.0  26/08/2017      16.7    3150.0       4.0       2.0  2.0
# 13576  1031000.0  26/08/2017       6.8    3016.0       3.0       2.0  2.0
# 13577  1170000.0  26/08/2017       6.8    3016.0       3.0       2.0  4.0
# 13578  2500000.0  26/08/2017       6.8    3016.0       4.0       1.0  5.0
# 13579  1285000.0  26/08/2017       6.3    3013.0       4.0       1.0  1.0
#
#        Landsize  BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# ...

# %%
df.nsmallest(3, 'Price')
# Out:
#          Suburb           Address  Rooms Type     Price Method  SellerG  \
# 2652  Footscray  202/51 Gordon St      1    u   85000.0     PI  Burnham
# 1805  Caulfield        30 Pyne St      4    h  131000.0     PI   Rodney
# 1927     Coburg   171 Moreland Rd      4    h  145000.0     PI   Jellis
#
#             Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 2652   3/09/2016       6.4    3011.0  ...       1.0  0.0       0.0
# 1805  25/02/2017       8.9    3162.0  ...       1.0  2.0     499.0
# 1927   4/06/2016       7.8    3058.0  ...       1.0  1.0     536.0
#
#       BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 2652           NaN     2007.0  Maribyrnong  -37.7911    144.8900
# 1805         155.0     1920.0    Glen Eira  -37.8864    145.0242
# 1927         164.0     1910.0     Moreland  -37.7555    144.9658
#
#                  Regionname Propertycount
# 2652   Western Metropolitan        7570.0
# 1805  Southern Metropolitan        2379.0
# ...

# %%
df.nlargest(4, 'Rooms')
# Out:
#                    Suburb           Address  Rooms Type      Price Method  \
# 11304            Bundoora         5 Ball Ct     10    h   900000.0     PI
# 379             Ashburton    115 Ashburn Gr      8    h  2950000.0      S
# 1926               Coburg      35 The Grove      8    u  2250000.0     PI
# 3255   Heidelberg Heights  478 Waterdale Rd      8    h   770000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 11304            Ray  15/07/2017      12.1    3083.0  ...       3.0  2.0
# 379    hockingstuart  10/09/2016      11.0    3147.0  ...       7.0  4.0
# 1926           Peter   4/03/2017       7.8    3058.0  ...       2.0  4.0
# 3255           Miles  19/11/2016      10.5    3081.0  ...       4.0  4.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 11304     313.0           NaN     2006.0      Darebin -37.71098   145.05381
# ...

# %%
df.sample(n=3, axis=0)
# Out:
#            Suburb          Address  Rooms Type      Price Method SellerG  \
# 4325      Niddrie    142 Hotham Rd      2    u   522500.0     SP  Nelson
# 3552   Kensington  51 Gatehouse Dr      3    h  1000000.0     SP  Nelson
# 11315   Chadstone     1/3 Evans St      3    u   960000.0      S  Jellis
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 4325   26/07/2016      11.2    3042.0  ...       1.0  1.0     167.0
# 3552   19/11/2016       4.2    3031.0  ...       2.0  2.0     211.0
# 11315  15/07/2017      11.7    3148.0  ...       2.0  2.0     382.0
#
#        BuildingArea  YearBuilt    CouncilArea Lattitude  Longtitude  \
# 4325            NaN        NaN  Moonee Valley -37.73280    144.8764
# 3552          132.0     1997.0      Melbourne -37.79260    144.9197
# 11315         151.0     2000.0         Monash -37.88304    145.0969
#
#                   Regionname Propertycount
# 4325    Western Metropolitan        2291.0
# ...

# %%
df.sample(n=3, axis=1)
# Out:
#        Bathroom           Address Type
# 0           1.0      85 Turner St    h
# 1           1.0   25 Bloomburg St    h
# 2           2.0      5 Charles St    h
# 3           2.0  40 Federation La    h
# 4           1.0       55a Park St    h
# ...         ...               ...  ...
# 13575       2.0      12 Strada Cr    h
# 13576       2.0     77 Merrett Dr    h
# 13577       2.0       83 Power St    h
# 13578       1.0      96 Verdon St    h
# 13579       1.0        6 Agnes St    h
#
# [13580 rows x 3 columns]

# %%
df['Price'].dropna(df['Price'].where(df['Price']==85000))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-9f93b30e3f69> in <module>
# ----> 1 df['Price'].dropna(df['Price'].where(df['Price']==85000))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in dropna(self, axis, inplace, how)
#    4487         inplace = validate_bool_kwarg(inplace, "inplace")
#    4488         # Validate the axis parameter
# -> 4489         self._get_axis_number(axis or 0)
#    4490
#    4491         if self._can_hold_na:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ...
