# %%
import pandas

# %%
dir(pandas)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %%
pwd
# Out:
# '/home/bishal/Downloads/MostImportant'

# %%
cd ..
# Out:
# /home/bishal/Downloads

# %%
cd developer_survey_2019/
# Out:
# /home/bishal/Downloads/developer_survey_2019

# %%
ls
# Out:
# __MACOSX/        so_survey_2019.pdf         survey_results_schema.csv
# README_2019.txt  survey_results_public.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
pd.set_option('display.max_rows', 90)

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
df.tail(1)
# Out:
#        Respondent MainBranch Hobbyist              OpenSourcer  \
# 88882       88863        NaN      Yes  Less than once per year
#
#                                               OpenSource  \
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                    Employment Country         Student  \
# 88882  Not employed, and not looking for work   Spain  Yes, full-time
#
#                                   EdLevel  \
# 88882  Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  \
# 88882  Computer science, computer engineering, or sof...
#
#                                                 EduOther OrgSize DevType  \
# 88882  Taken an online course in programming or softw...     NaN     NaN
#
#       YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 88882         8         11            3       NaN    NaN      NaN      NaN
#
# ...

# %%
pd.set_option('display.max_rows', 3)

# %%
df
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# ...           ...                                     ...      ...
# 88882       88863                                     NaN      Yes
#
#                    OpenSourcer  \
# 0                        Never
# ...                        ...
# 88882  Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# ...                                                  ...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                    Employment         Country         Student  \
# 0      Not employed, and not looking for work  United Kingdom              No
# ...                                       ...             ...             ...
# 88882  Not employed, and not looking for work           Spain  Yes, full-time
#
# ...

# %%
df.head(5)
# Out:
#     Respondent                              MainBranch Hobbyist  \
# 0            1  I am a student who is learning to code      Yes
# ..         ...                                     ...      ...
# 4            5          I am a developer by profession      Yes
#
#                    OpenSourcer  \
# 0                        Never
# ..                         ...
# 4   Once a month or more often
#
#                                            OpenSource  \
# 0   The quality of OSS and closed source software ...
# ..                                                ...
# 4   OSS is, on average, of HIGHER quality than pro...
#
#                                 Employment         Country Student  \
# 0   Not employed, and not looking for work  United Kingdom      No
# ..                                     ...             ...     ...
# 4                       Employed full-time         Ukraine      No
#
#                                      EdLevel  \
# ...

# %%
pd.set_option('display.max_rows',12)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema_df.head(3)
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...
# 2    Hobbyist                            Do you code as a hobby?

# %%
person = {
    "first": "Bishal",
    "age":12,
    "salary": "1M"
}

# %%
person = {
    "first": ["Bishal","Hemant", "Manish"],
    "age":[12, 13, 14],
    "salary": ["1M", "2M", "3M"]
}

# %%
person['salary']
# Out:
# ['1M', '2M', '3M']

# %%
df = pd.DataFrame(person)

# %%
df
# Out:
#     first  age salary
# 0  Bishal   12     1M
# 1  Hemant   13     2M
# 2  Manish   14     3M

# %%
df['age']
# Out:
# 0    12
# 1    13
# 2    14
# Name: age, dtype: int64

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.age
# Out:
# 0    12
# 1    13
# 2    14
# Name: age, dtype: int64

# %%
df[['first', 'age']]
# Out:
#     first  age
# 0  Bishal   12
# 1  Hemant   13
# 2  Manish   14

# %%
df.columns
# Out:
# Index(['first', 'age', 'salary'], dtype='object')

# %%
df.iloc[0]
# Out:
# first     Bishal
# age           12
# salary        1M
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#     first  age salary
# 0  Bishal   12     1M
# 1  Hemant   13     2M

# %%
df.iloc[[0,2],[1]]
# Out:
#    age
# 0   12
# 2   14

# %%
df.iloc[[1,2],[1,0]]
# Out:
#    age   first
# 1   13  Hemant
# 2   14  Manish

# %%
df.iloc[0]
# Out:
# first     Bishal
# age           12
# salary        1M
# Name: 0, dtype: object

# %%
df.loc[[0,1]]
# Out:
#     first  age salary
# 0  Bishal   12     1M
# 1  Hemant   13     2M

# %%
df.loc[[0,1],['age']]
# Out:
#    age
# 0   12
# 1   13

# %%
df.loc[[0,2],['age', 'salary']]
# Out:
#    age salary
# 0   12     1M
# 2   14     3M

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[[0,5],['Extraversion']]
# Out:
#                Extraversion
# 0                    Online
# 5  In real life (in person)

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[[0:2],['Hobbyist']]
# Out:
#   File "<ipython-input-71-2f544a92f55a>", line 1
#     df.loc[[0:2],['Hobbyist']]
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # when slicing we need to remove the square brackets

# %% [markdown]
# ## INclusive brackets

# %%
df.loc[0:2,['Hobbyist']]
# Out:
#   Hobbyist
# 0      Yes
# 1       No
# 2      Yes

# %%
df.loc[:5, 'Hobbyist':'Employment']
# Out:
#   Hobbyist                 OpenSourcer  \
# 0      Yes                       Never
# 1       No     Less than once per year
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
# 5      Yes                       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
# 5                      Employed full-time

# %%
df1 = pd.DataFrame(person)

# %%
df1
# Out:
#     first  age salary
# 0  Bishal   12     1M
# 1  Hemant   13     2M
# 2  Manish   14     3M

# %%
df1['age']
# Out:
# 0    12
# 1    13
# 2    14
# Name: age, dtype: int64

# %% [markdown]
# # To set custom index

# %%
df1.set_index('first')
# Out:
#         age salary
# first
# Bishal   12     1M
# Hemant   13     2M
# Manish   14     3M

# %%
df1
# Out:
#     first  age salary
# 0  Bishal   12     1M
# 1  Hemant   13     2M
# 2  Manish   14     3M

# %% [markdown]
# # Permanent changing the index to data

# %%
df1.set_index('first', inplace=True)

# %%
df1
# Out:
#         age salary
# first
# Bishal   12     1M
# Hemant   13     2M
# Manish   14     3M

# %%
df1.iloc[1]
# Out:
# age       13
# salary    2M
# Name: Hemant, dtype: object

# %%
df1.loc['Manish']
# Out:
# age       14
# salary    3M
# Name: Manish, dtype: object

# %%
df1.loc[['Manish'], ['age']]
# Out:
#         age
# first
# Manish   14

# %%
df1.reset_index()
# Out:
#     first  age salary
# 0  Bishal   12     1M
# 1  Hemant   13     2M
# 2  Manish   14     3M

# %%
df1
# Out:
#         age salary
# first
# Bishal   12     1M
# Hemant   13     2M
# Manish   14     3M

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#     first  age salary
# 0  Bishal   12     1M
# 1  Hemant   13     2M
# 2  Manish   14     3M

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[1]
# Out:
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
# Employment                 Not employed, and not looking for work
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 1, Length: 84, dtype: object

# %%
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df.set_index('Column', inplace=True)

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['Sexuality']
# Out:
# QuestionText    Which of the following do you currently identi...
# Name: Sexuality, dtype: object

# %%
schema_df.loc['Sexuality', 'QuestionText']
# Out:
# 'Which of the following do you currently identify as? Please select all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
schema_df.sort_index()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %%
schema_df.loc[['Age'],['QuestionText']]
# Out:
#                                              QuestionText
# Column
# Age     What is your age (in years)? If you prefer not...

# %%
schema_df.loc['Age','QuestionText']
# Out:
# 'What is your age (in years)? If you prefer not to answer, you may leave this question blank.'

# %%
schema_df.loc['Age', :]
# Out:
# QuestionText    What is your age (in years)? If you prefer not...
# Name: Age, dtype: object

# %%
schema_df.loc[['Age'],'QuestionText']
# Out:
# Column
# Age    What is your age (in years)? If you prefer not...
# Name: QuestionText, dtype: object

# %%
schema_df.iloc[0,'QuestionText']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    2009         else:
# -> 2010             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    2011
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-9a387b59cf46> in <module>
# ...

# %%
df1
# Out:
#     first  age salary
# 0  Bishal   12     1M
# 1  Hemant   13     2M
# 2  Manish   14     3M

# %%
df1['age'] >= 13
# Out:
# 0    False
# 1     True
# 2     True
# Name: age, dtype: bool

# %%
filt = (df1['age'] >= 13)

# %%
df1(filt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-c02b28f6ba0b> in <module>
# ----> 1 df1(filt)
#
# TypeError: 'DataFrame' object is not callable

# %%
df1
# Out:
#     first  age salary
# 0  Bishal   12     1M
# 1  Hemant   13     2M
# 2  Manish   14     3M

# %%
df1(filt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-c02b28f6ba0b> in <module>
# ----> 1 df1(filt)
#
# TypeError: 'DataFrame' object is not callable

# %%
df1(df1['age'] > 12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-339fe127e2f3> in <module>
# ----> 1 df1(df1['age'] > 12)
#
# TypeError: 'DataFrame' object is not callable

# %%
df1[filt]
# Out:
#     first  age salary
# 1  Hemant   13     2M
# 2  Manish   14     3M

# %%
df1[df1['age']>12]
# Out:
#     first  age salary
# 1  Hemant   13     2M
# 2  Manish   14     3M

# %%
df1.loc[filt]
# Out:
#     first  age salary
# 1  Hemant   13     2M
# 2  Manish   14     3M

# %%
df1.loc[filt, 'first']
# Out:
# 1    Hemant
# 2    Manish
# Name: first, dtype: object

# %% [markdown]
# # & and
# | or

# %%
filt = (df1['age'] == 13) | (df1['first'] == 'bishal' )

# %%
df1[filt]
# Out:
#     first  age salary
# 1  Hemant   13     2M

# %%
filt = (df1['age'] > 12) & (df1['first'] == 'Manish')

# %%
df1[filt]
# Out:
#     first  age salary
# 2  Manish   14     3M

# %%
df1[~filt]
# Out:
#     first  age salary
# 0  Bishal   12     1M
# 1  Hemant   13     2M

# %%
high_salary = df['Salary'] > 70000
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Salary'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-be3738258f0d> in <module>
# ----> 1 high_salary = df['Salary'] > 70000
# ...

# %%
high_filter = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_filter,['Country', 'LanguageWorkedWith', 'ConvertedComp'] ]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
df.loc[high_filter,['Country', 'LanguageWorkedWith', 'ConvertedComp'] ]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
df.loc[high_filter,['Country', 'LanguageWorkedWith', 'ConvertedComp']  ]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States', "India"]
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 4        United States
# 8                India
# 10               India
# 13       United States
# 15               India
#              ...
# 83862            India
# 84299            India
# 85642    United States
# 86012            India
# 88282    United States
# Name: Country, Length: 30010, dtype: object
