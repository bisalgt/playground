# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]

print(list(mycol.find()))
# Out:
# [{'_id': ObjectId('5eaf0e1ebaf67ec41d26da2a'), 'name': 'bishal', 'age': 24, 'salary': 300000}, {'_id': ObjectId('5eaf10cfbaf67ec41d26da2d'), 'names': 'bibek', 'age': 21, 'salary': 2300000}, {'_id': ObjectId('5eaf10cfbaf67ec41d26da2e'), 'names': 'manish', 'age': 25, 'salary': 239343}, {'_id': ObjectId('5eaf10cfbaf67ec41d26da2f'), 'names': 'hemant', 'age': 23, 'salary': 234234234}, {'_id': 1, 'name': 'John', 'address': 'Highway 37'}, {'_id': 2, 'name': 'Peter', 'address': 'Lowstreet 27'}, {'_id': 3, 'name': 'Amy', 'address': 'Apple st 652'}, {'_id': 4, 'name': 'Hannah', 'address': 'Mountain 21'}, {'_id': 5, 'name': 'Michael', 'address': 'Valley 345'}, {'_id': 6, 'name': 'Sandy', 'address': 'Ocean blvd 2'}, {'_id': 7, 'name': 'Betty', 'address': 'Green Grass 1'}, {'_id': 8, 'name': 'Richard', 'address': 'Sky st 331'}, {'_id': 9, 'name': 'Susan', 'address': 'One way 98'}, {'_id': 10, 'name': 'Vicky', 'address': 'Yellow Garden 2'}, {'_id': 11, 'name': 'Ben', 'address': 'Park Lane 38'}, {'
# ...

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]


print(mydb.list_collection_names())
print(list(mycol.find({}, {'id':1})))
# Out:
# ['customers']
# [{'_id': ObjectId('5eaf0e1ebaf67ec41d26da2a')}, {'_id': ObjectId('5eaf10cfbaf67ec41d26da2d')}, {'_id': ObjectId('5eaf10cfbaf67ec41d26da2e')}, {'_id': ObjectId('5eaf10cfbaf67ec41d26da2f')}, {'_id': 1}, {'_id': 2}, {'_id': 3}, {'_id': 4}, {'_id': 5}, {'_id': 6}, {'_id': 7}, {'_id': 8}, {'_id': 9}, {'_id': 10}, {'_id': 11}, {'_id': 12}, {'_id': 13}, {'_id': 14}]

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]


print(mydb.list_collection_names())
print(list(mycol.find({'_id':1})))
# Out:
# ['customers']
# [{'_id': 1, 'name': 'John', 'address': 'Highway 37'}]

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]


print(mydb.list_collection_names())
print(list(mycol.find({},{'_id':1})))
# Out:
# ['customers']
# [{'_id': ObjectId('5eaf0e1ebaf67ec41d26da2a')}, {'_id': ObjectId('5eaf10cfbaf67ec41d26da2d')}, {'_id': ObjectId('5eaf10cfbaf67ec41d26da2e')}, {'_id': ObjectId('5eaf10cfbaf67ec41d26da2f')}, {'_id': 1}, {'_id': 2}, {'_id': 3}, {'_id': 4}, {'_id': 5}, {'_id': 6}, {'_id': 7}, {'_id': 8}, {'_id': 9}, {'_id': 10}, {'_id': 11}, {'_id': 12}, {'_id': 13}, {'_id': 14}]

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]


print(mydb.list_collection_names())
print(list(mycol.find({'name':{'$gt':'P'}})))
# Out:
# ['customers']
# [{'_id': ObjectId('5eaf0e1ebaf67ec41d26da2a'), 'name': 'bishal', 'age': 24, 'salary': 300000}, {'_id': 2, 'name': 'Peter', 'address': 'Lowstreet 27'}, {'_id': 6, 'name': 'Sandy', 'address': 'Ocean blvd 2'}, {'_id': 8, 'name': 'Richard', 'address': 'Sky st 331'}, {'_id': 9, 'name': 'Susan', 'address': 'One way 98'}, {'_id': 10, 'name': 'Vicky', 'address': 'Yellow Garden 2'}, {'_id': 12, 'name': 'William', 'address': 'Central st 954'}, {'_id': 14, 'name': 'Viola', 'address': 'Sideway 1633'}]

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]


print(mydb.list_collection_names())
print(list(mycol.find({'address': {'$regex': '^S'}})))
# Out:
# ['customers']
# [{'_id': 8, 'name': 'Richard', 'address': 'Sky st 331'}, {'_id': 14, 'name': 'Viola', 'address': 'Sideway 1633'}]

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]


print(mydb.list_collection_names())
print(list(mycol.find().sort('name')))
# Out:
# ['customers']
# ...

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]


print(mydb.list_collection_names())
print(list(mycol.find().sort('name', -1)))
# Out:
# ['customers']
# ...

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]


mycol.delete_one({'name':'bishal'})

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]

x = mycol.delete_many({'names':'hemant'})

# %%
x.deleted_count
# Out:
# 1

# %%
list(mycol.find())
# Out:
# [{'_id': ObjectId('5eaf10cfbaf67ec41d26da2d'),
#   'names': 'bibek',
#   'age': 21,
#   'salary': 2300000},
#  {'_id': ObjectId('5eaf10cfbaf67ec41d26da2e'),
#   'names': 'manish',
#   'age': 25,
#   'salary': 239343},
#  {'_id': 1, 'name': 'John', 'address': 'Highway 37'},
#  {'_id': 2, 'name': 'Peter', 'address': 'Lowstreet 27'},
#  {'_id': 3, 'name': 'Amy', 'address': 'Apple st 652'},
#  {'_id': 4, 'name': 'Hannah', 'address': 'Mountain 21'},
#  {'_id': 5, 'name': 'Michael', 'address': 'Valley 345'},
#  {'_id': 6, 'name': 'Sandy', 'address': 'Ocean blvd 2'},
#  {'_id': 7, 'name': 'Betty', 'address': 'Green Grass 1'},
#  {'_id': 8, 'name': 'Richard', 'address': 'Sky st 331'},
#  {'_id': 9, 'name': 'Susan', 'address': 'One way 98'},
#  {'_id': 10, 'name': 'Vicky', 'address': 'Yellow Garden 2'},
#  {'_id': 11, 'name': 'Ben', 'address': 'Park Lane 38'},
#  {'_id': 12, 'name': 'William', 'address': 'Central st 954'},
#  {'_id': 13, 'name': 'Chuck', 'address': 'Main Road 989'},
# ...

# %%
x = mycol.drop()

# %%
print(x)
# Out:
# None

# %%
mydb.list_collection_names()
# Out:
# []

# %%
myclient.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %%
mycol
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mydatabase'), 'customers')

# %%
list(mycol.find())
# Out:
# []

# %%
mylist = mylist = [
  { "name": "Amy", "address": "Apple st 652"},
  { "name": "Hannah", "address": "Mountain 21"},
  { "name": "Michael", "address": "Valley 345"},
  { "name": "Sandy", "address": "Ocean blvd 2"},
  { "name": "Betty", "address": "Green Grass 1"},
  { "name": "Richard", "address": "Sky st 331"},
  { "name": "Susan", "address": "One way 98"},
  { "name": "Vicky", "address": "Yellow Garden 2"},
  { "name": "Ben", "address": "Park Lane 38"},
  { "name": "William", "address": "Central st 954"},
  { "name": "Chuck", "address": "Main Road 989"},
  { "name": "Viola", "address": "Sideway 1633"}
]


mycol.insert_many(mylist)

# %%
list(mycol.find())
# Out:
# [{'_id': ObjectId('5eafa06e6e04440ee19ba164'),
#   'name': 'Amy',
#   'address': 'Apple st 652'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba165'),
#   'name': 'Hannah',
#   'address': 'Mountain 21'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba166'),
#   'name': 'Michael',
#   'address': 'Valley 345'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba167'),
#   'name': 'Sandy',
#   'address': 'Ocean blvd 2'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba168'),
#   'name': 'Betty',
#   'address': 'Green Grass 1'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba169'),
#   'name': 'Richard',
#   'address': 'Sky st 331'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16a'),
#   'name': 'Susan',
#   'address': 'One way 98'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16b'),
#   'name': 'Vicky',
#   'address': 'Yellow Garden 2'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16c'),
#   'name': 'Ben',
#   'address': 'Park Lane 38'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16d'),
#   'name': 'William',
# ...

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]

# x = mycol.delete_many({'names':'hemant'})

myquery = {'name': 'Chuck'}
newvalues = {'$set':{'name': 'Chucking'}}

mycol.update_one(myquery, newvalues)

# %%
list(mycol.find())
# Out:
# [{'_id': ObjectId('5eafa06e6e04440ee19ba164'),
#   'name': 'Amy',
#   'address': 'Apple st 652'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba165'),
#   'name': 'Hannah',
#   'address': 'Mountain 21'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba166'),
#   'name': 'Michael',
#   'address': 'Valley 345'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba167'),
#   'name': 'Sandy',
#   'address': 'Ocean blvd 2'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba168'),
#   'name': 'Betty',
#   'address': 'Green Grass 1'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba169'),
#   'name': 'Richard',
#   'address': 'Sky st 331'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16a'),
#   'name': 'Susan',
#   'address': 'One way 98'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16b'),
#   'name': 'Vicky',
#   'address': 'Yellow Garden 2'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16c'),
#   'name': 'Ben',
#   'address': 'Park Lane 38'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16d'),
#   'name': 'William',
# ...

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

mydb = myclient["mydatabase"]
mycol = mydb["customers"]

# x = mycol.delete_many({'names':'hemant'})

myquery = {'name': 'Chucking'}
newvalues = {'$set':{'name': 'Chucking', 'address': 'San Deago'}}

mycol.update_one(myquery, newvalues)

# %%
list(mycol.find())
# Out:
# [{'_id': ObjectId('5eafa06e6e04440ee19ba164'),
#   'name': 'Amy',
#   'address': 'Apple st 652'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba165'),
#   'name': 'Hannah',
#   'address': 'Mountain 21'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba166'),
#   'name': 'Michael',
#   'address': 'Valley 345'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba167'),
#   'name': 'Sandy',
#   'address': 'Ocean blvd 2'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba168'),
#   'name': 'Betty',
#   'address': 'Green Grass 1'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba169'),
#   'name': 'Richard',
#   'address': 'Sky st 331'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16a'),
#   'name': 'Susan',
#   'address': 'One way 98'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16b'),
#   'name': 'Vicky',
#   'address': 'Yellow Garden 2'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16c'),
#   'name': 'Ben',
#   'address': 'Park Lane 38'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16d'),
#   'name': 'William',
# ...

# %%
myquery = {'name':{'$regex': '^S'}}

list(mycol.find(myquery))
# Out:
# [{'_id': ObjectId('5eafa06e6e04440ee19ba167'),
#   'name': 'Sandy',
#   'address': 'Ocean blvd 2'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16a'),
#   'name': 'Susan',
#   'address': 'One way 98'}]

# %%
newvalues = {'$set': {'name': 'updated names', 'address': 'updated address'}}

x = mycol.update_many(myquery, newvalues)

# %%
print(x)

# %%
print(x.modified_count)
# Out:
# 2

# %%
list(mycol.find())
# Out:
# [{'_id': ObjectId('5eafa06e6e04440ee19ba164'),
#   'name': 'Amy',
#   'address': 'Apple st 652'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba165'),
#   'name': 'Hannah',
#   'address': 'Mountain 21'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba166'),
#   'name': 'Michael',
#   'address': 'Valley 345'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba167'),
#   'name': 'updated names',
#   'address': 'updated address'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba168'),
#   'name': 'Betty',
#   'address': 'Green Grass 1'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba169'),
#   'name': 'Richard',
#   'address': 'Sky st 331'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16a'),
#   'name': 'updated names',
#   'address': 'updated address'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16b'),
#   'name': 'Vicky',
#   'address': 'Yellow Garden 2'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16c'),
#   'name': 'Ben',
#   'address': 'Park Lane 38'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba16d'),
# ...

# %%
list(mycol.find().limit(3))
# Out:
# [{'_id': ObjectId('5eafa06e6e04440ee19ba164'),
#   'name': 'Amy',
#   'address': 'Apple st 652'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba165'),
#   'name': 'Hannah',
#   'address': 'Mountain 21'},
#  {'_id': ObjectId('5eafa06e6e04440ee19ba166'),
#   'name': 'Michael',
#   'address': 'Valley 345'}]
